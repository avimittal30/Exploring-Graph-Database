# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# %cd /content/drive/MyDrive/Neo4j
# Out:
# /content/drive/MyDrive/Neo4j

# %%
# !pwd
# Out:
# /content/drive/MyDrive/Neo4j

# %%
# !pip install langchain langchain-community langchain-core langchain-experimental langchain-openai langchainhub langsmith py2neo neo4j openai jupyter notebook pandas
# Out:
# Requirement already satisfied: langchain in /usr/local/lib/python3.10/dist-packages (0.2.6)
# Requirement already satisfied: langchain-community in /usr/local/lib/python3.10/dist-packages (0.2.6)
# Requirement already satisfied: langchain-core in /usr/local/lib/python3.10/dist-packages (0.2.11)
# Requirement already satisfied: langchain-experimental in /usr/local/lib/python3.10/dist-packages (0.0.62)
# Requirement already satisfied: langchain-openai in /usr/local/lib/python3.10/dist-packages (0.1.14)
# Requirement already satisfied: langchainhub in /usr/local/lib/python3.10/dist-packages (0.1.20)
# Requirement already satisfied: langsmith in /usr/local/lib/python3.10/dist-packages (0.1.83)
# Requirement already satisfied: py2neo in /usr/local/lib/python3.10/dist-packages (2021.2.4)
# Requirement already satisfied: neo4j in /usr/local/lib/python3.10/dist-packages (5.22.0)
# Requirement already satisfied: openai in /usr/local/lib/python3.10/dist-packages (1.35.10)
# Requirement already satisfied: jupyter in /usr/local/lib/python3.10/dist-packages (1.0.0)
# Requirement already satisfied: notebook in /usr/local/lib/python3.10/dist-packages (6.5.5)
# Requirement already satisfied: pandas in /usr/local/lib/python3.10/dist-packages (2.0.3)
# Requirement already satisfied: PyYAML>=5.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (6.0.1)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.0.31)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /usr/local/lib/python3.10/dist-packages (from langchain) (3.9.5)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (4.0.3)
# Requirement already satisfied: langchain-text-splitters<0.3.0,>=0.2.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (0.2.2)
# Requirement already satisfied: numpy<2,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (1.25.2)
# Requirement already satisfied: pydantic<3,>=1 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.8.0)
# Requirement already satisfied: requests<3,>=2 in /usr/local/lib/python3.10/dist-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity!=8.4.0,<9.0.0,>=8.1.0 in /usr/local/lib/python3.10/dist-packages (from langchain) (8.4.2)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /usr/local/lib/python3.10/dist-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (1.33)
# Requirement already satisfied: packaging<25,>=23.2 in /usr/local/lib/python3.10/dist-packages (from langchain-core) (24.1)
# Requirement already satisfied: tiktoken<1,>=0.7 in /usr/local/lib/python3.10/dist-packages (from langchain-openai) (0.7.0)
# Requirement already satisfied: types-requests<3.0.0.0,>=2.31.0.2 in /usr/local/lib/python3.10/dist-packages (from langchainhub) (2.32.0.20240622)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /usr/local/lib/python3.10/dist-packages (from langsmith) (3.10.6)
# Requirement already satisfied: certifi in /usr/local/lib/python3.10/dist-packages (from py2neo) (2024.6.2)
# Requirement already satisfied: interchange~=2021.0.4 in /usr/local/lib/python3.10/dist-packages (from py2neo) (2021.0.4)
# Requirement already satisfied: monotonic in /usr/local/lib/python3.10/dist-packages (from py2neo) (1.6)
# Requirement already satisfied: pansi>=2020.7.3 in /usr/local/lib/python3.10/dist-packages (from py2neo) (2020.7.3)
# Requirement already satisfied: pygments>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from py2neo) (2.16.1)
# Requirement already satisfied: six>=1.15.0 in /usr/local/lib/python3.10/dist-packages (from py2neo) (1.16.0)
# Requirement already satisfied: urllib3 in /usr/local/lib/python3.10/dist-packages (from py2neo) (2.0.7)
# Requirement already satisfied: pytz in /usr/local/lib/python3.10/dist-packages (from neo4j) (2023.4)
# Requirement already satisfied: anyio<5,>=3.5.0 in /usr/local/lib/python3.10/dist-packages (from openai) (3.7.1)
# Requirement already satisfied: distro<2,>=1.7.0 in /usr/lib/python3/dist-packages (from openai) (1.7.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /usr/local/lib/python3.10/dist-packages (from openai) (0.27.0)
# Requirement already satisfied: sniffio in /usr/local/lib/python3.10/dist-packages (from openai) (1.3.1)
# Requirement already satisfied: tqdm>4 in /usr/local/lib/python3.10/dist-packages (from openai) (4.66.4)
# Requirement already satisfied: typing-extensions<5,>=4.7 in /usr/local/lib/python3.10/dist-packages (from openai) (4.12.2)
# Requirement already satisfied: qtconsole in /usr/local/lib/python3.10/dist-packages (from jupyter) (5.5.2)
# Requirement already satisfied: jupyter-console in /usr/local/lib/python3.10/dist-packages (from jupyter) (6.1.0)
# Requirement already satisfied: nbconvert in /usr/local/lib/python3.10/dist-packages (from jupyter) (6.5.4)
# Requirement already satisfied: ipykernel in /usr/local/lib/python3.10/dist-packages (from jupyter) (5.5.6)
# Requirement already satisfied: ipywidgets in /usr/local/lib/python3.10/dist-packages (from jupyter) (7.7.1)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from notebook) (3.1.4)
# Requirement already satisfied: tornado>=6.1 in /usr/local/lib/python3.10/dist-packages (from notebook) (6.3.3)
# Requirement already satisfied: pyzmq<25,>=17 in /usr/local/lib/python3.10/dist-packages (from notebook) (24.0.1)
# Requirement already satisfied: argon2-cffi in /usr/local/lib/python3.10/dist-packages (from notebook) (23.1.0)
# Requirement already satisfied: traitlets>=4.2.1 in /usr/local/lib/python3.10/dist-packages (from notebook) (5.7.1)
# Requirement already satisfied: jupyter-core>=4.6.1 in /usr/local/lib/python3.10/dist-packages (from notebook) (5.7.2)
# Requirement already satisfied: jupyter-client<8,>=5.3.4 in /usr/local/lib/python3.10/dist-packages (from notebook) (6.1.12)
# Requirement already satisfied: ipython-genutils in /usr/local/lib/python3.10/dist-packages (from notebook) (0.2.0)
# Requirement already satisfied: nbformat in /usr/local/lib/python3.10/dist-packages (from notebook) (5.10.4)
# Requirement already satisfied: nest-asyncio>=1.5 in /usr/local/lib/python3.10/dist-packages (from notebook) (1.6.0)
# Requirement already satisfied: Send2Trash>=1.8.0 in /usr/local/lib/python3.10/dist-packages (from notebook) (1.8.3)
# Requirement already satisfied: terminado>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from notebook) (0.18.1)
# Requirement already satisfied: prometheus-client in /usr/local/lib/python3.10/dist-packages (from notebook) (0.20.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /usr/local/lib/python3.10/dist-packages (from notebook) (1.1.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.10/dist-packages (from pandas) (2.8.2)
# Requirement already satisfied: tzdata>=2022.1 in /usr/local/lib/python3.10/dist-packages (from pandas) (2024.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.2.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.4.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.5)
# Requirement already satisfied: yarl<2.0,>=1.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.4)
# Requirement already satisfied: idna>=2.8 in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (3.7)
# Requirement already satisfied: exceptiongroup in /usr/local/lib/python3.10/dist-packages (from anyio<5,>=3.5.0->openai) (1.2.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.21.3)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: httpcore==1.* in /usr/local/lib/python3.10/dist-packages (from httpx<1,>=0.23.0->openai) (1.0.5)
# Requirement already satisfied: h11<0.15,>=0.13 in /usr/local/lib/python3.10/dist-packages (from httpcore==1.*->httpx<1,>=0.23.0->openai) (0.14.0)
# Requirement already satisfied: jsonpointer>=1.9 in /usr/local/lib/python3.10/dist-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: platformdirs>=2.5 in /usr/local/lib/python3.10/dist-packages (from jupyter-core>=4.6.1->notebook) (4.2.2)
# Requirement already satisfied: notebook-shim>=0.2.3 in /usr/local/lib/python3.10/dist-packages (from nbclassic>=0.4.7->notebook) (0.2.4)
# Requirement already satisfied: lxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (4.9.4)
# Requirement already satisfied: beautifulsoup4 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (4.12.3)
# Requirement already satisfied: bleach in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (6.1.0)
# Requirement already satisfied: defusedxml in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (0.7.1)
# Requirement already satisfied: entrypoints>=0.2.2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (0.4)
# Requirement already satisfied: jupyterlab-pygments in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (0.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (2.1.5)
# Requirement already satisfied: mistune<2,>=0.8.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (0.8.4)
# Requirement already satisfied: nbclient>=0.5.0 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (0.10.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (1.5.1)
# Requirement already satisfied: tinycss2 in /usr/local/lib/python3.10/dist-packages (from nbconvert->jupyter) (1.3.0)
# Requirement already satisfied: fastjsonschema>=2.15 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook) (2.20.0)
# Requirement already satisfied: jsonschema>=2.6 in /usr/local/lib/python3.10/dist-packages (from nbformat->notebook) (4.19.2)
# Requirement already satisfied: annotated-types>=0.4.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.20.0 in /usr/local/lib/python3.10/dist-packages (from pydantic<3,>=1->langchain) (2.20.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.10/dist-packages (from requests<3,>=2->langchain) (3.3.2)
# Requirement already satisfied: greenlet!=0.4.17 in /usr/local/lib/python3.10/dist-packages (from SQLAlchemy<3,>=1.4->langchain) (3.0.3)
# Requirement already satisfied: ptyprocess in /usr/local/lib/python3.10/dist-packages (from terminado>=0.8.3->notebook) (0.7.0)
# Requirement already satisfied: regex>=2022.1.18 in /usr/local/lib/python3.10/dist-packages (from tiktoken<1,>=0.7->langchain-openai) (2024.5.15)
# Requirement already satisfied: argon2-cffi-bindings in /usr/local/lib/python3.10/dist-packages (from argon2-cffi->notebook) (21.2.0)
# Requirement already satisfied: ipython>=5.0.0 in /usr/local/lib/python3.10/dist-packages (from ipykernel->jupyter) (7.34.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter) (3.6.6)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /usr/local/lib/python3.10/dist-packages (from ipywidgets->jupyter) (3.0.11)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.10/dist-packages (from jupyter-console->jupyter) (3.0.47)
# Requirement already satisfied: qtpy>=2.4.0 in /usr/local/lib/python3.10/dist-packages (from qtconsole->jupyter) (2.4.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter) (67.7.2)
# Requirement already satisfied: jedi>=0.16 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter) (0.19.1)
# Requirement already satisfied: decorator in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter) (0.7.5)
# Requirement already satisfied: backcall in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.10/dist-packages (from ipython>=5.0.0->ipykernel->jupyter) (4.9.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook) (0.35.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /usr/local/lib/python3.10/dist-packages (from jsonschema>=2.6->nbformat->notebook) (0.18.1)
# Requirement already satisfied: jupyter-server<3,>=1.8 in /usr/local/lib/python3.10/dist-packages (from notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook) (1.24.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.10/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->jupyter-console->jupyter) (0.2.13)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /usr/local/lib/python3.10/dist-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.0.0)
# Requirement already satisfied: cffi>=1.0.1 in /usr/local/lib/python3.10/dist-packages (from argon2-cffi-bindings->argon2-cffi->notebook) (1.16.0)
# Requirement already satisfied: soupsieve>1.2 in /usr/local/lib/python3.10/dist-packages (from beautifulsoup4->nbconvert->jupyter) (2.5)
# Requirement already satisfied: webencodings in /usr/local/lib/python3.10/dist-packages (from bleach->nbconvert->jupyter) (0.5.1)
# Requirement already satisfied: pycparser in /usr/local/lib/python3.10/dist-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook) (2.22)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /usr/local/lib/python3.10/dist-packages (from jedi>=0.16->ipython>=5.0.0->ipykernel->jupyter) (0.8.4)
# Requirement already satisfied: websocket-client in /usr/local/lib/python3.10/dist-packages (from jupyter-server<3,>=1.8->notebook-shim>=0.2.3->nbclassic>=0.4.7->notebook) (1.8.0)

# %%
import os
import pandas as pd

from langchain_community.graphs import Neo4jGraph

# In local pc - to access env variables
# from dotenv import load_dotenv
# _ = load_dotenv()
from google.colab import userdata # For colab env variables

# %%
os.environ["NEO4J_USERNAME"] = userdata.get('NEO4J_USERNAME')
os.environ["NEO4J_PASSWORD"] = userdata.get('NEO4J_PASSWORD')
os.environ["NEO4J_URI"] = userdata.get('NEO4J_URI')

# %%
df = pd.read_csv('vgsales.csv')

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df['Rank'].nunique()==df.shape[0]
# Out:
# True

# %%
kg = Neo4jGraph()

# %%
vgsales_query = """
LOAD CSV WITH HEADERS FROM 'https://raw.githubusercontent.com/KNAI-AI/knai-workshop/main/data/vgsales.csv' AS row
MERGE (g:Game {rank:toInteger(row.Rank)})
SET g.name = row.Name,
    g.platform = row.Platform,
    g.year = toInteger(row.Year),
    g.genre = row.Genre,
    g.publisher = row.Publisher,
    g.na_sales = toFloat(row.NA_Sales),
    g.eu_sales = toFloat(row.EU_Sales),
    g.jp_sales = toFloat(row.JP_Sales),
    g.other_sales = toFloat(row.Other_Sales),
    g.global_sales = toFloat(row.Global_Sales)

MERGE (p:Platform {name:row.Platform})
MERGE (g)-[:RELEASED_ON]->(p)

MERGE (pub:Publisher {name:row.Publisher})
MERGE (g)-[:PUBLISHED_BY]->(pub)

MERGE (ge:Genre {name:row.Genre})
MERGE (g)-[:BELONGS_TO_GENRE]->(ge)
"""
kg.query(vgsales_query)
# Out:
# []

# %%
kg.refresh_schema()
print(kg.schema)
# Out:
# Node properties:
# Game {rank: INTEGER, name: STRING, platform: STRING, year: INTEGER, genre: STRING, publisher: STRING, na_sales: FLOAT, eu_sales: FLOAT, jp_sales: FLOAT, other_sales: FLOAT, global_sales: FLOAT}
# Platform {name: STRING}
# Publisher {name: STRING}
# Genre {name: STRING}
# Relationship properties:
#
# The relationships:
# (:Game)-[:RELEASED_ON]->(:Platform)
# (:Game)-[:PUBLISHED_BY]->(:Publisher)
# (:Game)-[:BELONGS_TO_GENRE]->(:Genre)

# %%
cypher = """
  MATCH (n)
  RETURN count(n) AS numberOfNodes
  """
result = kg.query(cypher)
result
# Out:
# [{'numberOfNodes': 17220}]

# %%
df['Rank'].nunique()+df['Platform'].nunique()+df['Genre'].nunique() + df['Publisher'].nunique()
# Out:
# 17219

# %%
print(f"There are {result[0]['numberOfNodes']} nodes in this graph.")
# Out:
# There are 17220 nodes in this graph.

# %%
cypher = """
  MATCH (n:Game)
  RETURN count(n) AS numberOfGames
  """
kg.query(cypher)
# Out:
# [{'numberOfGames': 16598}]

# %%
cypher = """
  MATCH (nintendo:Publisher {name:"Nintendo"})
  RETURN count(nintendo) as count_nintendo
  """
kg.query(cypher)
# Out:
# [{'count_nintendo': 1}]

# %%
cypher = """
  MATCH (gta:Game {name:"Grand Theft Auto: San Andreas"})
  RETURN gta.global_sales
  """
kg.query(cypher)
# Out:
# [{'gta.global_sales': 20.81},
#  {'gta.global_sales': 1.95},
#  {'gta.global_sales': 0.98},
#  {'gta.global_sales': 0.12}]

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
df[df['Name']=='Grand Theft Auto: San Andreas']
# Out:
#       Rank                           Name Platform    Year   Genre  \
# 17      18  Grand Theft Auto: San Andreas      PS2  2004.0  Action
# 873    875  Grand Theft Auto: San Andreas       XB  2005.0  Action
# 2120  2122  Grand Theft Auto: San Andreas       PC  2005.0  Action
# 9827  9829  Grand Theft Auto: San Andreas     X360  2008.0  Action
#
#                  Publisher  NA_Sales  EU_Sales  JP_Sales  Other_Sales  \
# 17    Take-Two Interactive      9.43      0.40      0.41        10.57
# 873   Take-Two Interactive      1.26      0.61      0.00         0.09
# 2120  Take-Two Interactive      0.00      0.92      0.00         0.05
# 9827  Take-Two Interactive      0.08      0.03      0.00         0.01
#
#       Global_Sales
# 17           20.81
# 873           1.95
# 2120          0.98
# 9827          0.12

# %%
cypher = """
  MATCH (marioBros:Game {name:"New Super Mario Bros."})
  RETURN marioBros.global_sales, marioBros.publisher
  """
kg.query(cypher)
# Out:
# [{'marioBros.global_sales': 30.01, 'marioBros.publisher': 'Nintendo'}]

# %%
cypher = """
    MATCH (g:Game)
    RETURN g.platform AS platform, SUM(g.global_sales) AS totalGlobalSales
    ORDER BY totalGlobalSales DESC
  """

kg.query(cypher)
# Out:
# [{'platform': 'PS2', 'totalGlobalSales': 1255.6399999999871},
#  {'platform': 'X360', 'totalGlobalSales': 979.9599999999996},
#  {'platform': 'PS3', 'totalGlobalSales': 957.8399999999987},
#  {'platform': 'Wii', 'totalGlobalSales': 926.7099999999971},
#  {'platform': 'DS', 'totalGlobalSales': 822.4899999999874},
#  {'platform': 'PS', 'totalGlobalSales': 730.659999999997},
#  {'platform': 'GBA', 'totalGlobalSales': 318.499999999998},
#  {'platform': 'PSP', 'totalGlobalSales': 296.2799999999948},
#  {'platform': 'PS4', 'totalGlobalSales': 278.0999999999994},
#  {'platform': 'PC', 'totalGlobalSales': 258.81999999999846},
#  {'platform': 'XB', 'totalGlobalSales': 258.25999999999834},
#  {'platform': 'GB', 'totalGlobalSales': 255.44999999999987},
#  {'platform': 'NES', 'totalGlobalSales': 251.06999999999988},
#  {'platform': '3DS', 'totalGlobalSales': 247.4600000000001},
#  {'platform': 'N64', 'totalGlobalSales': 218.87999999999985},
#  {'platform': 'SNES', 'totalGlobalSales': 200.05000000000024},
#  {'platform': 'GC', 'totalGlobalSales': 199.3600000000007},
#  {'platform': 'XOne', 'totalGlobalSales': 141.05999999999995},
#  {'platform': '2600', 'totalGlobalSales': 97.08000000000003},
#  {'platform': 'WiiU', 'totalGlobalSales': 81.86000000000006},
#  {'platform': 'PSV', 'totalGlobalSales': 61.93000000000005},
#  {'platform': 'SAT', 'totalGlobalSales': 33.59000000000002},
#  {'platform': 'GEN', 'totalGlobalSales': 28.360000000000003},
#  {'platform': 'DC', 'totalGlobalSales': 15.969999999999997},
#  {'platform': 'SCD', 'totalGlobalSales': 1.8700000000000003},
#  {'platform': 'NG', 'totalGlobalSales': 1.4400000000000004},
#  {'platform': 'WS', 'totalGlobalSales': 1.42},
#  {'platform': 'TG16', 'totalGlobalSales': 0.16},
#  {'platform': '3DO', 'totalGlobalSales': 0.1},
#  {'platform': 'GG', 'totalGlobalSales': 0.04},
#  {'platform': 'PCFX', 'totalGlobalSales': 0.03}]

# %%
cypher = """
  MATCH (nineties:Game)
  WHERE nineties.year >= 1990
    AND nineties.year < 2000
  RETURN nineties.name
  """
kg.query(cypher)
# Out:
# [{'nineties.name': 'Pokemon Red/Pokemon Blue'},
#  {'nineties.name': 'Pokemon Gold/Pokemon Silver'},
#  {'nineties.name': 'Super Mario World'},
#  {'nineties.name': 'Pokémon Yellow: Special Pikachu Edition'},
#  {'nineties.name': 'Super Mario 64'},
#  {'nineties.name': 'Super Mario Land 2: 6 Golden Coins'},
#  {'nineties.name': 'Gran Turismo'},
#  {'nineties.name': 'Super Mario All-Stars'},
#  {'nineties.name': 'Mario Kart 64'},
#  {'nineties.name': 'Final Fantasy VII'},
#  {'nineties.name': 'Gran Turismo 2'},
#  {'nineties.name': 'Donkey Kong Country'},
#  {'nineties.name': 'Super Mario Kart'},
#  {'nineties.name': 'GoldenEye 007'},
#  {'nineties.name': 'Final Fantasy VIII'},
#  {'nineties.name': 'The Legend of Zelda: Ocarina of Time'},
#  {'nineties.name': 'Crash Bandicoot 2: Cortex Strikes Back'},
#  {'nineties.name': 'Tekken 3'},
#  {'nineties.name': 'Crash Bandicoot 3: Warped'},
#  {'nineties.name': 'Crash Bandicoot'},
#  {'nineties.name': 'Street Fighter II: The World Warrior'},
#  {'nineties.name': 'Driver'},
#  {'nineties.name': 'Sonic the Hedgehog 2'},
#  {'nineties.name': 'Metal Gear Solid'},
#  {'nineties.name': 'Resident Evil 2'},
#  {'nineties.name': 'Tekken 2'},
#  {'nineties.name': 'Super Smash Bros.'},
#  {'nineties.name': 'Pokemon Stadium'},
#  {'nineties.name': 'Pokemon Pinball'},
#  {'nineties.name': 'Donkey Kong 64'},
#  {'nineties.name': 'Tomb Raider II'},
#  {'nineties.name': 'Super Mario Land 3: Wario Land'},
#  {'nineties.name': "Donkey Kong Country 2: Diddy's Kong Quest"},
#  {'nineties.name': "Kirby's Dream Land"},
#  {'nineties.name': 'Microsoft Flight Simulator'},
#  {'nineties.name': 'Super Mario Bros.'},
#  {'nineties.name': 'Resident Evil'},
#  {'nineties.name': "Tony Hawk's Pro Skater"},
#  {'nineties.name': 'Warzone 2100'},
#  {'nineties.name': 'Spyro the Dragon'},
#  {'nineties.name': 'Diddy Kong Racing'},
#  {'nineties.name': 'Dr. Mario'},
#  {'nineties.name': 'Crash Team Racing'},
#  {'nineties.name': 'Tomb Raider'},
#  {'nineties.name': 'The Legend of Zelda: A Link to the Past'},
#  {'nineties.name': 'Sonic the Hedgehog'},
#  {'nineties.name': 'Warcraft II: Tides of Darkness'},
#  {'nineties.name': 'Frogger'},
#  {'nineties.name': 'Half-Life'},
#  {'nineties.name': "Super Mario World 2: Yoshi's Island"},
#  {'nineties.name': 'Street Fighter II Turbo'},
#  {'nineties.name': 'Namco Museum Vol.3'},
#  {'nineties.name': 'Star Fox 64'},
#  {'nineties.name': 'Donkey Kong Land'},
#  {'nineties.name': 'Namco Museum Vol.1'},
#  {'nineties.name': "The Legend of Zelda: Link's Awakening"},
#  {'nineties.name': "Resident Evil Director's Cut"},
#  {'nineties.name': 'Resident Evil 3: Nemesis'},
#  {'nineties.name': 'Pokémon Trading Card Game'},
#  {'nineties.name': 'Banjo-Kazooie'},
#  {'nineties.name': 'Pokemon Snap'},
#  {'nineties.name': 'Doom II: Hell on Earth'},
#  {'nineties.name': 'Croc: Legend of the Gobbos'},
#  {'nineties.name': 'Tomb Raider III: Adventures of Lara Croft'},
#  {'nineties.name': "Spyro 2: Ripto's Rage!"},
#  {'nineties.name': "Donkey Kong Country 3: Dixie Kong's Double Trouble!"},
#  {'nineties.name': 'Grand Theft Auto 2'},
#  {'nineties.name': 'Final Fantasy III'},
#  {'nineties.name': 'F-1 Race'},
#  {'nineties.name': 'WWF War Zone'},
#  {'nineties.name': 'Rugrats: Search For Reptar'},
#  {'nineties.name': 'Tekken'},
#  {'nineties.name': '007: Tomorrow Never Dies'},
#  {'nineties.name': 'Killer Instinct'},
#  {'nineties.name': 'Dragon Quest VI: Maboroshi no Daichi'},
#  {'nineties.name': 'Need for Speed III: Hot Pursuit'},
#  {'nineties.name': 'Star Wars Episode I Racer'},
#  {'nineties.name': 'Dragon Warrior IV'},
#  {'nineties.name': 'Donkey Kong'},
#  {'nineties.name': 'Rayman'},
#  {'nineties.name': 'Star Fox'},
#  {'nineties.name': 'Wave Race 64'},
#  {'nineties.name': 'Syphon Filter'},
#  {'nineties.name': 'Colin McRae Rally'},
#  {'nineties.name': 'F-Zero'},
#  {'nineties.name': "Yoshi's Story"},
#  {'nineties.name': 'Command & Conquer: Red Alert'},
#  {'nineties.name': 'Myst'},
#  {'nineties.name': 'Hot Shots Golf'},
#  {'nineties.name': "A Bug's Life"},
#  {'nineties.name': 'Dragon Quest V: Tenkuu no Hanayome'},
#  {'nineties.name': 'Mortal Kombat Trilogy'},
#  {'nineties.name': 'Mario Paint'},
#  {'nineties.name': 'Mario Party'},
#  {'nineties.name': 'Mortal Kombat'},
#  {'nineties.name': 'Medal of Honor'},
#  {'nineties.name': 'Star Wars: Shadows of the Empire'},
#  {'nineties.name': 'Streets of Rage'},
#  {'nineties.name': 'Mario Party 2'},
#  {'nineties.name': 'Tomb Raider: The Last Revelation'},
#  {'nineties.name': 'Final Fantasy V'},
#  {'nineties.name': 'Final Fantasy Tactics'},
#  {'nineties.name': 'Twisted Metal 2'},
#  {'nineties.name': 'Riven: The Sequel to Myst'},
#  {'nineties.name': 'Sonic Adventure'},
#  {'nineties.name': 'Dino Crisis'},
#  {'nineties.name': 'Tetris Plus'},
#  {'nineties.name': 'Theme Hospital'},
#  {'nineties.name': 'Monopoly'},
#  {'nineties.name': 'WCW/nWo Revenge'},
#  {'nineties.name': "Kirby's Dream Land 2"},
#  {'nineties.name': 'Donkey Kong Land II'},
#  {'nineties.name': 'Dragon Warrior Monsters'},
#  {'nineties.name': 'Grand Theft Auto'},
#  {'nineties.name': 'Need For Speed: High Stakes'},
#  {'nineties.name': 'Chrono Trigger'},
#  {'nineties.name': 'Cool Boarders 3'},
#  {'nineties.name': 'Tomb Raider II'},
#  {'nineties.name': 'TOCA Touring Car Championship'},
#  {'nineties.name': 'Cool Boarders 2'},
#  {'nineties.name': 'Teenage Mutant Ninja Turtles II: The Arcade Game'},
#  {'nineties.name': "The Legend of Zelda: Link's Awakening DX"},
#  {'nineties.name': "Kirby's Pinball Land"},
#  {'nineties.name': 'Star Wars: Rogue Squadron'},
#  {'nineties.name': 'Super Mario RPG: Legend of the Seven Stars'},
#  {'nineties.name': 'SimCity 2000'},
#  {'nineties.name': 'Parasite Eve'},
#  {'nineties.name': 'Derby Stallion'},
#  {'nineties.name': 'Sim Theme Park'},
#  {'nineties.name': 'Warcraft: Orcs & Humans'},
#  {'nineties.name': 'R4: Ridge Racer Type 4'},
#  {'nineties.name': 'NBA Jam'},
#  {'nineties.name': '1080°: TenEighty Snowboarding'},
#  {'nineties.name': 'Super Street Fighter II'},
#  {'nineties.name': 'Tenchu: Stealth Assassins'},
#  {'nineties.name': 'SimCity'},
#  {'nineties.name': 'Star Wars: Dark Forces'},
#  {'nineties.name': 'Who wants to be a millionaire'},
#  {'nineties.name': 'Jet Moto 2'},
#  {'nineties.name': 'Mortal Kombat II'},
#  {'nineties.name': 'Virtua Fighter 2'},
#  {'nineties.name': 'Tetris DX'},
#  {'nineties.name': 'PaRappa The Rapper'},
#  {'nineties.name': 'Yu-Gi-Oh! Forbidden Memories'},
#  {'nineties.name': 'Hot Shots Golf 2'},
#  {'nineties.name': 'WCW Nitro'},
#  {'nineties.name': 'FIFA 2000'},
#  {'nineties.name': 'The Legend of Dragoon'},
#  {'nineties.name': 'Turok 2: Seeds of Evil'},
#  {'nineties.name': 'Chrono Cross'},
#  {'nineties.name': 'Hey You, Pikachu!'},
#  {'nineties.name': 'Jet Moto'},
#  {'nineties.name': 'Secret of Mana'},
#  {'nineties.name': 'Air Combat'},
#  {'nineties.name': 'Sonic & Knuckles'},
#  {'nineties.name': 'NFL GameDay 2000'},
#  {'nineties.name': "Disney's The Lion King"},
#  {'nineties.name': 'Final Fantasy II'},
#  {'nineties.name': 'Metroid II: Return of Samus'},
#  {'nineties.name': 'WWF Attitude'},
#  {'nineties.name': 'Sonic the Hedgehog 3'},
#  {'nineties.name': 'Madden NFL 2000'},
#  {'nineties.name': 'Yoshi'},
#  {'nineties.name': "Disney's Aladdin"},
#  {'nineties.name': "Kirby's Adventure"},
#  {'nineties.name': 'Star Wars Episode I: The Phantom Menace'},
#  {'nineties.name': "Cruis'n USA"},
#  {'nineties.name': 'Madden NFL 99'},
#  {'nineties.name': 'Twisted Metal III'},
#  {'nineties.name': 'Toy Story 2: Buzz Lightyear to the Rescue!'},
#  {'nineties.name': 'Super Puyo Puyo'},
#  {'nineties.name': "Jampack Winter '99"},
#  {'nineties.name': 'WCW vs. nWo: World Tour'},
#  {'nineties.name': 'WCW/NWO Thunder'},
#  {'nineties.name': 'NFL GameDay 98'},
#  {'nineties.name': "Yoshi's Cookie"},
#  {'nineties.name': 'Time Crisis'},
#  {'nineties.name': "Street Fighter II': Special Champion Edition"},
#  {'nineties.name': 'Super Scope 6'},
#  {'nineties.name': "Tom Clancy's Rainbow Six"},
#  {'nineties.name': 'Ape Escape'},
#  {'nineties.name': 'Sled Storm'},
#  {'nineties.name': 'Yu-Gi-Oh! Duel Monsters'},
#  {'nineties.name': 'F-1 World Grand Prix'},
#  {'nineties.name': 'Silent Hill'},
#  {'nineties.name': 'Diablo'},
#  {'nineties.name': 'Soul Edge'},
#  {'nineties.name': 'NASCAR 2000'},
#  {'nineties.name': 'Twisted Metal'},
#  {'nineties.name': 'Final Fight'},
#  {'nineties.name': 'Command & Conquer: Tiberian Sun'},
#  {'nineties.name': 'Die Hard Trilogy'},
#  {'nineties.name': 'Mortal Kombat 3'},
#  {'nineties.name': 'NFL GameDay 99'},
#  {'nineties.name': 'Tiger Woods 99 PGA Tour Golf'},
#  {'nineties.name': 'Knockout Kings'},
#  {'nineties.name': 'NASCAR 98'},
#  {'nineties.name': 'NASCAR 99'},
#  {'nineties.name': 'NBA Live 2000'},
#  {'nineties.name': 'NBA Live 98'},
#  {'nineties.name': 'Monopoly'},
#  {'nineties.name': 'NFL Blitz'},
#  {'nineties.name': 'Sonic CD'},
#  {'nineties.name': 'Pac-Man World'},
#  {'nineties.name': 'Nintendo World Cup'},
#  {'nineties.name': 'WWF WrestleMania 2000'},
#  {'nineties.name': 'Wario Land II'},
#  {'nineties.name': 'Mario Golf'},
#  {'nineties.name': 'Xenogears'},
#  {'nineties.name': 'Mortal Kombat 4'},
#  {'nineties.name': 'WCW vs the World'},
#  {'nineties.name': 'Tamagotchi'},
#  {'nineties.name': 'Dragon Ball Z'},
#  {'nineties.name': 'Game de Hakken!! Tamagotchi 2'},
#  {'nineties.name': 'Namco Museum 64'},
#  {'nineties.name': 'Kirby Super Star'},
#  {'nineties.name': "Frogger 2: Swampy's Revenge"},
#  {'nineties.name': 'Triple Play 2000'},
#  {'nineties.name': 'Super Metroid'},
#  {'nineties.name': "Disney's The Lion King"},
#  {'nineties.name': 'Knockout Kings 2000'},
#  {'nineties.name': '2Xtreme'},
#  {'nineties.name': 'Final Fantasy III'},
#  {'nineties.name': 'NBA Jam'},
#  {'nineties.name': 'Teenage Mutant Ninja Turtles III: The Manhattan Project'},
#  {'nineties.name': 'Duke Nukem: Time to Kill'},
#  {'nineties.name': 'A Collection of Activision Classic Games for the Atari 2600'},
#  {'nineties.name': 'Pocket Monsters Stadium'},
#  {'nineties.name': 'Dragon Quest III: Soshite Densetsu e...'},
#  {'nineties.name': 'Dance Dance Revolution (Japan)'},
#  {'nineties.name': 'Madden NFL 98'},
#  {'nineties.name': 'SaGa Frontier'},
#  {'nineties.name': 'Mortal Kombat 3'},
#  {'nineties.name': 'WWF War Zone'},
#  {'nineties.name': 'TOCA 2: Touring Cars'},
#  {'nineties.name': 'Fighting Force'},
#  {'nineties.name': 'Madden NFL 97'},
#  {'nineties.name': 'TNN Motor Sports Hardcore 4x4'},
#  {'nineties.name': 'Rugrats Studio Tour'},
#  {'nineties.name': 'Test Drive 5'},
#  {'nineties.name': 'Romancing SaGa 3'},
#  {'nineties.name': 'Digimon World'},
#  {'nineties.name': 'Army Men 3D'},
#  {'nineties.name': 'Twisted Metal 4'},
#  {'nineties.name': 'Castlevania: Symphony of the Night'},
#  {'nineties.name': 'Road Rash'},
#  {'nineties.name': 'Battle Arena Toshinden'},
#  {'nineties.name': 'Devil Dice'},
#  {'nineties.name': 'Brian Lara Cricket'},
#  {'nineties.name': 'Wheel of Fortune'},
#  {'nineties.name': 'Reel Fishing'},
#  {'nineties.name': 'Road Rash 3D'},
#  {'nineties.name': "Oddworld: Abe's Oddysee"},
#  {'nineties.name': 'Tetris 2 (All region sales)'},
#  {'nineties.name': 'Vigilante 8'},
#  {'nineties.name': 'Intelligent Qube'},
#  {'nineties.name': 'Game & Watch Gallery 2'},
#  {'nineties.name': 'Game & Watch Gallery 3'},
#  {'nineties.name': 'NBA Live 99'},
#  {'nineties.name': 'Chocobo no Fushigi Dungeon'},
#  {'nineties.name': 'SimCity 2000'},
#  {'nineties.name': 'WCW Mayhem'},
#  {'nineties.name': 'The Magical Quest starring Mickey Mouse'},
#  {'nineties.name': 'Star Wars Episode 1: Jedi Power Battles'},
#  {'nineties.name': 'Test Drive 4'},
#  {'nineties.name': 'Dragon Ball Z: La Legende Saien'},
#  {'nineties.name': 'NFL 2K'},
#  {'nineties.name': 'Nuclear Strike'},
#  {'nineties.name': 'Kobe Bryant in NBA Courtside'},
#  {'nineties.name': "Disney's Chip 'n Dale: Rescue Rangers"},
#  {'nineties.name': 'The Dukes of Hazzard: Racing for Home'},
#  {'nineties.name': 'Metal Gear Solid VR Missions'},
#  {'nineties.name': 'Shenmue'},
#  {'nineties.name': "Super Ghouls 'n Ghosts"},
#  {'nineties.name': 'Soviet Strike'},
#  {'nineties.name': 'Mega Man 3'},
#  {'nineties.name': 'Mission: Impossible'},
#  {'nineties.name': 'Romancing SaGa 2'},
#  {'nineties.name': 'Cool Boarders 4'},
#  {'nineties.name': 'Rage Racer'},
#  {'nineties.name': 'Destruction Derby 2'},
#  {'nineties.name': 'Bushido Blade'},
#  {'nineties.name': 'Jet Force Gemini'},
#  {'nineties.name': 'Mega Man X'},
#  {'nineties.name': 'Sega Rally Championship'},
#  {'nineties.name': 'Test Drive: Off Road'},
#  {'nineties.name': 'Qix'},
#  {'nineties.name': 'Derby Stallion III'},
#  {'nineties.name': 'Dragon Quest I & II'},
#  {'nineties.name': 'Asteroids'},
#  {'nineties.name': 'Puyo Puyo Sun Ketteiban'},
#  {'nineties.name': 'Brave Fencer Musashi'},
#  {'nineties.name': 'South Park'},
#  {'nineties.name': 'Pilotwings'},
#  {'nineties.name': 'Super R.C. Pro-Am'},
#  {'nineties.name': 'Derby Stallion 99'},
#  {'nineties.name': "Jampack Winter '98"},
#  {'nineties.name': 'Pilotwings 64'},
#  {'nineties.name': "Yoshi's Cookie"},
#  {'nineties.name': 'Arc the Lad'},
#  {'nineties.name': 'NBA Jam Tournament Edition'},
#  {'nineties.name': 'Legend of Mana'},
#  {'nineties.name': 'Triple Play 98'},
#  {'nineties.name': 'Yu-Gi-Oh! Duel Monsters II: Dark Duel Stories'},
#  {'nineties.name': 'F-Zero X'},
#  {'nineties.name': 'Star Ocean: The Second Story'},
#  {'nineties.name': 'BeatMania'},
#  {'nineties.name': 'Densha De Go!'},
#  {'nineties.name': 'NFL Blitz 2000'},
#  {'nineties.name': 'Ready 2 Rumble Boxing'},
#  {'nineties.name': 'Doko Demo Issyo'},
#  {'nineties.name': 'Virtua Fighter'},
#  {'nineties.name': 'Championship Manager 99/00'},
#  {'nineties.name': 'NHL 99'},
#  {'nineties.name': 'Ridge Racer Revolution'},
#  {'nineties.name': 'Hot Wheels Turbo Racing'},
#  {'nineties.name': 'NCAA Football 99'},
#  {'nineties.name': 'Simple 1500 Series Vol. 1: The Mahjong'},
#  {'nineties.name': 'Worms Armageddon'},
#  {'nineties.name': 'NFL Blitz'},
#  {'nineties.name': 'NFL Quarterback Club 98'},
#  {'nineties.name': 'Arc the Lad II'},
#  {'nineties.name': 'Derby Stallion 96'},
#  {'nineties.name': 'Monster Rancher 2'},
#  {'nineties.name': 'Tales of Destiny'},
#  {'nineties.name': 'Mega Man X4'},
#  {'nineties.name': 'Bomberman 64'},
#  {'nineties.name': 'Jeremy McGrath Supercross 98'},
#  {'nineties.name': 'Tomb Raider'},
#  {'nineties.name': 'Street Fighter Alpha 3'},
#  {'nineties.name': 'Final Fight 2'},
#  {'nineties.name': 'The Lost World: Jurassic Park'},
#  {'nineties.name': 'Pong: The Next Level'},
#  {'nineties.name': 'NBA Jam Tournament Edition'},
#  {'nineties.name': 'Monster Rancher'},
#  {'nineties.name': 'Breath of Fire III'},
#  {'nineties.name': 'NES Open Tournament Golf'},
#  {'nineties.name': 'Game & Watch Gallery'},
#  {'nineties.name': 'Road & Track Presents: The Need for Speed'},
#  {'nineties.name': 'NBA Live 97'},
#  {'nineties.name': "Oddworld: Abe's Exoddus"},
#  {'nineties.name': 'Tetris 2'},
#  {'nineties.name': 'NASCAR 99'},
#  {'nineties.name': 'Romancing SaGa'},
#  {'nineties.name': "Jampack Summer '99"},
#  {'nineties.name': 'Dance Dance Revolution 2nd ReMIX'},
#  {'nineties.name': 'Mortal Kombat Trilogy'},
#  {'nineties.name': 'Wild ARMs'},
#  {'nineties.name': 'NCAA Football 2000'},
#  {'nineties.name': "Midway Presents Arcade's Greatest Hits: The Atari Collection 1"},
#  {'nineties.name': 'SaGa Frontier 2'},
#  {'nineties.name': 'MLB 2000'},
#  {'nineties.name': 'Mega Man 4'},
#  {'nineties.name': 'Toy Story 2: Buzz Lightyear to the Rescue!'},
#  {'nineties.name': 'SnoCross Championship Racing'},
#  {'nineties.name': 'NHL 98'},
#  {'nineties.name': 'Space Jam'},
#  {'nineties.name': 'Knockout Kings 2000'},
#  {'nineties.name': 'Tobal No.1'},
#  {'nineties.name': 'Glover'},
#  {'nineties.name': 'Super Momotarou Dentetsu III'},
#  {'nineties.name': "Mini-Yonku Shining Scorpion: Let's & Go!!"},
#  {'nineties.name': 'Destruction Derby'},
#  {'nineties.name': '3Xtreme'},
#  {'nineties.name': 'Madden NFL 99'},
#  {'nineties.name': 'Ace Combat 2'},
#  {'nineties.name': 'Seiken Densetsu 3'},
#  {'nineties.name': "Mega Man 8 Anniversary Collector's Edition"},
#  {'nineties.name': 'Star Wars: Rebel Assault II - The Hidden Empire'},
#  {'nineties.name': 'Gex'},
#  {'nineties.name': 'Derby Stallion II'},
#  {'nineties.name': 'Need for Speed: V-Rally'},
#  {'nineties.name': "NFL GameDay '97"},
#  {'nineties.name': 'NHL 2000'},
#  {'nineties.name': 'Madden Football 64'},
#  {'nineties.name': 'MLB 99'},
#  {'nineties.name': 'Army Men: Air Attack'},
#  {'nineties.name': 'Street Fighter Alpha 2'},
#  {'nineties.name': 'Rampage World Tour'},
#  {'nineties.name': 'NFL GameDay'},
#  {'nineties.name': 'Q*bert'},
#  {'nineties.name': 'Ace Combat 3: Electrosphere'},
#  {'nineties.name': 'The Game of Life'},
#  {'nineties.name': 'Mega Man Legends'},
#  {'nineties.name': 'MediEvil'},
#  {'nineties.name': 'Casper'},
#  {'nineties.name': 'Killer Instinct Gold'},
#  {'nineties.name': 'Kamaitachi no Yoru'},
#  {'nineties.name': 'Super Bomberman 2'},
#  {'nineties.name': "Jikkyou Powerful Pro Yakyuu '99 Kaimakuban"},
#  {'nineties.name': 'Valkyrie Profile'},
#  {'nineties.name': "Army Men: Sarge's Heroes"},
#  {'nineties.name': 'EarthBound'},
#  {'nineties.name': 'The Next Tetris'},
#  {'nineties.name': "World Soccer Jikkyou Winning Eleven 3: World Cup France '98"},
#  {'nineties.name': 'Moto Racer'},
#  {'nineties.name': 'Final Fantasy Anthology'},
#  {'nineties.name': "Capcom's Soccer Shootout"},
#  {'nineties.name': 'Ridge Racer'},
#  {'nineties.name': 'Momotarou Dentetsu 7'},
#  {'nineties.name': 'WCW Mayhem'},
#  {'nineties.name': 'Mega Man 5'},
#  {'nineties.name': 'Major League Baseball Featuring Ken Griffey Jr'},
#  {'nineties.name': 'The 7th Guest'},
#  {'nineties.name': 'Doom'},
#  {'nineties.name': 'Marvel vs. Capcom: Clash of Super Heroes'},
#  {'nineties.name': 'Battle Stations'},
#  {'nineties.name': 'Torneko no Daibouken: Fushigi no Dungeon'},
#  {'nineties.name': 'NBA ShootOut 98'},
#  {'nineties.name': 'Andretti Racing'},
#  {'nineties.name': 'Need for Speed: Porsche Unleashed'},
#  {'nineties.name': 'Dragon Warrior I&II'},
#  {'nineties.name': 'Formula 1'},
#  {'nineties.name': "Street Fighter Alpha: Warriors' Dreams"},
#  {'nineties.name': 'ISS Pro Evolution'},
#  {'nineties.name': 'Final Fantasy Legend III'},
#  {'nineties.name': 'San Francisco Rush: Extreme Racing'},
#  {'nineties.name': 'Street Fighter EX Plus Alpha'},
#  {'nineties.name': 'Jet Moto 3'},
#  {'nineties.name': 'FIFA: Road to World Cup 98'},
#  {'nineties.name': 'Dragon Ball Z: Ultime Menace'},
#  {'nineties.name': 'Yoshi'},
#  {'nineties.name': 'Mortal Kombat 4'},
#  {'nineties.name': 'Croc 2'},
#  {'nineties.name': 'SD Gundam G Generation'},
#  {'nineties.name': 'Area 51'},
#  {'nineties.name': 'Test Drive 6'},
#  {'nineties.name': 'Fear Effect'},
#  {'nineties.name': 'LEGO Racers'},
#  {'nineties.name': 'WWF Attitude'},
#  {'nineties.name': 'Blast Corps'},
#  {'nineties.name': 'Tactics Ogre: Let Us Cling Together'},
#  {'nineties.name': 'Battle Arena Toshinden 2'},
#  {'nineties.name': 'Jeopardy!'},
#  {'nineties.name': 'South Park'},
#  {'nineties.name': 'Super Bomberman 3'},
#  {'nineties.name': 'Command & Conquer: Red Alert Retaliation'},
#  {'nineties.name': 'NCAA Football 98'},
#  {'nineties.name': "Chocobo's Dungeon 2"},
#  {'nineties.name': 'Fire Emblem: Monsh? no Nazo'},
#  {'nineties.name': 'Moto Racer 2'},
#  {'nineties.name': 'J-League Soccer: Prime Goal'},
#  {'nineties.name': 'NFL Xtreme'},
#  {'nineties.name': 'Star Wars: Masters of Teras Kasi'},
#  {'nineties.name': 'Mortal Kombat Mythologies: Sub-Zero'},
#  {'nineties.name': 'Bushido Blade 2'},
#  {'nineties.name': 'Suikoden II'},
#  {'nineties.name': 'Street Sk8er'},
#  {'nineties.name': 'Contra: Legacy of War'},
#  {'nineties.name': 'Spice World'},
#  {'nineties.name': 'Wild ARMs 2'},
#  {'nineties.name': 'Pro Pinball: Big Race USA'},
#  {'nineties.name': 'Tiger Woods PGA Tour 2000'},
#  {'nineties.name': 'Legend of Legaia'},
#  {'nineties.name': 'Um Jammer Lammy'},
#  {'nineties.name': 'Animaniacs Ten Pin Alley'},
#  {'nineties.name': 'World of Dragon Warrior - Torneko: The Last Hope'},
#  {'nineties.name': 'Centipede'},
#  {'nineties.name': "Tom Clancy's Rainbow Six"},
#  {'nineties.name': 'Castlevania'},
#  {'nineties.name': 'Rayman 2: The Great Escape'},
#  {'nineties.name': "Cruis'n World"},
#  {'nineties.name': 'Nightmare Creatures'},
#  {'nineties.name': 'Sim Theme Park'},
#  {'nineties.name': "A Bug's Life"},
#  {'nineties.name': 'Super Castlevania IV'},
#  {'nineties.name': 'Final Fantasy VII International'},
#  {'nineties.name': 'Nobunaga no Yabou: Haouden'},
#  {'nineties.name': 'Virtua Cop'},
#  {'nineties.name': 'WWF in Your House'},
#  {'nineties.name': "NBA ShootOut '97"},
#  {'nineties.name': 'Beetle Adventure Racing!'},
#  {'nineties.name': 'Bass Landing'},
#  {'nineties.name': "Mario's Picross"},
#  {'nineties.name': 'Fighters MEGAMiX'},
#  {'nineties.name': 'Bahamut Lagoon'},
#  {'nineties.name': 'Tomb Raider III: Adventures of Lara Croft'},
#  {'nineties.name': 'NFL Quarterback Club 99'},
#  {'nineties.name': 'Small Soldiers'},
#  {'nineties.name': 'Duke Nukem: Total Meltdown'},
#  {'nineties.name': 'Tomb Raider Chronicles'},
#  {'nineties.name': 'Madden NFL 2000'},
#  {'nineties.name': 'Suikoden'},
#  {'nineties.name': 'Puyo Puyo Sun'},
#  {'nineties.name': 'International Superstar Soccer 64'},
#  {'nineties.name': 'BeatMania Append 3rdMix'},
#  {'nineties.name': 'Xena: Warrior Princess'},
#  {'nineties.name': 'Front Mission'},
#  {'nineties.name': "Jikkyou Powerful Pro Yakyuu '97 Kaimakuban"},
#  {'nineties.name': 'CyberTiger'},
#  {'nineties.name': "Jikkyou Powerful Pro Yakyuu '98 Kaimakuban"},
#  {'nineties.name': 'Extreme-G'},
#  {'nineties.name': 'Ready 2 Rumble Boxing'},
#  {'nineties.name': 'Barbie: Race & Ride'},
#  {'nineties.name': "Kirby's Dream Course"},
#  {'nineties.name': 'Tokimeki Memorial: Forever with You'},
#  {'nineties.name': 'Diablo'},
#  {'nineties.name': 'FIFA: Road to  World Cup 98'},
#  {'nineties.name': 'World Cup 98'},
#  {'nineties.name': "International Superstar Soccer '98"},
#  {'nineties.name': 'Tales of Phantasia'},
#  {'nineties.name': 'Gex: Enter the Gecko'},
#  {'nineties.name': 'Championship Motocross featuring Ricky Carmichael'},
#  {'nineties.name': 'Dragon Ball Z: Chou Saiya Densetsu'},
#  {'nineties.name': 'Fire Emblem: Seisen no Keifu'},
#  {'nineties.name': 'Parasite Eve II'},
#  {'nineties.name': 'NFL Blitz 2000'},
#  {'nineties.name': 'Theme Park'},
#  {'nineties.name': 'Beyond The Beyond'},
#  {'nineties.name': 'NBA Hangtime'},
#  {'nineties.name': 'Super Bomberman'},
#  {'nineties.name': "Army Men: Sarge's Heroes"},
#  {'nineties.name': 'Resident Evil 2'},
#  {'nineties.name': 'Mega Man X2'},
#  {'nineties.name': 'Fatal Fury Special'},
#  {'nineties.name': 'Lunar: Silver Star Story Complete'},
#  {'nineties.name': 'NBA Showtime: NBA on NBC'},
#  {'nineties.name': 'Daytona USA'},
#  {'nineties.name': 'Shin Super Robot Taisen'},
#  {'nineties.name': 'Fighting Force 2'},
#  {'nineties.name': 'Sakura Wars'},
#  {'nineties.name': 'Star Wars: Dark Forces'},
#  {'nineties.name': 'SD Gundam G Generation Zero'},
#  {'nineties.name': 'Super Robot Taisen F'},
#  {'nineties.name': 'Super Robot Taisen F Kanketsuhen'},
#  {'nineties.name': 'Mortal Kombat 3'},
#  {'nineties.name': 'Top Gun: Fire at Will!'},
#  {'nineties.name': 'Medarot 2: Kabuto / Kuwagata Version'},
#  {'nineties.name': 'Gauntlet Legends'},
#  {'nineties.name': 'FIFA 99'},
#  {'nineties.name': 'Bust A Groove'},
#  {'nineties.name': 'Pachi-Slot Aruze Oukoku 2'},
#  {'nineties.name': 'Sakura Taisen 2 - Kimi, Shinitamou Koto Nakare'},
#  {'nineties.name': 'Clock Tower'},
#  {'nineties.name': 'Gex 3: Deep Cover Gecko'},
#  {'nineties.name': 'Jampack Vol. 2'},
#  {'nineties.name': 'Virtual Soccer'},
#  {'nineties.name': 'Romance of the Three Kingdoms IV: Wall of Fire'},
#  {'nineties.name': 'Winning Post'},
#  {'nineties.name': 'Front Mission 2'},
#  {'nineties.name': 'J-League Soccer: Prime Goal 2'},
#  {'nineties.name': 'NASCAR 2000'},
#  {'nineties.name': "Wayne Gretzky's 3D Hockey"},
#  {'nineties.name': 'Seaman'},
#  {'nineties.name': 'The Grinch'},
#  {'nineties.name': 'Mega Man 6'},
#  {'nineties.name': 'Mission: Impossible'},
#  {'nineties.name': 'Rival Schools: United By Fate'},
#  {'nineties.name': 'Front Mission 3'},
#  {'nineties.name': 'Omega Boost'},
#  {'nineties.name': 'International Track & Field'},
#  {'nineties.name': 'Virtual Pool'},
#  {'nineties.name': 'Rugrats: Scavenger Hunt'},
#  {'nineties.name': 'International Superstar Soccer 2000 (All region sales)'},
#  {'nineties.name': 'Dai-4-Ji Super Robot Taisen S'},
#  {'nineties.name': 'NHL FaceOff 98'},
#  {'nineties.name': "Bases Loaded '96: Double Header"},
#  {'nineties.name': 'RPG Maker'},
#  {'nineties.name': 'Super Famista 5'},
#  {'nineties.name': 'PoPoLoCrois Monogatari'},
#  {'nineties.name': 'Mario & Wario'},
#  {'nineties.name': 'FIFA Soccer 64'},
#  {'nineties.name': 'J-League Pro Soccer Club wo Tsukurou! 2'},
#  {'nineties.name': 'Die Hard Trilogy 2: Viva Las Vegas'},
#  {'nineties.name': 'SimCity 2000'},
#  {'nineties.name': 'Yu-Gi-Oh! Forbidden Memories (JP sales)'},
#  {'nineties.name': 'The Legend of the Mystical Ninja'},
#  {'nineties.name': 'ECW Hardcore Revolution'},
#  {'nineties.name': 'Wu-Tang: Shaolin Style'},
#  {'nineties.name': 'All-Star Baseball 99'},
#  {'nineties.name': 'Harvest Moon 64'},
#  {'nineties.name': 'Vigilante 8: 2nd Offense'},
#  {'nineties.name': 'NFL Xtreme 2'},
#  {'nineties.name': 'Alien Trilogy'},
#  {'nineties.name': 'NBA Live 99'},
#  {'nineties.name': 'Super Puyo Puyo 2'},
#  {'nineties.name': 'WipEout'},
#  {'nineties.name': 'Bomberman Hero'},
#  {'nineties.name': 'Automobili Lamborghini'},
#  {'nineties.name': 'Quest 64'},
#  {'nineties.name': 'Momotarou Dentetsu V'},
#  {'nineties.name': 'Doom 64'},
#  {'nineties.name': 'MTV Music Generator'},
#  {'nineties.name': 'Super Momotarou Dentetsu DX'},
#  {'nineties.name': 'NHL 97'},
#  {'nineties.name': 'Razor Freestyle Scooter'},
#  {'nineties.name': 'Super Batter Up'},
#  {'nineties.name': 'Crayon Shin-Chan: Arashi o Yobu Enji'},
#  {'nineties.name': 'Hydro Thunder'},
#  {'nineties.name': "NHL FaceOff '97"},
#  {'nineties.name': 'Bloody Roar II'},
#  {'nineties.name': 'Space Invaders'},
#  {'nineties.name': 'Warhawk'},
#  {'nineties.name': 'Missile Command'},
#  {'nineties.name': 'Jikkyou Powerful Pro Yakyuu 3'},
#  {'nineties.name': "J-League Excite Stage '95"},
#  {'nineties.name': 'NCAA Gamebreaker 99'},
#  {'nineties.name': 'World Stadium 2'},
#  {'nineties.name': 'Apocalypse'},
#  {'nineties.name': 'Fatal Fury 2'},
#  {'nineties.name': 'Rampage World Tour'},
#  {'nineties.name': 'Persona'},
#  {'nineties.name': 'Mobile Suit Gundam'},
#  {'nineties.name': 'Final Fantasy Collection'},
#  {'nineties.name': 'NHL FaceOff'},
#  {'nineties.name': 'Vandal Hearts'},
#  {'nineties.name': 'NBA Live 2000'},
#  {'nineties.name': 'World Stadium EX'},
#  {'nineties.name': 'Independence Day'},
#  {'nineties.name': 'Chocobo Racing'},
#  {'nineties.name': 'Blood Omen: Legacy of Kain'},
#  {'nineties.name': 'Super Bomberman 4'},
#  {'nineties.name': 'Bomberman II'},
#  {'nineties.name': 'Duke Nukem 64'},
#  {'nineties.name': 'Neon Genesis Evangelion'},
#  {'nineties.name': 'NiGHTS into dreams...'},
#  {'nineties.name': 'Wonder Project J: Kikai no Shonen Pino'},
#  {'nineties.name': 'WipEout 64'},
#  {'nineties.name': 'Mischief Makers'},
#  {'nineties.name': 'Cool Boarders'},
#  {'nineties.name': 'NHL FaceOff 99'},
#  {'nineties.name': 'Neon Genesis Evangelion 2nd Impression'},
#  {'nineties.name': 'The X Files'},
#  {'nineties.name': 'Super Wagyan Land'},
#  {'nineties.name': 'Rascal'},
#  {'nineties.name': 'Colony Wars'},
#  {'nineties.name': 'Grandia'},
#  {'nineties.name': 'JGTC: All-Japan Grand Touring Car Championship'},
#  {'nineties.name': 'Arc the Lad III'},
#  {'nineties.name': 'Rush 2: Extreme Racing USA'},
#  {'nineties.name': 'Jikkyou Powerful Pro Yakyuu 6'},
#  {'nineties.name': 'Super Famista 4'},
#  {'nineties.name': "International Superstar Soccer Pro '98"},
#  {'nineties.name': 'X-Men vs. Street Fighter'},
#  {'nineties.name': 'Cyber Troopers Virtual-On'},
#  {'nineties.name': 'Tomb Raider: The Last Revelation'},
#  {'nineties.name': 'Sega Rally Championship 2'},
#  {'nineties.name': 'Quake II'},
#  {'nineties.name': 'Grudge Warriors'},
#  {'nineties.name': 'Mobile Suit Gundam'},
#  {'nineties.name': 'E0: Enemy Zero'},
#  {'nineties.name': 'NASCAR Racing'},
#  {'nineties.name': 'Command & Conquer: Red Alert'},
#  {'nineties.name': 'Ogre Battle 64: Person of Lordly Caliber'},
#  {'nineties.name': 'Superman: The New Superman Adventures'},
#  {'nineties.name': 'Armored Core'},
#  {'nineties.name': 'Densha De Go! 2'},
#  {'nineties.name': 'Pro Pinball'},
#  {'nineties.name': "'98 Koshien"},
#  {'nineties.name': 'Mario no Super Picross'},
#  {'nineties.name': "Jikkyou Powerful Pro Yakuu '94"},
#  {'nineties.name': 'Medarot: Kabuto / Kuwagata Version'},
#  {'nineties.name': 'Pet in TV'},
#  {'nineties.name': 'NBA ShootOut 2000'},
#  {'nineties.name': 'Samurai Shodown'},
#  {'nineties.name': 'Fighting Vipers'},
#  {'nineties.name': 'NCAA GameBreaker 2000'},
#  {'nineties.name': 'RR64: Ridge Racer 64'},
#  {'nineties.name': 'Top Gear Rally'},
#  {'nineties.name': 'NFL Quarterback Club 2000'},
#  {'nineties.name': 'Mortal Kombat Mythologies: Sub-Zero'},
#  {'nineties.name': 'Bugs Bunny: Lost in Time'},
#  {'nineties.name': 'Road Rash: Jailbreak'},
#  {'nineties.name': "You Don't Know Jack"},
#  {'nineties.name': 'Mystery Dungeon: Shiren the Wanderer'},
#  {'nineties.name': 'Command & Conquer'},
#  {'nineties.name': 'Tales of Phantasia'},
#  {'nineties.name': 'NHL 99'},
#  {'nineties.name': 'Bloody Roar'},
#  {'nineties.name': 'Thrasher Presents: Skate and Destroy'},
#  {'nineties.name': 'All-Star Baseball 2000'},
#  {'nineties.name': 'Extreme-G: XG2'},
#  {'nineties.name': 'BattleTanx: Global Assault'},
#  {'nineties.name': 'Super Fire ProWrestling'},
#  {'nineties.name': 'Fatal Fury'},
#  {'nineties.name': 'Super Famista 3'},
#  {'nineties.name': 'Tokimeki Memorial 2'},
#  {'nineties.name': 'Triple Play 97'},
#  {'nineties.name': 'Super Soccer'},
#  {'nineties.name': 'Wario Land II (GBC)'},
#  {'nineties.name': 'San Francisco Rush: Extreme Racing'},
#  {'nineties.name': 'Bakusou Dekotora Densetsu: Otoko Ippiki Yume Kaidoi'},
#  {'nineties.name': 'Shin Megami Tensei: Devil Summoner'},
#  {'nineties.name': 'ESPN Extreme Games'},
#  {'nineties.name': 'Ninja: Shadow of Darkness'},
#  {'nineties.name': 'Mobile Suit Gundam version 2.0'},
#  {'nineties.name': 'Final Fantasy Adventure'},
#  {'nineties.name': 'Tokimeki Memorial: Forever with You'},
#  {'nineties.name': 'MediEvil II'},
#  {'nineties.name': 'Rogue Trip: Vacation 2012'},
#  {'nineties.name': 'Dai-4-Ji Super Robot Taisen'},
#  {'nineties.name': 'NCAA Final Four 2000'},
#  {'nineties.name': 'Tobal 2'},
#  {'nineties.name': 'Kileak: The DNA Imperative'},
#  {'nineties.name': 'Super Formation Soccer 94'},
#  {'nineties.name': 'Panzer Dragoon'},
#  {'nineties.name': 'Yarudora Series Vol.1: Double Cast'},
#  {'nineties.name': 'Turok: Rage Wars'},
#  {'nineties.name': 'Super Robot Taisen EX'},
#  {'nineties.name': 'Bottom of the 9th'},
#  {'nineties.name': 'Shin Megami Tensei II'},
#  {'nineties.name': 'Virtua Fighter 3tb'},
#  {'nineties.name': "Mini-Yonku GB: Let's & Go!!"},
#  {'nineties.name': 'Zero4 Champ RR'},
#  {'nineties.name': 'Nonomura Byoin no Hitobito'},
#  {'nineties.name': 'Super Fire ProWrestling Special'},
#  {'nineties.name': 'Yuu Yuu Hakusho'},
#  {'nineties.name': 'MechWarrior 2: 31st Century Combat'},
#  {'nineties.name': 'Mobile Suit Z-Gundam'},
#  {'nineties.name': "Kirby's Dream Land 3"},
#  {'nineties.name': 'Big Bass World Championship'},
#  {'nineties.name': 'Jurassic Park'},
#  {'nineties.name': 'Mystical Ninja starring Goemon'},
#  {'nineties.name': 'Tetrisphere'},
#  {'nineties.name': 'Breath of Fire II'},
#  {'nineties.name': 'LEGO Racers'},
#  {'nineties.name': "Boxer's Road"},
#  {'nineties.name': 'South Park Rally'},
#  {'nineties.name': 'Ganbare Goemon 3: Shishi Jyuurokubei no Karakuri Manji Katame'},
#  {'nineties.name': 'J-League Pro Soccer Club o Tsukurou!'},
#  {'nineties.name': 'Formula 1 Championship Edition'},
#  {'nineties.name': 'Blasto'},
#  {'nineties.name': 'Picross 2'},
#  {'nineties.name': 'Mega Man X3'},
#  {'nineties.name': 'Stunt Race FX'},
#  {'nineties.name': 'Rally Cross 2'},
#  {'nineties.name': 'Lunar 2: Eternal Blue Complete'},
#  {'nineties.name': "Street Fighter Alpha: Warriors' Dreams"},
#  {'nineties.name': 'Kurushi Final: Mental Blocks'},
#  {'nineties.name': 'SoulCalibur'},
#  {'nineties.name': 'WipEout 3'},
#  {'nineties.name': 'Iron Storm'},
#  {'nineties.name': 'Marvel Super Heroes'},
#  {'nineties.name': "Night Warriors: Darkstalkers' Revenge"},
#  {'nineties.name': 'Off Road Challenge'},
#  {'nineties.name': 'Backstreet Billiards'},
#  {'nineties.name': 'Point Blank'},
#  {'nineties.name': 'Tiny Tank'},
#  {'nineties.name': 'Fade to Black'},
#  {'nineties.name': 'Tokyo Highway Battle'},
#  {'nineties.name': 'Bomberman World'},
#  {'nineties.name': 'Deathtrap Dungeon'},
#  {'nineties.name': 'BeatMania Append GottaMix'},
#  {'nineties.name': 'World Stadium 3'},
#  {'nineties.name': 'Extra Bases'},
#  {'nineties.name': 'Super Power League 2'},
#  {'nineties.name': 'BattleTanx'},
#  {'nineties.name': 'Pitfall 3D: Beyond the Jungle'},
#  {'nineties.name': 'Battle Dodge Ball'},
#  {'nineties.name': 'Parodius'},
#  {'nineties.name': 'Kidou Senshi Gundam F91: Formula Senki 0122'},
#  {'nineties.name': 'DX Game of Life 2'},
#  {'nineties.name': 'NBA Live 96'},
#  {'nineties.name': 'Shin Nippon Pro Wrestling: Toukon Retsuden'},
#  {'nineties.name': 'Championship Bass'},
#  {'nineties.name': 'NHL Breakaway 98'},
#  {'nineties.name': "Bust-A-Move '99"},
#  {'nineties.name': 'OverBlood'},
#  {'nineties.name': 'ESPN X-Games Pro Boarder'},
#  {'nineties.name': 'Harvest Moon: Back to Nature'},
#  {'nineties.name': 'Nagano Winter Olympics 98'},
#  {'nineties.name': "Kirby's Block Ball"},
#  {'nineties.name': 'Rally Cross'},
#  {'nineties.name': 'Extreme Pinball'},
#  {'nineties.name': 'Street Fighter Alpha 2'},
#  {'nineties.name': 'No.1 Muscle Ranking - Kinniku Banzuke Vol. 1: Oregasaikyouno Otokoda!'},
#  {'nineties.name': 'Tetris 2 + Bombliss'},
#  {'nineties.name': 'Riven: The Sequel to Myst'},
#  {'nineties.name': 'Shin Momotarou Densetsu'},
#  {'nineties.name': 'The Conveni: Ano Machi wo Dokusen Seyo'},
#  {'nineties.name': 'Shin Super Robot Taisen Special Disk'},
#  {'nineties.name': 'Live A Live'},
#  {'nineties.name': 'Momotarou Dentetsu Happy'},
#  {'nineties.name': 'Heart of Darkness'},
#  {'nineties.name': 'Virtua Striker 2'},
#  {'nineties.name': 'WarCraft II: The Dark Saga'},
#  {'nineties.name': 'NBA ShootOut'},
#  {'nineties.name': 'Ganbare Goemon: KiraKira Douchuu - Boku ga Dancer ni Natta Riyuu'},
#  {'nineties.name': 'Mario Golf'},
#  {'nineties.name': "Sesame Street: Elmo's Letter Adventure"},
#  {'nineties.name': "Alone in the Dark: One-Eyed Jack's Revenge"},
#  {'nineties.name': 'Einhänder'},
#  {'nineties.name': 'Tiny Toon Adventures: The Great Beanstalk'},
#  {'nineties.name': 'Panzer Dragoon II Zwei'},
#  {'nineties.name': 'Super Robot Taisen Complete Box'},
#  {'nineties.name': 'Jikkyou Powerful Pro Yakyuu 4'},
#  {'nineties.name': "Goemon's Great Adventure"},
#  {'nineties.name': 'Hot Wheels Turbo Racing'},
#  {'nineties.name': 'Vigilante 8'},
#  {'nineties.name': 'Bass Hunter 64'},
#  {'nineties.name': 'Shin Megami Tensei: Devil Summoner - Soul Hackers'},
#  {'nineties.name': 'Demolition Racer'},
#  {'nineties.name': 'Final Fantasy IV'},
#  {'nineties.name': 'NHL FaceOff 2000'},
#  {'nineties.name': "South Park: Chef's Luv Shack"},
#  {'nineties.name': 'Ganbare Goemon 2: Kiteretsu Shougun Magginesu'},
#  {'nineties.name': '40 Winks'},
#  {'nineties.name': 'A Collection of Classic Games from the Intellivision'},
#  {'nineties.name': 'RPG Tsukuru 2'},
#  {'nineties.name': 'Yuu Yuu Hakusho 2: Kakutou no Sho'},
#  {'nineties.name': 'Gameboy Gallery'},
#  {'nineties.name': 'Virtua Cop 2'},
#  {'nineties.name': 'Ehrgeiz'},
#  {'nineties.name': 'Jumping Flash!'},
#  {'nineties.name': 'Blazing Heroes'},
#  {'nineties.name': 'Cart World Series'},
#  {'nineties.name': "Famista '91"},
#  {'nineties.name': 'Decathlete'},
#  {'nineties.name': 'Daikaijyuu Monogatari'},
#  {'nineties.name': 'Monster Truck Madness 64'},
#  {'nineties.name': 'Quake II'},
#  {'nineties.name': 'Macross Digital Mission VF-X'},
#  {'nineties.name': 'Super Bomberman 5'},
#  {'nineties.name': 'Dragon Force'},
#  {'nineties.name': 'Winning Post 2'},
#  {'nineties.name': 'Star Gladiator Episode: I Final Crusade'},
#  {'nineties.name': 'Far East of Eden Zero'},
#  {'nineties.name': 'Future Cop L.A.P.D.'},
#  {'nineties.name': 'Hamster Tarou'},
#  {'nineties.name': 'Guardian Heroes'},
#  {'nineties.name': "Fisherman's Bait 2: Big Ol' Bass"},
#  {'nineties.name': 'Kagero: Deception II'},
#  {'nineties.name': "J-League Victory Goal '96"},
#  {'nineties.name': 'SD Gundam G Century'},
#  {'nineties.name': 'Itadaki Street 2: Neon Sign wa Bara Iro ni'},
#  {'nineties.name': 'Viz'},
#  {'nineties.name': 'Top Gear Overdrive'},
#  {'nineties.name': 'Xena: Warrior Princess - The Talisman of Fate'},
#  {'nineties.name': 'Jeremy McGrath Supercross 2000'},
#  {'nineties.name': 'The New Tetris'},
#  {'nineties.name': "Ken Griffey Jr.'s Slugfest"},
#  {'nineties.name': 'Supercross 2000'},
#  {'nineties.name': 'War Gods'},
#  {'nineties.name': 'DX Game of Life'},
#  {'nineties.name': 'MLB Pennant Race'},
#  {'nineties.name': 'SD Gundam Gaiden: Knight Gundam Monogatari: Ooinaru Isan'},
#  {'nineties.name': 'Namco Museum Vol.2'},
#  {'nineties.name': 'Tomba! 2: The Evil Swine Return'},
#  {'nineties.name': 'BeatMania Append 4thMix: The beat goes on'},
#  {'nineties.name': 'Romance of the Three Kingdoms III: Dragon of Destiny'},
#  {'nineties.name': 'PGA Tour 97'},
#  {'nineties.name': 'VMX Racing'},
#  {'nineties.name': 'Super Fire ProWrestling X'},
#  {'nineties.name': 'International Superstar Soccer'},
#  {'nineties.name': 'Digimon Adventure: Anode Tamer'},
#  {'nineties.name': "The King of Fighters '95"},
#  {'nineties.name': 'Triple Play 2000'},
#  {'nineties.name': "Mega Man: Dr. Wily's Revenge"},
#  {'nineties.name': "Famista '92"},
#  {'nineties.name': 'Mega Man II'},
#  {'nineties.name': 'Lord of Darkness'},
#  {'nineties.name': 'Dead or Alive'},
#  {'nineties.name': 'Mega Man 7'},
#  {'nineties.name': 'NBA In The Zone'},
#  {'nineties.name': 'F1 ROC: Race of Champions'},
#  {'nineties.name': 'Kakyuusei'},
#  {'nineties.name': 'Civilization II'},
#  {'nineties.name': 'F-1 Grand Prix'},
#  {'nineties.name': 'SimCity 2000'},
#  {'nineties.name': 'Yu-Gi-Oh! Monster Capsule Breed & Battle'},
#  {'nineties.name': 'Warpath: Jurassic Park'},
#  {'nineties.name': 'Mobile Suit Gundam Side Story I: Senritsu no Blue'},
#  {'nineties.name': 'Armored Core: Project Phantasma'},
#  {'nineties.name': 'Nichibutsu Arcade Classics'},
#  {'nineties.name': 'Shin Nippon Pro Wrestling: Toukon Retsuden 2'},
#  {'nineties.name': 'Resident Evil 2: Dual Shock Edition'},
#  {'nineties.name': 'Dynasty Warriors'},
#  {'nineties.name': 'Dragon Ball GT: Final Bout'},
#  {'nineties.name': 'Gunship'},
#  {'nineties.name': 'Bishoujo Senshi Sailormoon R'},
#  {'nineties.name': 'Slam Dunk: Yonkyo Taiketsu!!'},
#  {'nineties.name': 'Fushigi no Dungeon: Fuurai no Shiren GB: Tsukikagemura no Kaibutsu'},
#  {'nineties.name': "NBA In The Zone '98"},
#  {'nineties.name': 'Jikkyou Powerful Pro Yakyuu 5'},
#  {'nineties.name': 'NBA Jam 99'},
#  {'nineties.name': 'Shadow Man'},
#  {'nineties.name': 'Command & Conquer'},
#  {'nineties.name': 'Jikkyou Powerful Pro Yakyuu 2'},
#  {'nineties.name': 'Thoroughbred Breeder II'},
#  {'nineties.name': 'Superbike 2000'},
#  {'nineties.name': 'Alundra 2: A New Legend Begins'},
#  {'nineties.name': "Jikkyou Powerful Pro Yakyuu '98 Ketteiban"},
#  {'nineties.name': 'Final Doom'},
#  {'nineties.name': 'Battle Arena Toshinden 3'},
#  {'nineties.name': 'Jade Cocoon: Story of the Tamamayu'},
#  {'nineties.name': 'Super Nazo Puyo: Ruruu no Ruu'},
#  {'nineties.name': 'Gallop Racer 2: One and Only Road to Victory'},
#  {'nineties.name': 'The House of the Dead 2'},
#  {'nineties.name': "Jikkyou Powerful Pro Yakyuu '99 Ketteiban"},
#  {'nineties.name': "King's Field II"},
#  {'nineties.name': 'NCAA Gamebreaker'},
#  {'nineties.name': 'Tomba!'},
#  {'nineties.name': 'Virtua Racing'},
#  {'nineties.name': 'Bust A Groove 2'},
#  {'nineties.name': 'Nightmare Creatures'},
#  {'nineties.name': 'Duke Nukem: Zero Hour'},
#  {'nineties.name': 'Armorines: Project S.W.A.R.M.'},
#  {'nineties.name': 'X-Men vs. Street Fighter'},
#  {'nineties.name': 'Marvel Super Heroes vs. Street Fighter'},
#  {'nineties.name': 'J-League Pro Soccer Club wo Tsukurou!'},
#  {'nineties.name': 'Choro Q3'},
#  {'nineties.name': 'Armored Core: Master of Arena'},
#  {'nineties.name': 'Fire Emblem: Thracia 776'},
#  {'nineties.name': 'Tengai Makyou: Daishi no Mokushiroku - The Apocalypse IV'},
#  {'nineties.name': 'NHL Rock the Rink'},
#  {'nineties.name': 'Doukyuusei if'},
#  {'nineties.name': 'Combination Pro Soccer: J-League no Kantoku ni Natte Sekai wo Mezase!!'},
#  {'nineties.name': 'Kidou Senshi Gundam: Giren no Yabou'},
#  {'nineties.name': 'Crusaders of Might and Magic'},
#  {'nineties.name': 'Romance of the Three Kingdoms II'},
#  {'nineties.name': 'Galactic Attack'},
#  {'nineties.name': 'Evil Zone'},
#  {'nineties.name': 'A. IV Evolution: A Ressha de Ikou 4'},
#  {'nineties.name': 'Scrabble'},
#  {'nineties.name': 'WipEout XL'},
#  {'nineties.name': 'Marie no Atelier: Salburg no Renkinjutsushi'},
#  {'nineties.name': 'Samurai Shodown II'},
#  {'nineties.name': 'Hybrid Heaven'},
#  {'nineties.name': 'NBA Showtime: NBA on NBC'},
#  {'nineties.name': "Fox Sports College Hoops '99"},
#  {'nineties.name': 'Wheel of Fortune'},
#  {'nineties.name': 'MRC: Multi-Racing Championship'},
#  {'nineties.name': 'F1 Pole Position 64'},
#  {'nineties.name': 'Gex 64: Enter the Gecko'},
#  {'nineties.name': "Wayne Gretzky's 3D Hockey '98"},
#  {'nineties.name': 'NBA Courtside 2 featuring Kobe Bryant'},
#  {'nineties.name': 'Penny Racers'},
#  {'nineties.name': 'Caesars Palace II'},
#  {'nineties.name': 'Pro Yakyuu Team o Tsukurou!'},
#  {'nineties.name': 'Sentimental Graffiti'},
#  {'nineties.name': 'NBA Jam Tournament Edition'},
#  {'nineties.name': 'Shadow Man'},
#  {'nineties.name': 'Grandia'},
#  {'nineties.name': 'Dune 2000'},
#  {'nineties.name': 'Project Overkill'},
#  {'nineties.name': 'Jumping Flash! 2'},
#  {'nineties.name': 'Choro Q2'},
#  {'nineties.name': 'Panzer General'},
#  {'nineties.name': 'Gallop Racer (JP)'},
#  {'nineties.name': 'Spawn the Eternal'},
#  {'nineties.name': 'Guitar Freaks'},
#  {'nineties.name': 'Namco Tennis Smash Court'},
#  {'nineties.name': 'K-1 Revenge'},
#  {'nineties.name': 'G-Police'},
#  {'nineties.name': 'Paperboy'},
#  {'nineties.name': "South Park: Chef's Luv Shack"},
#  {'nineties.name': 'Road Rash 64'},
#  {'nineties.name': 'Lucky Luke'},
#  {'nineties.name': 'Forsaken'},
#  {'nineties.name': 'Front Mission: Gun Hazard'},
#  {'nineties.name': 'Wild 9'},
#  {'nineties.name': 'PGA Tour 96'},
#  {'nineties.name': "Sesame Street: Elmo's Number Journey"},
#  {'nineties.name': 'Street Fighter EX2 Plus'},
#  {'nineties.name': 'Pro Yakyuu Team o Tsukurou!'},
#  {'nineties.name': 'Harvest Moon GB'},
#  {'nineties.name': 'Gundam Battle Assault'},
#  {'nineties.name': 'Virtua Fighter Kids'},
#  {'nineties.name': 'Lunar: Silver Star Story'},
#  {'nineties.name': 'Colony Wars: Vengeance'},
#  {'nineties.name': "The King of Fighters '95 (CD)"},
#  {'nineties.name': 'Perfect Weapon'},
#  {'nineties.name': 'Tetris 2 (weekly jp sales)'},
#  {'nineties.name': 'Critical Depth'},
#  {'nineties.name': 'Star Ocean'},
#  {'nineties.name': 'Alundra'},
#  {'nineties.name': 'Super R-Type'},
#  {'nineties.name': 'Rampage 2: Universal Tour'},
#  {'nineties.name': 'Super Robot Taisen F Kanketsuhen'},
#  {'nineties.name': 'The Raiden Project'},
#  {'nineties.name': 'Pocket Fighter'},
#  {'nineties.name': 'Tetris Attack'},
#  {'nineties.name': 'Shin Nippon Pro Wrestling: Toukon Retsuden 3'},
#  {'nineties.name': 'Jersey Devil'},
#  {'nineties.name': '64 de Hakken! Tamagotchi Minna de Tamagotchi World'},
#  {'nineties.name': 'Super Adventure Island'},
#  {'nineties.name': 'Bust-A-Move 4'},
#  {'nineties.name': 'NFL Quarterback Club 97'},
#  {'nineties.name': 'Barbie Super Sports'},
#  {'nineties.name': 'Chou-Kuukan Night Pro Yakyuu King(higher JP sales)'},
#  {'nineties.name': 'Rampage 2: Universal Tour'},
#  {'nineties.name': 'NBA Jam Extreme'},
#  {'nineties.name': 'NHL Championship 2000'},
#  {'nineties.name': 'Kartia: The Word of Fate'},
#  {'nineties.name': "Kirby's Star Stacker"},
#  {'nineties.name': 'Jackie Chan: Stuntmaster'},
#  {'nineties.name': 'Sports Car GT'},
#  {'nineties.name': 'Kanzen Chuuki Pro Yakyuu Greatest Nine'},
#  {'nineties.name': 'Sailor Moon'},
#  {'nineties.name': 'Pandemonium!'},
#  {'nineties.name': "Pro Yakyuu Greatest Nine '97"},
#  {'nineties.name': 'Lunar: Silver Star Story Complete'},
#  {'nineties.name': 'EVE: burst error'},
#  {'nineties.name': 'WCW Backstage Assault'},
#  {'nineties.name': 'NOëL: NOT DiGITAL'},
#  {'nineties.name': 'Dragon Ball Z Hyper Dimension'},
#  {'nineties.name': 'ClayFighter 63 1/3'},
#  {'nineties.name': 'Monopoly'},
#  {'nineties.name': 'WCW Nitro'},
#  {'nineties.name': 'Gex 3: Deep Cover Gecko'},
#  ...]

# %%
cypher = """
  MATCH (game:Game)-[:BELONGS_TO_GENRE]->(genre:Genre)
  RETURN game.name, genre.name
  """
kg.query(cypher)
# Out:
# [{'game.name': 'Wii Sports', 'genre.name': 'Sports'},
#  {'game.name': 'Wii Sports Resort', 'genre.name': 'Sports'},
#  {'game.name': 'Wii Fit', 'genre.name': 'Sports'},
#  {'game.name': 'Wii Fit Plus', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 16', 'genre.name': 'Sports'},
#  {'game.name': 'Mario & Sonic at the Olympic Games', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 14', 'genre.name': 'Sports'},
#  {'game.name': 'Zumba Fitness', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 12', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 15', 'genre.name': 'Sports'},
#  {'game.name': 'Kinect Sports', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2004', 'genre.name': 'Sports'},
#  {'game.name': 'Mario & Sonic at the Olympic Games', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 11', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater", 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 06', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 15', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 17', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater 2", 'genre.name': 'Sports'},
#  {'game.name': 'Mario & Sonic at the Olympic Winter Games',
#   'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2005', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 07', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater 3", 'genre.name': 'Sports'},
#  {'game.name': 'Winning Eleven: Pro Evolution Soccer 2007',
#   'genre.name': 'Sports'},
#  {'game.name': 'FIFA 14', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 06', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 12', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2003', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 07', 'genre.name': 'Sports'},
#  {'game.name': 'World Soccer Winning Eleven 9', 'genre.name': 'Sports'},
#  {'game.name': 'Golf', 'genre.name': 'Sports'},
#  {'game.name': 'EA Sports Active', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Underground", 'genre.name': 'Sports'},
#  {'game.name': 'Sports Champions', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K16', 'genre.name': 'Sports'},
#  {'game.name': 'World Soccer Winning Eleven 8 International',
#   'genre.name': 'Sports'},
#  {'game.name': 'Mario & Sonic at the London 2012 Olympic Games',
#   'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 2005', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater 4", 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 10', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2008', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 11', 'genre.name': 'Sports'},
#  {'game.name': 'Mario & Sonic at the Olympic Winter Games',
#   'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 2004', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 2003', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 16', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 16', 'genre.name': 'Sports'},
#  {'game.name': 'Baseball', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 08', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 15', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2002', 'genre.name': 'Sports'},
#  {'game.name': 'World Class Track Meet', 'genre.name': 'Sports'},
#  {'game.name': 'WWE SmackDown! Shut Your Mouth', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K13', 'genre.name': 'Sports'},
#  {'game.name': 'World Soccer Winning Eleven 6 International',
#   'genre.name': 'Sports'},
#  {'game.name': 'FIFA 14', 'genre.name': 'Sports'},
#  {'game.name': 'Sega Superstars Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'World Soccer Winning Eleven 7 International',
#   'genre.name': 'Sports'},
#  {'game.name': 'Hot Shots Golf 3', 'genre.name': 'Sports'},
#  {'game.name': 'Zumba Fitness 2', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 13', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 16', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 10', 'genre.name': 'Sports'},
#  {'game.name': 'Hot Shots Golf', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Street', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 12', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 11', 'genre.name': 'Sports'},
#  {'game.name': 'Skate 3', 'genre.name': 'Sports'},
#  {'game.name': 'ESPN NFL 2K5', 'genre.name': 'Sports'},
#  {'game.name': 'Mario Strikers Charged', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 10', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K12', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 09', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2005', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 08', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 13', 'genre.name': 'Sports'},
#  {'game.name': 'Deca Sports', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 09', 'genre.name': 'Sports'},
#  {'game.name': 'PES 2009: Pro Evolution Soccer', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K13', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K14', 'genre.name': 'Sports'},
#  {'game.name': 'Ice Hockey', 'genre.name': 'Sports'},
#  {'game.name': 'pro evolution soccer 2011', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 16', 'genre.name': 'Sports'},
#  {'game.name': 'Zumba Fitness', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K15', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 11', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 08', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Underground 2", 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 10', 'genre.name': 'Sports'},
#  {'game.name': 'Kinect Sports: Season Two', 'genre.name': 'Sports'},
#  {'game.name': 'My Fitness Coach', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K16', 'genre.name': 'Sports'},
#  {'game.name': 'Mario Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'Cool Boarders 3', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2010', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 09', 'genre.name': 'Sports'},
#  {'game.name': 'Cool Boarders 2', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 12', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Yakyuu Family Stadium', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 25', 'genre.name': 'Sports'},
#  {'game.name': 'Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'Your Shape featuring Jenny McCarthy', 'genre.name': 'Sports'},
#  {'game.name': 'Volleyball', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 15', 'genre.name': 'Sports'},
#  {'game.name': 'Golf', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K12', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater", 'genre.name': 'Sports'},
#  {'game.name': 'PES 2009: Pro Evolution Soccer', 'genre.name': 'Sports'},
#  {'game.name': 'Mario Sports Mix', 'genre.name': 'Sports'},
#  {'game.name': 'Derby Stallion', 'genre.name': 'Sports'},
#  {'game.name': 'Skate 3', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K14', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Jam', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 15', 'genre.name': 'Sports'},
#  {'game.name': '1080°: TenEighty Snowboarding', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2004', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 15', 'genre.name': 'Sports'},
#  {'game.name': 'Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'Hot Shots Golf: Open Tee', 'genre.name': 'Sports'},
#  {'game.name': 'Soccer', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Street Vol. 2', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 09', 'genre.name': 'Sports'},
#  {'game.name': 'Mario Super Sluggers', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 09', 'genre.name': 'Sports'},
#  {'game.name': 'Hot Shots Golf 2', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 2000', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 06', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2002', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 06', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 07', 'genre.name': 'Sports'},
#  {'game.name': 'NFL GameDay 2000', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 25', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 08', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2000', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 99', 'genre.name': 'Sports'},
#  {'game.name': 'SSX Tricky', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2005', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Big Game Hunter 2010", 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 10', 'genre.name': 'Sports'},
#  {'game.name': 'We Ski', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 07', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K15', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 16', 'genre.name': 'Sports'},
#  {'game.name': 'NFL GameDay 98', 'genre.name': 'Sports'},
#  {'game.name': 'Shaun White Snowboarding: Road Trip', 'genre.name': 'Sports'},
#  {'game.name': 'SSX 3', 'genre.name': 'Sports'},
#  {'game.name': 'Big Beach Sports', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2001', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater 3", 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 2004', 'genre.name': 'Sports'},
#  {'game.name': 'SSX', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Ballers', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2003', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 2003', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 06 (All region sales)', 'genre.name': 'Sports'},
#  {'game.name': 'ESPN NFL 2K5', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 2004', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K15', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 2005', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's American Wasteland (Old all region sales)",
#   'genre.name': 'Sports'},
#  {'game.name': 'Mario Hoops 3 on 3', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Street 2', 'genre.name': 'Sports'},
#  {'game.name': 'Baseball', 'genre.name': 'Sports'},
#  {'game.name': 'Super Mario Strikers', 'genre.name': 'Sports'},
#  {'game.name': 'ESPN NBA 2K5', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2008', 'genre.name': 'Sports'},
#  {'game.name': 'Carnival Games: Mini Golf', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2010', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 2002', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2013', 'genre.name': 'Sports'},
#  {'game.name': 'Active Life: Outdoor Challenge', 'genre.name': 'Sports'},
#  {'game.name': 'MVP Baseball 2005', 'genre.name': 'Sports'},
#  {'game.name': 'NFL GameDay 99', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 17', 'genre.name': 'Sports'},
#  {'game.name': 'Mario Golf: Toadstool Tour', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods 99 PGA Tour Golf', 'genre.name': 'Sports'},
#  {'game.name': 'The Simpsons Skateboarding', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2000', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 15', 'genre.name': 'Sports'},
#  {'game.name': 'Football Manager 2012', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 98', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Blitz', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2001', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 09', 'genre.name': 'Sports'},
#  {'game.name': 'New Play Control! Mario Power Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'Nintendo World Cup', 'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball 2K5', 'genre.name': 'Sports'},
#  {'game.name': 'Triple Play 99', 'genre.name': 'Sports'},
#  {'game.name': 'Mario Superstar Baseball', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's American Wasteland (Weekly american sales)",
#   'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 2005', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 2003', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 09 All-Play', 'genre.name': 'Sports'},
#  {'game.name': 'Triple Play 2000', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Big Game Hunter", 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 06 (Weekly american sales)', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Street', 'genre.name': 'Sports'},
#  {'game.name': "Pro Yakyuu Family Stadium '87", 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 15', 'genre.name': 'Sports'},
#  {'game.name': '2Xtreme', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2002', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Jam', 'genre.name': 'Sports'},
#  {'game.name': 'Dave Mirra Freestyle BMX 2', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K15', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 98', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 09', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 08', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 08', 'genre.name': 'Sports'},
#  {'game.name': 'MVP Baseball 2004', 'genre.name': 'Sports'},
#  {'game.name': 'Your Shape: Fitness Evolved', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K14', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater", 'genre.name': 'Sports'},
#  {'game.name': 'Triple Play 2001', 'genre.name': 'Sports'},
#  {'game.name': 'NFL 2K3', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 97', 'genre.name': 'Sports'},
#  {'game.name': "Gold's Gym: Cardio Workout", 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 07', 'genre.name': 'Sports'},
#  {'game.name': 'EA Playground', 'genre.name': 'Sports'},
#  {'game.name': 'EA Sports Active 2', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Street', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K9', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Underground", 'genre.name': 'Sports'},
#  {'game.name': "Jillian Michaels' Fitness Ultimatum 2009",
#   'genre.name': 'Sports'},
#  {'game.name': 'Rockstar Games presents Table Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'Football Manager 2011', 'genre.name': 'Sports'},
#  {'game.name': 'Championship Manager 03/04', 'genre.name': 'Sports'},
#  {'game.name': 'Brian Lara Cricket', 'genre.name': 'Sports'},
#  {'game.name': 'Winter Sports: The Ultimate Challenge',
#   'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2001', 'genre.name': 'Sports'},
#  {'game.name': 'Reel Fishing', 'genre.name': 'Sports'},
#  {'game.name': '2010 FIFA World Cup South Africa', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 17', 'genre.name': 'Sports'},
#  {'game.name': 'Mario Power Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 99', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K2', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 11', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 07', 'genre.name': 'Sports'},
#  {'game.name': 'World Soccer Winning Eleven 9 (JP & Others sales)',
#   'genre.name': 'Sports'},
#  {'game.name': 'WWE 2K16', 'genre.name': 'Sports'},
#  {'game.name': 'NFL 2K', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 2002', 'genre.name': 'Sports'},
#  {'game.name': 'WWE 2K14', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2008', 'genre.name': 'Sports'},
#  {'game.name': 'Mario & Sonic at the London 2012 Olympic Games',
#   'genre.name': 'Sports'},
#  {'game.name': 'Kobe Bryant in NBA Courtside', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 14', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K17', 'genre.name': 'Sports'},
#  {'game.name': "Pro Yakyuu Family Stadium '88", 'genre.name': 'Sports'},
#  {'game.name': 'Mario Tennis', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater 2", 'genre.name': 'Sports'},
#  {'game.name': 'Your Shape: Fitness Evolved 2012', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Dangerous Hunts", 'genre.name': 'Sports'},
#  {'game.name': 'Cool Boarders 4', 'genre.name': 'Sports'},
#  {'game.name': 'Football Manager 2013', 'genre.name': 'Sports'},
#  {'game.name': 'EA Sports Active: More Workouts', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 10', 'genre.name': 'Sports'},
#  {'game.name': 'Derby Stallion III', 'genre.name': 'Sports'},
#  {'game.name': 'Hot Shots Golf: Out of Bounds', 'genre.name': 'Sports'},
#  {'game.name': 'Derby Stallion 99', 'genre.name': 'Sports'},
#  {'game.name': 'WWE 2K15', 'genre.name': 'Sports'},
#  {'game.name': 'WWE 2K14', 'genre.name': 'Sports'},
#  {'game.name': 'Worldwide Soccer Manager 2008', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Jam Tournament Edition', 'genre.name': 'Sports'},
#  {'game.name': 'Triple Play 98', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2001', 'genre.name': 'Sports'},
#  {'game.name': 'Skate 2', 'genre.name': 'Sports'},
#  {'game.name': 'NFL 2K1', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2004', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 10', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Blitz 2000', 'genre.name': 'Sports'},
#  {'game.name': 'The Biggest Loser', 'genre.name': 'Sports'},
#  {'game.name': "Fisherman's Bass Club", 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 11', 'genre.name': 'Sports'},
#  {'game.name': 'Ready 2 Rumble Boxing', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 14', 'genre.name': 'Sports'},
#  {'game.name': 'Championship Manager 99/00', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2008', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 99', 'genre.name': 'Sports'},
#  {'game.name': 'World Tour Soccer', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 99', 'genre.name': 'Sports'},
#  {'game.name': 'Sega Superstars Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Street V3', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Blitz', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Quarterback Club 98', 'genre.name': 'Sports'},
#  {'game.name': 'Virtua Tennis 3', 'genre.name': 'Sports'},
#  {'game.name': 'Derby Stallion 96', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K3', 'genre.name': 'Sports'},
#  {'game.name': 'Dave Mirra Freestyle BMX', 'genre.name': 'Sports'},
#  {'game.name': 'MVP Baseball 2003', 'genre.name': 'Sports'},
#  {'game.name': 'EA Sports UFC', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 08', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA March Madness 2004', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 08', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 07', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Jam Tournament Edition', 'genre.name': 'Sports'},
#  {'game.name': 'Championship Manager 3', 'genre.name': 'Sports'},
#  {'game.name': 'PES 2009: Pro Evolution Soccer', 'genre.name': 'Sports'},
#  {'game.name': 'NES Open Tournament Golf', 'genre.name': 'Sports'},
#  {'game.name': 'Winning Eleven: Pro Evolution Soccer 2007 (All Region sales)',
#   'genre.name': 'Sports'},
#  {'game.name': 'NFL GameDay 2001', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 97', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Fever 2002', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 12', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 10', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2008', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 16', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 10', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 08', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 06', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K10', 'genre.name': 'Sports'},
#  {'game.name': 'Club Penguin: Game Day!', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 2004', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K16', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 2005', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 2001', 'genre.name': 'Sports'},
#  {'game.name': 'My Weight Loss Coach', 'genre.name': 'Sports'},
#  {'game.name': 'ESPN NBA 2K5', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 2000', 'genre.name': 'Sports'},
#  {'game.name': 'Tony Hawk: RIDE', 'genre.name': 'Sports'},
#  {'game.name': 'Mario Tennis Open', 'genre.name': 'Sports'},
#  {'game.name': 'MVP Baseball 2005', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 10', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 2000', 'genre.name': 'Sports'},
#  {'game.name': 'Hot Shots Golf Fore!', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 06: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 2003', 'genre.name': 'Sports'},
#  {'game.name': 'Nickelodeon Fit', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater 4", 'genre.name': 'Sports'},
#  {'game.name': 'EA Sports Grand Slam Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'SSX', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 07: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 11', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 98', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Street', 'genre.name': 'Sports'},
#  {'game.name': 'EA Sports Active 2', 'genre.name': 'Sports'},
#  {'game.name': 'Space Jam', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 12: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 15: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'AMF Bowling Pinbusters!', 'genre.name': 'Sports'},
#  {'game.name': 'Street Hoops', 'genre.name': 'Sports'},
#  {'game.name': 'Knockout Kings 2002', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 2002', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 2005', 'genre.name': 'Sports'},
#  {'game.name': 'We Ski & Snowboard', 'genre.name': 'Sports'},
#  {'game.name': 'Hot Shots Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 12: The Masters', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 99', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 09 All-Play', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2005', 'genre.name': 'Sports'},
#  {'game.name': 'Harry Potter: Quidditch World Cup', 'genre.name': 'Sports'},
#  {'game.name': 'The Biggest Loser: Ultimate Workout', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 08', 'genre.name': 'Sports'},
#  {'game.name': 'Blitz: The League', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 06', 'genre.name': 'Sports'},
#  {'game.name': 'NFL 2K2', 'genre.name': 'Sports'},
#  {'game.name': 'EA Sports UFC 2', 'genre.name': 'Sports'},
#  {'game.name': 'Wii Fit U', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 2001', 'genre.name': 'Sports'},
#  {'game.name': 'ESPN NHL 2K5', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K14', 'genre.name': 'Sports'},
#  {'game.name': 'Derby Stallion II', 'genre.name': 'Sports'},
#  {'game.name': "Gold's Gym: Dance Workout", 'genre.name': 'Sports'},
#  {'game.name': "NFL GameDay '97", 'genre.name': 'Sports'},
#  {'game.name': 'Beijing 2008', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Project 8", 'genre.name': 'Sports'},
#  {'game.name': 'NHL 2000', 'genre.name': 'Sports'},
#  {'game.name': 'Triple Play 2002', 'genre.name': 'Sports'},
#  {'game.name': 'Winning Eleven: Pro Evolution Soccer 2007',
#   'genre.name': 'Sports'},
#  {'game.name': 'Madden Football 64', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 99', 'genre.name': 'Sports'},
#  {'game.name': '2010 FIFA World Cup South Africa', 'genre.name': 'Sports'},
#  {'game.name': 'Skate 2', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 08', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 09 All-Play', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K8', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 2005', 'genre.name': 'Sports'},
#  {'game.name': 'WWE 2K15', 'genre.name': 'Sports'},
#  {'game.name': 'NFL GameDay', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 11', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K10', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 11', 'genre.name': 'Sports'},
#  {'game.name': 'Rocket Power: Team Rocket Rescue', 'genre.name': 'Sports'},
#  {'game.name': 'ESPN College Hoops 2K5', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 15', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 07', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer World Championship', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 12', 'genre.name': 'Sports'},
#  {'game.name': 'MLB SlugFest 20-03', 'genre.name': 'Sports'},
#  {'game.name': 'Deca Sports 2', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 17', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Underground 2 Remix", 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater 3", 'genre.name': 'Sports'},
#  {'game.name': 'Amped: Freestyle Snowboarding', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 16', 'genre.name': 'Sports'},
#  {'game.name': 'Shaun White Snowboarding', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 25', 'genre.name': 'Sports'},
#  {'game.name': 'EA Sports Active NFL Training Camp', 'genre.name': 'Sports'},
#  {'game.name': "Jikkyou Powerful Pro Yakyuu '99 Kaimakuban",
#   'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2010', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 10', 'genre.name': 'Sports'},
#  {'game.name': "World Soccer Jikkyou Winning Eleven 3: World Cup France '98",
#   'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 14', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2010', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K16', 'genre.name': 'Sports'},
#  {'game.name': 'All Star Cheer Squad', 'genre.name': 'Sports'},
#  {'game.name': 'PES 2009: Pro Evolution Soccer', 'genre.name': 'Sports'},
#  {'game.name': 'Mario & Sonic at the Sochi 2014 Olympic Winter Games',
#   'genre.name': 'Sports'},
#  {'game.name': "Capcom's Soccer Shootout", 'genre.name': 'Sports'},
#  {'game.name': 'pro evolution soccer 2011', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 10', 'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball Featuring Ken Griffey Jr',
#   'genre.name': 'Sports'},
#  {'game.name': 'FIFA 12', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 08', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 2004', 'genre.name': 'Sports'},
#  {'game.name': 'Personal Trainer: Walking', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2016', 'genre.name': 'Sports'},
#  {'game.name': 'UFC Personal Trainer: The Ultimate Fitness System',
#   'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K7', 'genre.name': 'Sports'},
#  {'game.name': 'NBA ShootOut 98', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 25', 'genre.name': 'Sports'},
#  {'game.name': 'All-Star Baseball 2003', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Deer Hunt: 2004 Season", 'genre.name': 'Sports'},
#  {'game.name': 'ISS Pro Evolution', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2015', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater 2", 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 11', 'genre.name': 'Sports'},
#  {'game.name': 'Deer Drive', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 15', 'genre.name': 'Sports'},
#  {'game.name': 'Rockstar Games presents Table Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 06', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Underground 2", 'genre.name': 'Sports'},
#  {'game.name': 'MVP 06 NCAA Baseball', 'genre.name': 'Sports'},
#  {'game.name': 'Sega Superstars Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 11', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 2001', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 08', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA: Road to World Cup 98', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 10', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 11', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 07', 'genre.name': 'Sports'},
#  {'game.name': "Shaun Palmer's Pro Snowboarder", 'genre.name': 'Sports'},
#  {'game.name': 'SSX', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 08', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 07', 'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball 2K7', 'genre.name': 'Sports'},
#  {'game.name': 'Skate', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 09: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 11', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2003', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 13: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'Top Spin 4', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 08', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 09', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 10: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'Football Manager 2014', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 09', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 09', 'genre.name': 'Sports'},
#  {'game.name': '2014 FIFA World Cup Brazil', 'genre.name': 'Sports'},
#  {'game.name': 'London 2012: The Official Video Game of the Olympic Games',
#   'genre.name': 'Sports'},
#  {'game.name': 'NHL 12', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Underground", 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 08', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2005', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 98', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 2001', 'genre.name': 'Sports'},
#  {'game.name': 'MotionSports', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 08: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'WWE 2K15', 'genre.name': 'Sports'},
#  {'game.name': 'J-League Soccer: Prime Goal', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Xtreme', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Street Vol. 2', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 2005', 'genre.name': 'Sports'},
#  {'game.name': 'Hot Shots Golf: Open Tee 2', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 06', 'genre.name': 'Sports'},
#  {'game.name': 'Street Sk8er', 'genre.name': 'Sports'},
#  {'game.name': 'The Biggest Loser: Challenge', 'genre.name': 'Sports'},
#  {'game.name': 'Virtua Tennis: World Tour (US & Others sales)',
#   'genre.name': 'Sports'},
#  {'game.name': 'Summer Sports: Paradise Island (Others sales)',
#   'genre.name': 'Sports'},
#  {'game.name': 'NHL 13', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Street', 'genre.name': 'Sports'},
#  {'game.name': 'Shaun White Snowboarding', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Proving Ground", 'genre.name': 'Sports'},
#  {'game.name': 'MLB 2004', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 2000', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA March Madness 2003', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 10', 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou World Soccer 2000 Final Edition',
#   'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 09', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 10', 'genre.name': 'Sports'},
#  {'game.name': 'Animaniacs Ten Pin Alley', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 13', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 09', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 14: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 10', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K17', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 06', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2001', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 08', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater 2x", 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 2003', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Project 8", 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Big Game Hunter (2008)", 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 2002', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 12: The Masters', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 2001', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's American Wasteland", 'genre.name': 'Sports'},
#  {'game.name': "NBA ShootOut '97", 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 07', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 2004', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2015', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer', 'genre.name': 'Sports'},
#  {'game.name': 'Strike Force Bowling', 'genre.name': 'Sports'},
#  {'game.name': 'Bass Landing', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Quarterback Club 99', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K9', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 16', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Fever 2003', 'genre.name': 'Sports'},
#  {'game.name': 'Tony Hawk: RIDE', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Monster Buck Hunter", 'genre.name': 'Sports'},
#  {'game.name': 'pro evolution soccer 2011', 'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball 2K8', 'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball 2K9', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2003', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2002', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2000', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Underground", 'genre.name': 'Sports'},
#  {'game.name': 'Hot Shots Golf: World Invitational', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K8', 'genre.name': 'Sports'},
#  {'game.name': 'Tony Hawk: RIDE', 'genre.name': 'Sports'},
#  {'game.name': 'International Superstar Soccer 64', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 11', 'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball 2K7', 'genre.name': 'Sports'},
#  {'game.name': 'London 2012: The Official Video Game of the Olympic Games',
#   'genre.name': 'Sports'},
#  {'game.name': 'Beijing 2008', 'genre.name': 'Sports'},
#  {'game.name': "Jikkyou Powerful Pro Yakyuu '97 Kaimakuban",
#   'genre.name': 'Sports'},
#  {'game.name': 'CyberTiger', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Blitz 2001', 'genre.name': 'Sports'},
#  {'game.name': "Jikkyou Powerful Pro Yakyuu '98 Kaimakuban",
#   'genre.name': 'Sports'},
#  {'game.name': '2002 FIFA World Cup', 'genre.name': 'Sports'},
#  {'game.name': 'MVP Baseball 2004', 'genre.name': 'Sports'},
#  {'game.name': 'Ready 2 Rumble Boxing', 'genre.name': 'Sports'},
#  {'game.name': 'Dead or Alive Xtreme Beach Volleyball',
#   'genre.name': 'Sports'},
#  {'game.name': 'NHL 12', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 06', 'genre.name': 'Sports'},
#  {'game.name': 'Skate it', 'genre.name': 'Sports'},
#  {'game.name': 'Zumba Fitness', 'genre.name': 'Sports'},
#  {'game.name': 'Backyard NBA Basketball', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 10', 'genre.name': 'Sports'},
#  {'game.name': "Kirby's Dream Course", 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Dangerous Hunts 2011", 'genre.name': 'Sports'},
#  {'game.name': 'NHL 15', 'genre.name': 'Sports'},
#  {'game.name': 'Kinect Sports Rivals', 'genre.name': 'Sports'},
#  {'game.name': 'WWE 2K16', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 09', 'genre.name': 'Sports'},
#  {'game.name': 'Sammy Sosa High Heat Baseball 2001', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA: Road to  World Cup 98', 'genre.name': 'Sports'},
#  {'game.name': 'World Cup 98', 'genre.name': 'Sports'},
#  {'game.name': "International Superstar Soccer '98", 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K7', 'genre.name': 'Sports'},
#  {'game.name': 'WWE 2K16', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater 4", 'genre.name': 'Sports'},
#  {'game.name': 'MLB 11: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 06', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 10', 'genre.name': 'Sports'},
#  {'game.name': 'Rapala: We Fish', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Blitz 2000', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2002', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 10', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater 4", 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 06', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Hangtime', 'genre.name': 'Sports'},
#  {'game.name': 'Jillian Michaels Fitness Ultimatum 2010',
#   'genre.name': 'Sports'},
#  {'game.name': 'FIFA World Cup Germany 2006', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 14', 'genre.name': 'Sports'},
#  {'game.name': 'Arena Football', 'genre.name': 'Sports'},
#  {'game.name': 'NHL Hitz 20-02', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA March Madness 07', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Project 8", 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Big Game Hunter 2005 Adventures",
#   'genre.name': 'Sports'},
#  {'game.name': 'All-Star Baseball 2002', 'genre.name': 'Sports'},
#  {'game.name': 'Backyard NFL Football', 'genre.name': 'Sports'},
#  {'game.name': 'Tony Hawk: Shred', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Proving Ground", 'genre.name': 'Sports'},
#  {'game.name': 'ESPN NFL Football', 'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball 2K5', 'genre.name': 'Sports'},
#  {'game.name': 'WWE 2K15', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 11', 'genre.name': 'Sports'},
#  {'game.name': 'Rapala Tournament Fishing!', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 07', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Showtime: NBA on NBC', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 13', 'genre.name': 'Sports'},
#  {'game.name': 'The Activision Decathlon', 'genre.name': 'Sports'},
#  {'game.name': 'Derby Stallion 04', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K8', 'genre.name': 'Sports'},
#  {'game.name': 'Barbie Horse Adventures: Riding Camp', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater 3", 'genre.name': 'Sports'},
#  {'game.name': 'Soccer Tsuku 2002: J-League Pro Soccer Club o Tsukurou!',
#   'genre.name': 'Sports'},
#  {'game.name': 'Summer Sports: Paradise Island', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 08', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 10', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 07', 'genre.name': 'Sports'},
#  {'game.name': 'Gekikuukan Pro Yakyuu: At the End of the Century 1999',
#   'genre.name': 'Sports'},
#  {'game.name': 'FIFA 99', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 14', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 13', 'genre.name': 'Sports'},
#  {'game.name': 'SSX Tricky', 'genre.name': 'Sports'},
#  {'game.name': 'World Soccer Winning Eleven 7 International (JP version)',
#   'genre.name': 'Sports'},
#  {'game.name': 'ESPN NBA Basketball', 'genre.name': 'Sports'},
#  {'game.name': "Mat Hoffman's Pro BMX", 'genre.name': 'Sports'},
#  {'game.name': 'NBA Street Vol. 2', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA March Madness 06', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA March Madness 2005', 'genre.name': 'Sports'},
#  {'game.name': 'MLB SlugFest 20-04', 'genre.name': 'Sports'},
#  {'game.name': 'Blitz: The League', 'genre.name': 'Sports'},
#  {'game.name': 'Virtual Soccer', 'genre.name': 'Sports'},
#  {'game.name': 'Winning Post', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 12', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 06', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 11', 'genre.name': 'Sports'},
#  {'game.name': 'J-League Soccer: Prime Goal 2', 'genre.name': 'Sports'},
#  {'game.name': "Wayne Gretzky's 3D Hockey", 'genre.name': 'Sports'},
#  {'game.name': 'Mario Tennis: Power Tour', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 08', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 2003', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 09', 'genre.name': 'Sports'},
#  {'game.name': 'Swing Away Golf', 'genre.name': 'Sports'},
#  {'game.name': 'J-League Pro Soccer Club o Tsukurou! 3',
#   'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 07', 'genre.name': 'Sports'},
#  {'game.name': 'SSX On Tour', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Pro Skater 3", 'genre.name': 'Sports'},
#  {'game.name': 'NFL 2K3', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2002', 'genre.name': 'Sports'},
#  {'game.name': 'Fishing Derby', 'genre.name': 'Sports'},
#  {'game.name': 'International Track & Field', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 13', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2010', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2004', 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou Powerful Pro Yakyuu 10', 'genre.name': 'Sports'},
#  {'game.name': 'Virtual Pool', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 07', 'genre.name': 'Sports'},
#  {'game.name': 'Sega Bass Fishing', 'genre.name': 'Sports'},
#  {'game.name': 'International Superstar Soccer 2000 (All region sales)',
#   'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball 2K10', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2004', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 07', 'genre.name': 'Sports'},
#  {'game.name': 'The BIGS', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Ballers', 'genre.name': 'Sports'},
#  {'game.name': 'NHL FaceOff 98', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 09', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 07', 'genre.name': 'Sports'},
#  {'game.name': 'WWE 2K16', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 07', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Street Homecourt', 'genre.name': 'Sports'},
#  {'game.name': "Bases Loaded '96: Double Header", 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 14', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 11', 'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball 2K12', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Underground 2", 'genre.name': 'Sports'},
#  {'game.name': 'Super Famista 5', 'genre.name': 'Sports'},
#  {'game.name': 'RealSports Tennis', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Project 8", 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Underground 2", 'genre.name': 'Sports'},
#  {'game.name': 'Ice Hockey', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 09', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Soccer 64', 'genre.name': 'Sports'},
#  {'game.name': 'J-League Pro Soccer Club wo Tsukurou! 2',
#   'genre.name': 'Sports'},
#  {'game.name': 'Backyard Baseball', 'genre.name': 'Sports'},
#  {'game.name': 'Barbie Horse Adventures: Wild Horse Rescue',
#   'genre.name': 'Sports'},
#  {'game.name': 'Football Manager Handheld 2009', 'genre.name': 'Sports'},
#  {'game.name': 'Bass Pro Shops: The Strike', 'genre.name': 'Sports'},
#  {'game.name': 'Active Life: Extreme Challenge', 'genre.name': 'Sports'},
#  {'game.name': 'Mario Golf: World Tour', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Street 2', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 07', 'genre.name': 'Sports'},
#  {'game.name': '2010 FIFA World Cup South Africa', 'genre.name': 'Sports'},
#  {'game.name': 'All-Star Baseball 99', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 09', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Xtreme 2', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 06', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA World Cup Germany 2006', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 99', 'genre.name': 'Sports'},
#  {'game.name': '2014 FIFA World Cup Brazil', 'genre.name': 'Sports'},
#  {'game.name': 'Virtua Tennis 4: World Tour', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Ballers: Phenom', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 07', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 16', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 12', 'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball 2K13', 'genre.name': 'Sports'},
#  {'game.name': 'World Soccer Winning Eleven 8: Liveware Evolution',
#   'genre.name': 'Sports'},
#  {'game.name': 'NHL 15', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 97', 'genre.name': 'Sports'},
#  {'game.name': 'Imagine: Figure Skater (US sales)', 'genre.name': 'Sports'},
#  {'game.name': "Mat Hoffman's Pro BMX 2", 'genre.name': 'Sports'},
#  {'game.name': 'Razor Freestyle Scooter', 'genre.name': 'Sports'},
#  {'game.name': 'Super Batter Up', 'genre.name': 'Sports'},
#  {'game.name': 'Walk it Out!', 'genre.name': 'Sports'},
#  {'game.name': "NHL FaceOff '97", 'genre.name': 'Sports'},
#  {'game.name': 'Virtua Tennis 4', 'genre.name': 'Sports'},
#  {'game.name': 'EA Sports UFC', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 12', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 07', 'genre.name': 'Sports'},
#  {'game.name': 'Top Spin', 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou Powerful Pro Yakyuu 3', 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou Powerful Pro Yakyuu 12', 'genre.name': 'Sports'},
#  {'game.name': "J-League Excite Stage '95", 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K13', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Head Coach', 'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball 2K11', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Gamebreaker 99', 'genre.name': 'Sports'},
#  {'game.name': 'World Stadium 2', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 2005', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2016', 'genre.name': 'Sports'},
#  {'game.name': 'PES 2009: Pro Evolution Soccer', 'genre.name': 'Sports'},
#  {'game.name': 'World Soccer Winning Eleven 5 Final Evolution',
#   'genre.name': 'Sports'},
#  {'game.name': 'FIFA 15', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 10', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's Proving Ground", 'genre.name': 'Sports'},
#  {'game.name': 'NHL FaceOff', 'genre.name': 'Sports'},
#  {'game.name': 'Brunswick Pro Bowling', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2005', 'genre.name': 'Sports'},
#  {'game.name': 'Mario Tennis Ultra Smash', 'genre.name': 'Sports'},
#  {'game.name': 'Celebrity Sports Showdown', 'genre.name': 'Sports'},
#  {'game.name': 'Mario Golf: Advance Tour', 'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball 2K6', 'genre.name': 'Sports'},
#  {'game.name': 'World Soccer Winning Eleven 9', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2000', 'genre.name': 'Sports'},
#  {'game.name': 'World Stadium EX', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 2003', 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou Powerful Pro Yakyuu 9', 'genre.name': 'Sports'},
#  {'game.name': 'Grind Session', 'genre.name': 'Sports'},
#  {'game.name': 'Deer Drive', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Blitz 20-03', 'genre.name': 'Sports'},
#  {'game.name': 'Remington Great American Bird Hunt', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2002', 'genre.name': 'Sports'},
#  {'game.name': 'SSX Tricky', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 14', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 2004', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Jam', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 2002', 'genre.name': 'Sports'},
#  {'game.name': '2010 FIFA World Cup South Africa', 'genre.name': 'Sports'},
#  {'game.name': 'NHL Slapshot', 'genre.name': 'Sports'},
#  {'game.name': 'EyeToy: AntiGrav', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 14', 'genre.name': 'Sports'},
#  {'game.name': 'Cool Boarders', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2003', 'genre.name': 'Sports'},
#  {'game.name': 'Backyard Baseball', 'genre.name': 'Sports'},
#  {'game.name': 'NHL FaceOff 99', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Street', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 2K6', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's American Wasteland", 'genre.name': 'Sports'},
#  {'game.name': 'Top Spin 4', 'genre.name': 'Sports'},
#  {'game.name': 'All-Star Baseball 2004', 'genre.name': 'Sports'},
#  {'game.name': 'Big Strike Bowling', 'genre.name': 'Sports'},
#  {'game.name': 'ESPN NHL 2K5', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 06', 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou Powerful Pro Yakyuu 11', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Blitz 2001', 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou Powerful Pro Yakyuu 6', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 08: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'Super Famista 4', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Legendary Adventures", 'genre.name': 'Sports'},
#  {'game.name': "International Superstar Soccer Pro '98",
#   'genre.name': 'Sports'},
#  {'game.name': 'Fishing Resort', 'genre.name': 'Sports'},
#  {'game.name': 'Football Manager Handheld 2011', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Jam', 'genre.name': 'Sports'},
#  {'game.name': 'NFL GameDay 2004', 'genre.name': 'Sports'},
#  {'game.name': 'pro evolution soccer 2011', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 10: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'Cool Boarders 2001', 'genre.name': 'Sports'},
#  {'game.name': 'World Soccer Jikkyou Winning Eleven 2000: U-23 Medal heno Chousen',
#   'genre.name': 'Sports'},
#  {'game.name': 'UEFA Euro 2008 Austria-Switzerland', 'genre.name': 'Sports'},
#  {'game.name': 'Winter Sports 2: The Next Challenge', 'genre.name': 'Sports'},
#  {'game.name': "'98 Koshien", 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K9', 'genre.name': 'Sports'},
#  {'game.name': "Jikkyou Powerful Pro Yakuu '94", 'genre.name': 'Sports'},
#  {'game.name': 'NFL GameDay 2002', 'genre.name': 'Sports'},
#  {'game.name': 'Sega Superstars Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K10', 'genre.name': 'Sports'},
#  {'game.name': 'NFL GameDay 2003', 'genre.name': 'Sports'},
#  {'game.name': 'Harry Potter: Quidditch World Cup', 'genre.name': 'Sports'},
#  {'game.name': 'NBA ShootOut 2000', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 15', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Big Game Hunter 2010", 'genre.name': 'Sports'},
#  {'game.name': 'EA Sports UFC 2', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA GameBreaker 2000', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Quarterback Club 2000', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Jam', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 2006', 'genre.name': 'Sports'},
#  {'game.name': 'Brunswick Pro Bowling', 'genre.name': 'Sports'},
#  {'game.name': 'Rapala Pro Bass Fishing 2010', 'genre.name': 'Sports'},
#  {'game.name': 'Wii Sports Club', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2002', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Jam', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 99', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K10', 'genre.name': 'Sports'},
#  {'game.name': 'Brunswick Pro Bowling', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 09', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 12', 'genre.name': 'Sports'},
#  {'game.name': 'Ener-G: Gym Rockets', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 09', 'genre.name': 'Sports'},
#  {'game.name': 'Thrasher Presents: Skate and Destroy', 'genre.name': 'Sports'},
#  {'game.name': 'EA Sports Active 2', 'genre.name': 'Sports'},
#  {'game.name': 'SSX 3', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 15: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2005', 'genre.name': 'Sports'},
#  {'game.name': 'All-Star Baseball 2000', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Dangerous Hunts 2", 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 14', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL Football', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 14: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'Super Famista 3', 'genre.name': 'Sports'},
#  {'game.name': 'Hooked! Again: Real Motion Fishing', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 08', 'genre.name': 'Sports'},
#  {'game.name': 'Harry Potter: Quidditch World Cup', 'genre.name': 'Sports'},
#  {'game.name': 'Triple Play 97', 'genre.name': 'Sports'},
#  {'game.name': 'Virtua Tennis 2009', 'genre.name': 'Sports'},
#  {'game.name': 'Super Soccer', 'genre.name': 'Sports'},
#  {'game.name': 'ESPN College Hoops 2K5', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Dangerous Hunts 2009", 'genre.name': 'Sports'},
#  {'game.name': 'Get Fit with Mel B', 'genre.name': 'Sports'},
#  {'game.name': 'NFL GameDay 2002', 'genre.name': 'Sports'},
#  {'game.name': 'Sega Superstars Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'Skate', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 08', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 15', 'genre.name': 'Sports'},
#  {'game.name': 'ESPN Extreme Games', 'genre.name': 'Sports'},
#  {'game.name': 'SSX 3', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 11', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K7', 'genre.name': 'Sports'},
#  {'game.name': 'Virtua Tennis 2009', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Big Game Hunter 2012", 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 08', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Final Four 2000', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 17', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2011 3D', 'genre.name': 'Sports'},
#  {'game.name': 'ESPN: Sports Connection', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 09', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Inside Drive 2002', 'genre.name': 'Sports'},
#  {'game.name': 'The BIGS', 'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball 2K6', 'genre.name': 'Sports'},
#  {'game.name': 'Reel Fishing III', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Deer Hunt 2005 Season", 'genre.name': 'Sports'},
#  {'game.name': 'High Heat Major League Baseball 2003', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 11', 'genre.name': 'Sports'},
#  {'game.name': 'Super Formation Soccer 94', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 12: The Masters', 'genre.name': 'Sports'},
#  {'game.name': 'Rec Room Games', 'genre.name': 'Sports'},
#  {'game.name': 'Barbie Horse Adventures: Blue Ribbon Race',
#   'genre.name': 'Sports'},
#  {'game.name': 'NFL Street 2 Unleashed', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Street 2', 'genre.name': 'Sports'},
#  {'game.name': 'Bottom of the 9th', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Football 07', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2003', 'genre.name': 'Sports'},
#  {'game.name': 'My Horse & Me', 'genre.name': 'Sports'},
#  {'game.name': 'Zero4 Champ RR', 'genre.name': 'Sports'},
#  {'game.name': 'ESPN X Games Skateboarding', 'genre.name': 'Sports'},
#  {'game.name': 'High Heat Major League Baseball 2004', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 09', 'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 14', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 2K10', 'genre.name': 'Sports'},
#  {'game.name': 'Big Bass World Championship', 'genre.name': 'Sports'},
#  {'game.name': 'NFL GameDay 2001', 'genre.name': 'Sports'},
#  {'game.name': 'North American Hunting Extravaganza', 'genre.name': 'Sports'},
#  {'game.name': "Shaun Palmer's Pro Snowboarder", 'genre.name': 'Sports'},
#  {'game.name': 'AMF Bowling World Lanes', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K12', 'genre.name': 'Sports'},
#  {'game.name': 'ESPN NFL Football', 'genre.name': 'Sports'},
#  {'game.name': 'Rapala Pro Fishing', 'genre.name': 'Sports'},
#  {'game.name': "J-League Pro Soccer Club o Tsukurou '04",
#   'genre.name': 'Sports'},
#  {'game.name': 'NHL 2K10', 'genre.name': 'Sports'},
#  {'game.name': 'Football Manager Handheld 2010', 'genre.name': 'Sports'},
#  {'game.name': 'J-League Pro Soccer Club o Tsukurou!', 'genre.name': 'Sports'},
#  {'game.name': 'Backyard Baseball 2006', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Outdoor Adventures (2006)", 'genre.name': 'Sports'},
#  {'game.name': 'Outlaw Golf 2', 'genre.name': 'Sports'},
#  {'game.name': 'Vancouver 2010 - The Official Video Game of the Olympic Winter Games',
#   'genre.name': 'Sports'},
#  {'game.name': "Cabela's Dangerous Hunts", 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou Powerful Pro Yakyuu 13', 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou Powerful Pro Yakyuu 2000', 'genre.name': 'Sports'},
#  {'game.name': 'Racquet Sports', 'genre.name': 'Sports'},
#  {'game.name': 'College Hoops 2K8', 'genre.name': 'Sports'},
#  {'game.name': 'Aggressive Inline', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Street', 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou Powerful Pro Yakyuu 7', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 06: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'UEFA Euro 2008 Austria-Switzerland', 'genre.name': 'Sports'},
#  {'game.name': 'Football Manager Handheld 2008', 'genre.name': 'Sports'},
#  {'game.name': 'MVP 06 NCAA Baseball', 'genre.name': 'Sports'},
#  {'game.name': 'Jonah Lomu Rugby Challenge', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 09', 'genre.name': 'Sports'},
#  {'game.name': 'Virtua Tennis 2009', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Basketball 10', 'genre.name': 'Sports'},
#  {'game.name': 'Rugby World Cup 2011', 'genre.name': 'Sports'},
#  {'game.name': "Kelly Slater's Pro Surfer", 'genre.name': 'Sports'},
#  {'game.name': 'World Stadium 3', 'genre.name': 'Sports'},
#  {'game.name': 'Extra Bases', 'genre.name': 'Sports'},
#  {'game.name': 'Super Power League 2', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 09', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 09: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'Cool Boarders 2001', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Street 3', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Dangerous Hunts 2011", 'genre.name': 'Sports'},
#  {'game.name': 'DECA Sports Freedom', 'genre.name': 'Sports'},
#  {'game.name': 'Battle Dodge Ball', 'genre.name': 'Sports'},
#  {'game.name': 'SSX Blur', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 08: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA GameBreaker 2001', 'genre.name': 'Sports'},
#  {'game.name': 'MVP Baseball 2005', 'genre.name': 'Sports'},
#  {'game.name': 'EA Playground', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 96', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 06', 'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball 2K6', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K10', 'genre.name': 'Sports'},
#  {'game.name': 'Championship Bass', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 13', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Basketball 10', 'genre.name': 'Sports'},
#  {'game.name': 'NHL Breakaway 98', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Street V3', 'genre.name': 'Sports'},
#  {'game.name': 'ESPN X-Games Pro Boarder', 'genre.name': 'Sports'},
#  {'game.name': "Tony Hawk's American Wasteland", 'genre.name': 'Sports'},
#  {'game.name': 'The Biggest Loser', 'genre.name': 'Sports'},
#  {'game.name': 'Nagano Winter Olympics 98', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 2001 Major League Soccer', 'genre.name': 'Sports'},
#  {'game.name': 'My Horse & Me', 'genre.name': 'Sports'},
#  {'game.name': 'Shaun White Snowboarding', 'genre.name': 'Sports'},
#  {'game.name': "Gold's Gym: Cardio Workout (Others sales)",
#   'genre.name': 'Sports'},
#  {'game.name': 'No.1 Muscle Ranking - Kinniku Banzuke Vol. 1: Oregasaikyouno Otokoda!',
#   'genre.name': 'Sports'},
#  {'game.name': "Disney's Extreme Skate Adventure", 'genre.name': 'Sports'},
#  {'game.name': 'Derby Stallion DS', 'genre.name': 'Sports'},
#  {'game.name': 'NBA 2K3', 'genre.name': 'Sports'},
#  {'game.name': 'All-Star Baseball 2005', 'genre.name': 'Sports'},
#  {'game.name': 'NFL Fever 2004', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2002', 'genre.name': 'Sports'},
#  {'game.name': 'UEFA Euro 2008 Austria-Switzerland', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Dangerous Hunts 2011", 'genre.name': 'Sports'},
#  {'game.name': 'Virtua Striker 2', 'genre.name': 'Sports'},
#  {'game.name': 'ExerBeat', 'genre.name': 'Sports'},
#  {'game.name': 'NBA ShootOut', 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou Powerful Pro Yakyuu 14', 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 2004', 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou Powerful Pro Yakyuu Portable 3',
#   'genre.name': 'Sports'},
#  {'game.name': 'NBA Inside Drive 2003', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Street', 'genre.name': 'Sports'},
#  {'game.name': 'MLB 07: The Show', 'genre.name': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2013', 'genre.name': 'Sports'},
#  {'game.name': "Cabela's Outdoor Adventures (2009)", 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou Powerful Pro Yakyuu 4', 'genre.name': 'Sports'},
#  {'game.name': 'Bass Hunter 64', 'genre.name': 'Sports'},
#  {'game.name': 'J-League Winning Eleven 2007: Club Championship',
#   'genre.name': 'Sports'},
#  {'game.name': 'Tiger Woods PGA Tour 06', 'genre.name': 'Sports'},
#  {'game.name': 'Shaun White Snowboarding', 'genre.name': 'Sports'},
#  {'game.name': 'Major League Baseball 2K8', 'genre.name': 'Sports'},
#  {'game.name': 'Rapala Pro Bass Fishing 2010', 'genre.name': 'Sports'},
#  {'game.name': 'NHL FaceOff 2000', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 08', 'genre.name': 'Sports'},
#  {'game.name': 'NCAA Final Four 2002', 'genre.name': 'Sports'},
#  {'game.name': 'Shaun White Snowboarding: World Stage',
#   'genre.name': 'Sports'},
#  {'game.name': "Famista '91", 'genre.name': 'Sports'},
#  {'game.name': 'Decathlete', 'genre.name': 'Sports'},
#  {'game.name': 'Hard Hitter Tennis', 'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 2003', 'genre.name': 'Sports'},
#  {'game.name': 'Winning Post 2', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA 15', 'genre.name': 'Sports'},
#  {'game.name': "Reel Fishing: Angler's Dream", 'genre.name': 'Sports'},
#  {'game.name': 'Power Pro Kun Pocket 6', 'genre.name': 'Sports'},
#  {'game.name': 'Power Pro Kun Pocket 10', 'genre.name': 'Sports'},
#  {'game.name': 'MLB SlugFest Loaded', 'genre.name': 'Sports'},
#  {'game.name': 'FIFA Street 3', 'genre.name': 'Sports'},
#  {'game.name': 'AMF Bowling 2004', 'genre.name': 'Sports'},
#  {'game.name': 'RealSports Boxing', 'genre.name': 'Sports'},
#  {'game.name': 'The BIGS 2', 'genre.name': 'Sports'},
#  {'game.name': 'Power Pro Kun Pocket 4', 'genre.name': 'Sports'},
#  {'game.name': 'MLB Power Pros', 'genre.name': 'Sports'},
#  {'game.name': 'Outlaw Golf', 'genre.name': 'Sports'},
#  {'game.name': "Fisherman's Bait 2: Big Ol' Bass", 'genre.name': 'Sports'},
#  {'game.name': 'NBA Street V3', 'genre.name': 'Sports'},
#  {'game.name': 'Punch-Out!!', 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou Powerful Pro Yakyuu 2000 Kaimakuban',
#   'genre.name': 'Sports'},
#  {'game.name': 'NBA Live 06', 'genre.name': 'Sports'},
#  {'game.name': "J-League Victory Goal '96", 'genre.name': 'Sports'},
#  {'game.name': 'Jikkyou Powerful Pro Yakyuu 8', 'genre.name': 'Sports'},
#  {'game.name': "Ken Griffey Jr.'s Slugfest", 'genre.name': 'Sports'},
#  {'game.name': 'Madden NFL 08', 'genre.name': 'Sports'},
#  {'game.name': 'MLB Pennant Race', 'genre.name': 'Sports'},
#  {'game.name': 'Snowboarding', 'genre.name': 'Sports'},
#  {'game.name': "Surf's Up", 'genre.name': 'Sports'},
#  {'game.name': 'Power Pro Kun Pocket 11', 'genre.name': 'Sports'},
#  {'game.name': 'Links 2004', 'genre.name': 'Sports'},
#  {'game.name': 'PGA Tour 97', 'genre.name': 'Sports'},
#  {'game.name': 'All Star Cheer Squad', 'genre.name': 'Sports'},
#  {'game.name': 'Rugby World Cup 2011', 'genre.name': 'Sports'},
#  {'game.name': 'Hot Shots Golf: World Invitational', 'genre.name': 'Sports'},
#  {'game.name': "Disney's Extreme Skate Adventure", 'genre.name': 'Sports'},
#  {'game.name': 'International Superstar Soccer', 'genre.name': 'Sports'},
#  {'game.name': 'NHL 2K11', 'genre.name': 'Sports'},
#  {'game.name': 'Street Hoops', 'genre.name': 'Sports'},
#  {'game.name': 'Tony Hawk: Shred', 'genre.name': 'Sports'},
#  {'game.name': 'Netsu Chu! Pro Yakyuu 2003', 'genre.name': 'Sports'},
#  ...]

# %%
df.head()
# Out:
#    Rank                      Name Platform    Year         Genre Publisher  \
# 0     1                Wii Sports      Wii  2006.0        Sports  Nintendo
# 1     2         Super Mario Bros.      NES  1985.0      Platform  Nintendo
# 2     3            Mario Kart Wii      Wii  2008.0        Racing  Nintendo
# 3     4         Wii Sports Resort      Wii  2009.0        Sports  Nintendo
# 4     5  Pokemon Red/Pokemon Blue       GB  1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 0     41.49     29.02      3.77         8.46         82.74
# 1     29.08      3.58      6.81         0.77         40.24
# 2     15.85     12.88      3.79         3.31         35.82
# 3     15.75     11.01      3.28         2.96         33.00
# 4     11.27      8.89     10.22         1.00         31.37

# %%
cypher = """
  MATCH (game:Game)
  RETURN game.name, game.genre
  """
kg.query(cypher)
# Out:
# [{'game.name': 'Wii Sports', 'game.genre': 'Sports'},
#  {'game.name': 'Super Mario Bros.', 'game.genre': 'Platform'},
#  {'game.name': 'Mario Kart Wii', 'game.genre': 'Racing'},
#  {'game.name': 'Wii Sports Resort', 'game.genre': 'Sports'},
#  {'game.name': 'Pokemon Red/Pokemon Blue', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Tetris', 'game.genre': 'Puzzle'},
#  {'game.name': 'New Super Mario Bros.', 'game.genre': 'Platform'},
#  {'game.name': 'Wii Play', 'game.genre': 'Misc'},
#  {'game.name': 'New Super Mario Bros. Wii', 'game.genre': 'Platform'},
#  {'game.name': 'Duck Hunt', 'game.genre': 'Shooter'},
#  {'game.name': 'Nintendogs', 'game.genre': 'Simulation'},
#  {'game.name': 'Mario Kart DS', 'game.genre': 'Racing'},
#  {'game.name': 'Pokemon Gold/Pokemon Silver', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Wii Fit', 'game.genre': 'Sports'},
#  {'game.name': 'Wii Fit Plus', 'game.genre': 'Sports'},
#  {'game.name': 'Kinect Adventures!', 'game.genre': 'Misc'},
#  {'game.name': 'Grand Theft Auto V', 'game.genre': 'Action'},
#  {'game.name': 'Grand Theft Auto: San Andreas', 'game.genre': 'Action'},
#  {'game.name': 'Super Mario World', 'game.genre': 'Platform'},
#  {'game.name': 'Brain Age: Train Your Brain in Minutes a Day',
#   'game.genre': 'Misc'},
#  {'game.name': 'Pokemon Diamond/Pokemon Pearl', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Super Mario Land', 'game.genre': 'Platform'},
#  {'game.name': 'Super Mario Bros. 3', 'game.genre': 'Platform'},
#  {'game.name': 'Grand Theft Auto V', 'game.genre': 'Action'},
#  {'game.name': 'Grand Theft Auto: Vice City', 'game.genre': 'Action'},
#  {'game.name': 'Pokemon Ruby/Pokemon Sapphire', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Pokemon Black/Pokemon White', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Brain Age 2: More Training in Minutes a Day',
#   'game.genre': 'Puzzle'},
#  {'game.name': 'Gran Turismo 3: A-Spec', 'game.genre': 'Racing'},
#  {'game.name': 'Call of Duty: Modern Warfare 3', 'game.genre': 'Shooter'},
#  {'game.name': 'Pokémon Yellow: Special Pikachu Edition',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Call of Duty: Black Ops', 'game.genre': 'Shooter'},
#  {'game.name': 'Pokemon X/Pokemon Y', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Call of Duty: Black Ops 3', 'game.genre': 'Shooter'},
#  {'game.name': 'Call of Duty: Black Ops II', 'game.genre': 'Shooter'},
#  {'game.name': 'Call of Duty: Black Ops II', 'game.genre': 'Shooter'},
#  {'game.name': 'Call of Duty: Modern Warfare 2', 'game.genre': 'Shooter'},
#  {'game.name': 'Call of Duty: Modern Warfare 3', 'game.genre': 'Shooter'},
#  {'game.name': 'Grand Theft Auto III', 'game.genre': 'Action'},
#  {'game.name': 'Super Smash Bros. Brawl', 'game.genre': 'Fighting'},
#  {'game.name': 'Call of Duty: Black Ops', 'game.genre': 'Shooter'},
#  {'game.name': 'Animal Crossing: Wild World', 'game.genre': 'Simulation'},
#  {'game.name': 'Mario Kart 7', 'game.genre': 'Racing'},
#  {'game.name': 'Halo 3', 'game.genre': 'Shooter'},
#  {'game.name': 'Grand Theft Auto V', 'game.genre': 'Action'},
#  {'game.name': 'Pokemon HeartGold/Pokemon SoulSilver', 'game.genre': 'Action'},
#  {'game.name': 'Super Mario 64', 'game.genre': 'Platform'},
#  {'game.name': 'Gran Turismo 4', 'game.genre': 'Racing'},
#  {'game.name': 'Super Mario Galaxy', 'game.genre': 'Platform'},
#  {'game.name': 'Pokemon Omega Ruby/Pokemon Alpha Sapphire',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Super Mario Land 2: 6 Golden Coins',
#   'game.genre': 'Adventure'},
#  {'game.name': 'Grand Theft Auto IV', 'game.genre': 'Action'},
#  {'game.name': 'Gran Turismo', 'game.genre': 'Racing'},
#  {'game.name': 'Super Mario 3D Land', 'game.genre': 'Platform'},
#  {'game.name': 'Gran Turismo 5', 'game.genre': 'Racing'},
#  {'game.name': 'Call of Duty: Modern Warfare 2', 'game.genre': 'Shooter'},
#  {'game.name': 'Grand Theft Auto IV', 'game.genre': 'Action'},
#  {'game.name': 'Super Mario All-Stars', 'game.genre': 'Platform'},
#  {'game.name': 'Pokemon FireRed/Pokemon LeafGreen',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Super Mario 64', 'game.genre': 'Platform'},
#  {'game.name': 'Just Dance 3', 'game.genre': 'Misc'},
#  {'game.name': 'Call of Duty: Ghosts', 'game.genre': 'Shooter'},
#  {'game.name': 'Halo: Reach', 'game.genre': 'Shooter'},
#  {'game.name': 'Mario Kart 64', 'game.genre': 'Racing'},
#  {'game.name': 'New Super Mario Bros. 2', 'game.genre': 'Platform'},
#  {'game.name': 'Halo 4', 'game.genre': 'Shooter'},
#  {'game.name': 'Final Fantasy VII', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Call of Duty: Ghosts', 'game.genre': 'Shooter'},
#  {'game.name': 'Just Dance 2', 'game.genre': 'Misc'},
#  {'game.name': 'Gran Turismo 2', 'game.genre': 'Racing'},
#  {'game.name': 'Call of Duty 4: Modern Warfare', 'game.genre': 'Shooter'},
#  {'game.name': 'Donkey Kong Country', 'game.genre': 'Platform'},
#  {'game.name': 'Minecraft', 'game.genre': 'Misc'},
#  {'game.name': 'Animal Crossing: New Leaf', 'game.genre': 'Simulation'},
#  {'game.name': 'Mario Party DS', 'game.genre': 'Misc'},
#  {'game.name': 'The Elder Scrolls V: Skyrim', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Super Mario Kart', 'game.genre': 'Racing'},
#  {'game.name': 'FIFA 16', 'game.genre': 'Sports'},
#  {'game.name': 'Wii Party', 'game.genre': 'Misc'},
#  {'game.name': 'Halo 2', 'game.genre': 'Shooter'},
#  {'game.name': 'Mario Party 8', 'game.genre': 'Misc'},
#  {'game.name': 'Pokemon Black 2/Pokemon White 2',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'FIFA Soccer 13', 'game.genre': 'Action'},
#  {'game.name': 'The Sims 3', 'game.genre': 'Simulation'},
#  {'game.name': 'GoldenEye 007', 'game.genre': 'Shooter'},
#  {'game.name': 'Mario & Sonic at the Olympic Games', 'game.genre': 'Sports'},
#  {'game.name': 'Final Fantasy X', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Final Fantasy VIII', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Pokémon Platinum Version', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Pac-Man', 'game.genre': 'Puzzle'},
#  {'game.name': 'Grand Theft Auto: Liberty City Stories',
#   'game.genre': 'Action'},
#  {'game.name': 'Super Mario Galaxy 2', 'game.genre': 'Platform'},
#  {'game.name': 'Star Wars Battlefront (2015)', 'game.genre': 'Shooter'},
#  {'game.name': 'Call of Duty: Advanced Warfare', 'game.genre': 'Shooter'},
#  {'game.name': 'The Legend of Zelda: Ocarina of Time', 'game.genre': 'Action'},
#  {'game.name': 'Crash Bandicoot 2: Cortex Strikes Back',
#   'game.genre': 'Platform'},
#  {'game.name': 'Super Mario Bros. 2', 'game.genre': 'Platform'},
#  {'game.name': 'Super Smash Bros. for Wii U and 3DS',
#   'game.genre': 'Fighting'},
#  {'game.name': 'Call of Duty: World at War', 'game.genre': 'Shooter'},
#  {'game.name': 'Battlefield 3', 'game.genre': 'Shooter'},
#  {'game.name': 'The Legend of Zelda: Twilight Princess',
#   'game.genre': 'Action'},
#  {'game.name': 'Call of Duty: Black Ops 3', 'game.genre': 'Shooter'},
#  {'game.name': 'Just Dance', 'game.genre': 'Misc'},
#  {'game.name': 'Battlefield 3', 'game.genre': 'Shooter'},
#  {'game.name': 'Need for Speed Underground', 'game.genre': 'Racing'},
#  {'game.name': 'Tekken 3', 'game.genre': 'Fighting'},
#  {'game.name': 'Crash Bandicoot 3: Warped', 'game.genre': 'Platform'},
#  {'game.name': 'Super Smash Bros. Melee', 'game.genre': 'Fighting'},
#  {'game.name': 'Mario Kart 8', 'game.genre': 'Racing'},
#  {'game.name': 'Fallout 4', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Mario Kart: Double Dash!!', 'game.genre': 'Racing'},
#  {'game.name': 'Just Dance 4', 'game.genre': 'Misc'},
#  {'game.name': 'FIFA 14', 'game.genre': 'Sports'},
#  {'game.name': 'Need for Speed Underground 2', 'game.genre': 'Racing'},
#  {'game.name': 'Medal of Honor: Frontline', 'game.genre': 'Shooter'},
#  {'game.name': "Uncharted 3: Drake's Deception", 'game.genre': 'Action'},
#  {'game.name': 'Crash Bandicoot', 'game.genre': 'Platform'},
#  {'game.name': 'Zumba Fitness', 'game.genre': 'Sports'},
#  {'game.name': 'Gears of War 2', 'game.genre': 'Shooter'},
#  {'game.name': 'Uncharted 2: Among Thieves', 'game.genre': 'Action'},
#  {'game.name': 'Call of Duty 4: Modern Warfare', 'game.genre': 'Shooter'},
#  {'game.name': 'FIFA 12', 'game.genre': 'Sports'},
#  {'game.name': 'Big Brain Academy', 'game.genre': 'Misc'},
#  {'game.name': 'Red Dead Redemption', 'game.genre': 'Action'},
#  {'game.name': 'FIFA 15', 'game.genre': 'Sports'},
#  {'game.name': 'Donkey Kong Country Returns', 'game.genre': 'Platform'},
#  {'game.name': 'The Elder Scrolls V: Skyrim', 'game.genre': 'Role-Playing'},
#  {'game.name': 'The Legend of Zelda', 'game.genre': 'Action'},
#  {'game.name': "Assassin's Creed III", 'game.genre': 'Action'},
#  {'game.name': 'Halo: Combat Evolved', 'game.genre': 'Shooter'},
#  {'game.name': 'Pokémon Emerald Version', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Kingdom Hearts', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Pokémon Crystal Version', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Halo 3: ODST', 'game.genre': 'Shooter'},
#  {'game.name': 'Red Dead Redemption', 'game.genre': 'Action'},
#  {'game.name': 'Super Mario Sunshine', 'game.genre': 'Platform'},
#  {'game.name': 'Street Fighter II: The World Warrior',
#   'game.genre': 'Fighting'},
#  {'game.name': 'World of Warcraft', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Driver', 'game.genre': 'Action'},
#  {'game.name': 'Kinect Sports', 'game.genre': 'Sports'},
#  {'game.name': 'Gears of War 3', 'game.genre': 'Shooter'},
#  {'game.name': 'Gears of War', 'game.genre': 'Shooter'},
#  {'game.name': 'Metal Gear Solid 2: Sons of Liberty', 'game.genre': 'Action'},
#  {'game.name': 'Sonic the Hedgehog 2', 'game.genre': 'Platform'},
#  {'game.name': 'Metal Gear Solid 4: Guns of the Patriots',
#   'game.genre': 'Action'},
#  {'game.name': 'Metal Gear Solid', 'game.genre': 'Action'},
#  {'game.name': 'The Last of Us', 'game.genre': 'Action'},
#  {'game.name': 'Final Fantasy XII', 'game.genre': 'Role-Playing'},
#  {'game.name': 'LittleBigPlanet', 'game.genre': 'Platform'},
#  {'game.name': 'Dragon Quest IX: Sentinels of the Starry Skies',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'LEGO Star Wars: The Complete Saga', 'game.genre': 'Action'},
#  {'game.name': 'Resident Evil 2', 'game.genre': 'Action'},
#  {'game.name': 'Tekken 2', 'game.genre': 'Fighting'},
#  {'game.name': 'Cooking Mama', 'game.genre': 'Simulation'},
#  {'game.name': 'Destiny', 'game.genre': 'Shooter'},
#  {'game.name': 'Tetris', 'game.genre': 'Puzzle'},
#  {'game.name': "Assassin's Creed II", 'game.genre': 'Action'},
#  {'game.name': 'Super Smash Bros.', 'game.genre': 'Fighting'},
#  {'game.name': "Assassin's Creed", 'game.genre': 'Adventure'},
#  {'game.name': 'Batman: Arkham City', 'game.genre': 'Action'},
#  {'game.name': 'Forza Motorsport 3', 'game.genre': 'Racing'},
#  {'game.name': 'Monster Hunter Freedom Unite', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Super Mario Advance', 'game.genre': 'Platform'},
#  {'game.name': 'Mario Kart: Super Circuit', 'game.genre': 'Racing'},
#  {'game.name': 'Super Mario World', 'game.genre': 'Platform'},
#  {'game.name': 'Pokemon Stadium', 'game.genre': 'Strategy'},
#  {'game.name': 'Call of Duty: World at War', 'game.genre': 'Shooter'},
#  {'game.name': 'Crash Bandicoot: The Wrath of Cortex',
#   'game.genre': 'Platform'},
#  {'game.name': 'Minecraft', 'game.genre': 'Misc'},
#  {'game.name': 'Final Fantasy XIII', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Dr. Mario', 'game.genre': 'Puzzle'},
#  {'game.name': 'Pokemon Pinball', 'game.genre': 'Misc'},
#  {'game.name': "Assassin's Creed III", 'game.genre': 'Action'},
#  {'game.name': 'Final Fantasy IX', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Final Fantasy X-2', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Donkey Kong 64', 'game.genre': 'Platform'},
#  {'game.name': "Assassin's Creed II", 'game.genre': 'Action'},
#  {'game.name': 'Professor Layton and the Curious Village',
#   'game.genre': 'Puzzle'},
#  {'game.name': 'Tomb Raider II', 'game.genre': 'Action'},
#  {'game.name': 'Madden NFL 2004', 'game.genre': 'Sports'},
#  {'game.name': 'Dragon Quest VIII: Journey of the Cursed King',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Diablo III', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Super Mario Bros. 3', 'game.genre': 'Platform'},
#  {'game.name': 'New Super Mario Bros. U', 'game.genre': 'Platform'},
#  {'game.name': 'Super Mario Land 3: Wario Land', 'game.genre': 'Platform'},
#  {'game.name': 'FIFA Soccer 13', 'game.genre': 'Action'},
#  {'game.name': 'The Legend of Zelda: Phantom Hourglass',
#   'game.genre': 'Action'},
#  {'game.name': "Donkey Kong Country 2: Diddy's Kong Quest",
#   'game.genre': 'Platform'},
#  {'game.name': 'Tomodachi Life', 'game.genre': 'Simulation'},
#  {'game.name': 'Mario & Sonic at the Olympic Games', 'game.genre': 'Sports'},
#  {'game.name': 'Medal of Honor: Rising Sun', 'game.genre': 'Shooter'},
#  {'game.name': "Kirby's Dream Land", 'game.genre': 'Platform'},
#  {'game.name': 'Fable III', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Call of Duty: Advanced Warfare', 'game.genre': 'Shooter'},
#  {'game.name': 'Microsoft Flight Simulator', 'game.genre': 'Simulation'},
#  {'game.name': 'Guitar Hero II', 'game.genre': 'Misc'},
#  {'game.name': 'Resident Evil 5', 'game.genre': 'Action'},
#  {'game.name': 'Grand Theft Auto V', 'game.genre': 'Action'},
#  {'game.name': 'Grand Theft Auto: Vice City Stories', 'game.genre': 'Action'},
#  {'game.name': 'FIFA Soccer 11', 'game.genre': 'Sports'},
#  {'game.name': 'Super Mario Bros.', 'game.genre': 'Platform'},
#  {'game.name': 'Resident Evil', 'game.genre': 'Action'},
#  {'game.name': "Tony Hawk's Pro Skater", 'game.genre': 'Sports'},
#  {'game.name': 'Super Smash Bros. for Wii U and 3DS',
#   'game.genre': 'Fighting'},
#  {'game.name': 'Warzone 2100', 'game.genre': 'Strategy'},
#  {'game.name': 'Spyro the Dragon', 'game.genre': 'Platform'},
#  {'game.name': "Link's Crossbow Training", 'game.genre': 'Shooter'},
#  {'game.name': 'Guitar Hero III: Legends of Rock', 'game.genre': 'Misc'},
#  {'game.name': 'Fallout 3', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Pokemon Mystery Dungeon: Explorers of Time/Explorers of Darkness',
#   'game.genre': 'Role-Playing'},
#  {'game.name': "Uncharted: Drake's Fortune", 'game.genre': 'Action'},
#  {'game.name': 'Madden NFL 06', 'game.genre': 'Sports'},
#  {'game.name': 'LEGO Star Wars: The Complete Saga', 'game.genre': 'Action'},
#  {'game.name': 'Diddy Kong Racing', 'game.genre': 'Racing'},
#  {'game.name': 'Monster Hunter Freedom 3', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Dr. Mario', 'game.genre': 'Puzzle'},
#  {'game.name': 'God of War III', 'game.genre': 'Action'},
#  {'game.name': 'StarCraft II: Wings of Liberty', 'game.genre': 'Strategy'},
#  {'game.name': "Assassin's Creed", 'game.genre': 'Adventure'},
#  {'game.name': 'FIFA 15', 'game.genre': 'Sports'},
#  {'game.name': 'Crash Team Racing', 'game.genre': 'Racing'},
#  {'game.name': 'FIFA 17', 'game.genre': 'Sports'},
#  {'game.name': 'Batman: Arkham City', 'game.genre': 'Action'},
#  {'game.name': 'Driver 2', 'game.genre': 'Action'},
#  {'game.name': 'The Simpsons: Hit & Run', 'game.genre': 'Racing'},
#  {'game.name': "Tony Hawk's Pro Skater 2", 'game.genre': 'Sports'},
#  {'game.name': 'Animal Crossing: City Folk', 'game.genre': 'Simulation'},
#  {'game.name': 'The Lord of the Rings: The Two Towers',
#   'game.genre': 'Action'},
#  {'game.name': 'Forza Motorsport 4', 'game.genre': 'Racing'},
#  {'game.name': 'Tomb Raider', 'game.genre': 'Action'},
#  {'game.name': 'Guitar Hero III: Legends of Rock', 'game.genre': 'Misc'},
#  {'game.name': 'The Legend of Zelda: A Link to the Past',
#   'game.genre': 'Action'},
#  {'game.name': 'The Legend of Zelda: The Wind Waker', 'game.genre': 'Action'},
#  {'game.name': 'Mario & Sonic at the Olympic Winter Games',
#   'game.genre': 'Sports'},
#  {'game.name': "Luigi's Mansion: Dark Moon", 'game.genre': 'Action'},
#  {'game.name': 'Splatoon', 'game.genre': 'Shooter'},
#  {'game.name': 'The Last of Us', 'game.genre': 'Action'},
#  {'game.name': 'Guitar Hero III: Legends of Rock', 'game.genre': 'Misc'},
#  {'game.name': 'Madden NFL 2005', 'game.genre': 'Sports'},
#  {'game.name': 'Pitfall!', 'game.genre': 'Platform'},
#  {'game.name': 'Madden NFL 07', 'game.genre': 'Sports'},
#  {'game.name': 'Spider-Man: The Movie', 'game.genre': 'Action'},
#  {'game.name': 'Dragon Quest VII: Warriors of Eden',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Uncharted: The Nathan Drake Collection',
#   'game.genre': 'Action'},
#  {'game.name': 'Call of Duty: Advanced Warfare', 'game.genre': 'Shooter'},
#  {'game.name': 'God of War', 'game.genre': 'Action'},
#  {'game.name': 'Nintendo Land', 'game.genre': 'Misc'},
#  {'game.name': 'Michael Jackson: The Experience', 'game.genre': 'Misc'},
#  {'game.name': "Tony Hawk's Pro Skater 3", 'game.genre': 'Sports'},
#  {'game.name': 'Winning Eleven: Pro Evolution Soccer 2007',
#   'game.genre': 'Sports'},
#  {'game.name': 'The Elder Scrolls IV: Oblivion', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Zelda II: The Adventure of Link', 'game.genre': 'Adventure'},
#  {'game.name': 'Need for Speed: Most Wanted', 'game.genre': 'Racing'},
#  {'game.name': 'Resistance: Fall of Man', 'game.genre': 'Shooter'},
#  {'game.name': 'Sonic the Hedgehog', 'game.genre': 'Platform'},
#  {'game.name': 'Kingdom Hearts II', 'game.genre': 'Role-Playing'},
#  {'game.name': 'FIFA 14', 'game.genre': 'Sports'},
#  {'game.name': 'Call of Duty: Advanced Warfare', 'game.genre': 'Shooter'},
#  {'game.name': 'Asteroids', 'game.genre': 'Shooter'},
#  {'game.name': 'Fable II', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Halo 5: Guardians', 'game.genre': 'Shooter'},
#  {'game.name': 'Super Mario 3D World', 'game.genre': 'Platform'},
#  {'game.name': 'Batman: Arkham Asylum', 'game.genre': 'Action'},
#  {'game.name': "Assassin's Creed: Revelations", 'game.genre': 'Action'},
#  {'game.name': 'Namco Museum', 'game.genre': 'Misc'},
#  {'game.name': 'Metal Gear Solid 3: Snake Eater', 'game.genre': 'Action'},
#  {'game.name': 'Daxter', 'game.genre': 'Platform'},
#  {'game.name': 'Warcraft II: Tides of Darkness', 'game.genre': 'Strategy'},
#  {'game.name': 'The Legend of Zelda: Ocarina of Time', 'game.genre': 'Action'},
#  {'game.name': 'FIFA Soccer 06', 'game.genre': 'Sports'},
#  {'game.name': 'EyeToy Play', 'game.genre': 'Misc'},
#  {'game.name': "Uncharted 4: A Thief's End", 'game.genre': 'Shooter'},
#  {'game.name': 'Gran Turismo 5 Prologue', 'game.genre': 'Racing'},
#  {'game.name': "Assassin's Creed: Revelations", 'game.genre': 'Action'},
#  {'game.name': 'Street Fighter IV', 'game.genre': 'Fighting'},
#  {'game.name': 'FIFA 12', 'game.genre': 'Sports'},
#  {'game.name': 'Teenage Mutant Ninja Turtles', 'game.genre': 'Action'},
#  {'game.name': 'Excitebike', 'game.genre': 'Racing'},
#  {'game.name': 'Frogger', 'game.genre': 'Action'},
#  {'game.name': 'Madden NFL 2003', 'game.genre': 'Sports'},
#  {'game.name': 'Watch Dogs', 'game.genre': 'Action'},
#  {'game.name': 'Half-Life', 'game.genre': 'Shooter'},
#  {'game.name': "Super Mario World 2: Yoshi's Island",
#   'game.genre': 'Platform'},
#  {'game.name': 'FIFA Soccer 07', 'game.genre': 'Sports'},
#  {'game.name': 'The Legend of Zelda: Skyward Sword', 'game.genre': 'Action'},
#  {'game.name': 'Street Fighter II Turbo', 'game.genre': 'Fighting'},
#  {'game.name': 'Carnival Games', 'game.genre': 'Misc'},
#  {'game.name': 'Fallout 4', 'game.genre': 'Role-Playing'},
#  {'game.name': 'World of Warcraft: The Burning Crusade',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Fallout: New Vegas', 'game.genre': 'Role-Playing'},
#  {'game.name': 'God of War II', 'game.genre': 'Action'},
#  {'game.name': 'Forza Motorsport 2', 'game.genre': 'Racing'},
#  {'game.name': 'World Soccer Winning Eleven 9', 'game.genre': 'Sports'},
#  {'game.name': 'Namco Museum Vol.3', 'game.genre': 'Misc'},
#  {'game.name': 'Tekken Tag Tournament', 'game.genre': 'Fighting'},
#  {'game.name': 'Far Cry 4', 'game.genre': 'Shooter'},
#  {'game.name': 'Star Fox 64', 'game.genre': 'Shooter'},
#  {'game.name': 'Minecraft', 'game.genre': 'Misc'},
#  {'game.name': 'Golf', 'game.genre': 'Sports'},
#  {'game.name': 'Fallout 3', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Professor Layton and the Diabolical Box',
#   'game.genre': 'Puzzle'},
#  {'game.name': 'Left 4 Dead 2', 'game.genre': 'Shooter'},
#  {'game.name': 'Namco Museum: 50th Anniversary', 'game.genre': 'Misc'},
#  {'game.name': 'EA Sports Active', 'game.genre': 'Sports'},
#  {'game.name': "Assassin's Creed: Unity", 'game.genre': 'Action'},
#  {'game.name': 'Donkey Kong Land', 'game.genre': 'Platform'},
#  {'game.name': "Tony Hawk's Underground", 'game.genre': 'Sports'},
#  {'game.name': "Assassin's Creed IV: Black Flag", 'game.genre': 'Action'},
#  {'game.name': 'Monster Hunter 4 Ultimate', 'game.genre': 'Role-Playing'},
#  {'game.name': 'MotorStorm', 'game.genre': 'Racing'},
#  {'game.name': 'The Elder Scrolls V: Skyrim', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Tekken 5', 'game.genre': 'Fighting'},
#  {'game.name': 'Dragon Warrior III', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Sports Champions', 'game.genre': 'Sports'},
#  {'game.name': 'NBA 2K16', 'game.genre': 'Sports'},
#  {'game.name': 'World Soccer Winning Eleven 8 International',
#   'game.genre': 'Sports'},
#  {'game.name': 'Flash Focus: Vision Training in Minutes a Day',
#   'game.genre': 'Misc'},
#  {'game.name': 'Namco Museum Vol.1', 'game.genre': 'Misc'},
#  {'game.name': "The Legend of Zelda: Link's Awakening",
#   'game.genre': 'Action'},
#  {'game.name': "Mario & Luigi: Bowser's Inside Story",
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Big Brain Academy: Wii Degree', 'game.genre': 'Misc'},
#  {'game.name': 'Nintendogs + cats', 'game.genre': 'Simulation'},
#  {'game.name': 'Batman: Arkham Knight', 'game.genre': 'Action'},
#  {'game.name': 'Mario & Sonic at the London 2012 Olympic Games',
#   'game.genre': 'Sports'},
#  {'game.name': 'LEGO Indiana Jones: The Original Adventures',
#   'game.genre': 'Action'},
#  {'game.name': "Resident Evil Director's Cut", 'game.genre': 'Action'},
#  {'game.name': 'Ratchet & Clank: Size Matters', 'game.genre': 'Platform'},
#  {'game.name': 'Just Dance 2014', 'game.genre': 'Misc'},
#  {'game.name': 'The Sims: Unleashed', 'game.genre': 'Simulation'},
#  {'game.name': 'Super Paper Mario', 'game.genre': 'Platform'},
#  {'game.name': "Harry Potter and the Sorcerer's Stone",
#   'game.genre': 'Action'},
#  {'game.name': 'The Witcher 3: Wild Hunt', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Resident Evil 3: Nemesis', 'game.genre': 'Action'},
#  {'game.name': 'Spyro: Year of the Dragon', 'game.genre': 'Platform'},
#  {'game.name': 'FIFA Soccer 2005', 'game.genre': 'Sports'},
#  {'game.name': 'Pokémon Trading Card Game', 'game.genre': 'Strategy'},
#  {'game.name': 'Battlefield 4', 'game.genre': 'Shooter'},
#  {'game.name': 'MySims', 'game.genre': 'Simulation'},
#  {'game.name': 'Friend Collection', 'game.genre': 'Misc'},
#  {'game.name': "Tony Hawk's Pro Skater 4", 'game.genre': 'Sports'},
#  {'game.name': 'Midnight Club 3: DUB Edition', 'game.genre': 'Racing'},
#  {'game.name': 'Banjo-Kazooie', 'game.genre': 'Platform'},
#  {'game.name': 'SOCOM: U.S. Navy SEALs', 'game.genre': 'Shooter'},
#  {'game.name': 'Guitar Hero: World Tour', 'game.genre': 'Misc'},
#  {'game.name': 'Gran Turismo 6', 'game.genre': 'Racing'},
#  {'game.name': 'Jak and Daxter: The Precursor Legacy',
#   'game.genre': 'Platform'},
#  {'game.name': 'Pokemon Snap', 'game.genre': 'Simulation'},
#  {'game.name': 'FIFA Soccer 10', 'game.genre': 'Sports'},
#  {'game.name': 'Pro Evolution Soccer 2008', 'game.genre': 'Sports'},
#  {'game.name': 'Call of Duty: Ghosts', 'game.genre': 'Shooter'},
#  {'game.name': 'Resident Evil 4', 'game.genre': 'Action'},
#  {'game.name': "Tom Clancy's The Division", 'game.genre': 'Shooter'},
#  {'game.name': 'Star Wars: Battlefront', 'game.genre': 'Shooter'},
#  {'game.name': 'Doom II: Hell on Earth', 'game.genre': 'Shooter'},
#  {'game.name': 'The Simpsons: Road Rage', 'game.genre': 'Racing'},
#  {'game.name': 'Cooking Mama 2: Dinner With Friends',
#   'game.genre': 'Simulation'},
#  {'game.name': "Luigi's Mansion", 'game.genre': 'Action'},
#  {'game.name': 'Star Wars: Battlefront II', 'game.genre': 'Shooter'},
#  {'game.name': 'WWF SmackDown!', 'game.genre': 'Fighting'},
#  {'game.name': 'Croc: Legend of the Gobbos', 'game.genre': 'Platform'},
#  {'game.name': 'Grand Theft Auto: Liberty City Stories',
#   'game.genre': 'Action'},
#  {'game.name': 'The Getaway', 'game.genre': 'Action'},
#  {'game.name': 'Tomb Raider III: Adventures of Lara Croft',
#   'game.genre': 'Action'},
#  {'game.name': 'James Bond 007: Agent Under Fire', 'game.genre': 'Shooter'},
#  {'game.name': 'LEGO Star Wars: The Video Game', 'game.genre': 'Action'},
#  {'game.name': 'Battlefield 4', 'game.genre': 'Shooter'},
#  {'game.name': 'FIFA Soccer 11', 'game.genre': 'Sports'},
#  {'game.name': 'Rugrats in Paris: The Movie', 'game.genre': 'Action'},
#  {'game.name': "Spyro 2: Ripto's Rage!", 'game.genre': 'Platform'},
#  {'game.name': 'Left 4 Dead', 'game.genre': 'Shooter'},
#  {'game.name': 'Mario & Sonic at the Olympic Winter Games',
#   'game.genre': 'Sports'},
#  {'game.name': 'Resident Evil 5', 'game.genre': 'Action'},
#  {'game.name': "Donkey Kong Country 3: Dixie Kong's Double Trouble!",
#   'game.genre': 'Platform'},
#  {'game.name': "Assassin's Creed: Brotherhood", 'game.genre': 'Action'},
#  {'game.name': 'Kung Fu', 'game.genre': 'Action'},
#  {'game.name': 'Batman: Arkham Asylum', 'game.genre': 'Action'},
#  {'game.name': 'Clubhouse Games', 'game.genre': 'Misc'},
#  {'game.name': 'FIFA Soccer 2004', 'game.genre': 'Sports'},
#  {'game.name': 'Star Wars Battlefront (2015)', 'game.genre': 'Shooter'},
#  {'game.name': 'Battlefield: Bad Company 2', 'game.genre': 'Shooter'},
#  {'game.name': 'Guitar Hero: On Tour', 'game.genre': 'Misc'},
#  {'game.name': "Assassin's Creed: Unity", 'game.genre': 'Action'},
#  {'game.name': 'Far Cry 3', 'game.genre': 'Shooter'},
#  {'game.name': 'Monster Hunter 4', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Borderlands', 'game.genre': 'Shooter'},
#  {'game.name': 'Tekken 4', 'game.genre': 'Fighting'},
#  {'game.name': 'Battlefield 4', 'game.genre': 'Shooter'},
#  {'game.name': 'LittleBigPlanet 2', 'game.genre': 'Platform'},
#  {'game.name': 'Grand Theft Auto 2', 'game.genre': 'Action'},
#  {'game.name': 'Final Fantasy III', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Spider-Man 2', 'game.genre': 'Action'},
#  {'game.name': 'F-1 Race', 'game.genre': 'Racing'},
#  {'game.name': 'FIFA Soccer 2003', 'game.genre': 'Sports'},
#  {'game.name': 'Crash Bash', 'game.genre': 'Misc'},
#  {'game.name': 'LEGO Batman: The Videogame', 'game.genre': 'Action'},
#  {'game.name': 'Metal Gear Solid V: The Phantom Pain', 'game.genre': 'Action'},
#  {'game.name': 'The Legend of Zelda: Spirit Tracks', 'game.genre': 'Action'},
#  {'game.name': 'WWF War Zone', 'game.genre': 'Fighting'},
#  {'game.name': "The Legend of Zelda: Majora's Mask", 'game.genre': 'Action'},
#  {'game.name': 'Professor Layton and the Unwound Future',
#   'game.genre': 'Puzzle'},
#  {'game.name': 'Rugrats: Search For Reptar', 'game.genre': 'Adventure'},
#  {'game.name': "Assassin's Creed IV: Black Flag", 'game.genre': 'Action'},
#  {'game.name': 'English Training: Have Fun Improving Your Skills!',
#   'game.genre': 'Misc'},
#  {'game.name': 'James Bond 007: Nightfire', 'game.genre': 'Shooter'},
#  {'game.name': 'Ratchet & Clank', 'game.genre': 'Platform'},
#  {'game.name': 'Mario Party 9', 'game.genre': 'Misc'},
#  {'game.name': 'Star Wars Episode III: Revenge of the Sith',
#   'game.genre': 'Action'},
#  {'game.name': 'Max Payne', 'game.genre': 'Shooter'},
#  {'game.name': 'The Lord of the Rings: The Return of the King',
#   'game.genre': 'Action'},
#  {'game.name': "Assassin's Creed Syndicate", 'game.genre': 'Action'},
#  {'game.name': 'Destiny', 'game.genre': 'Shooter'},
#  {'game.name': 'True Crime: Streets of LA', 'game.genre': 'Action'},
#  {'game.name': 'Wii Music', 'game.genre': 'Misc'},
#  {'game.name': 'Gran Turismo (PSP)', 'game.genre': 'Racing'},
#  {'game.name': 'Monster Hunter X', 'game.genre': 'Action'},
#  {'game.name': 'Tekken', 'game.genre': 'Fighting'},
#  {'game.name': 'FIFA 16', 'game.genre': 'Sports'},
#  {'game.name': 'L.A. Noire', 'game.genre': 'Adventure'},
#  {'game.name': 'Madden NFL 16', 'game.genre': 'Sports'},
#  {'game.name': 'Yokai Watch 2 Ganso/Honke', 'game.genre': 'Role-Playing'},
#  {'game.name': '007: Tomorrow Never Dies', 'game.genre': 'Shooter'},
#  {'game.name': 'Baseball', 'game.genre': 'Sports'},
#  {'game.name': 'Killer Instinct', 'game.genre': 'Fighting'},
#  {'game.name': 'WWF SmackDown! 2: Know Your Role', 'game.genre': 'Fighting'},
#  {'game.name': 'Crisis Core: Final Fantasy VII', 'game.genre': 'Role-Playing'},
#  {'game.name': 'God of War: Chains of Olympus', 'game.genre': 'Action'},
#  {'game.name': 'Dragon Quest VI: Maboroshi no Daichi',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Dance Central', 'game.genre': 'Misc'},
#  {'game.name': 'Enter the Matrix', 'game.genre': 'Action'},
#  {'game.name': 'Super Mario Maker', 'game.genre': 'Platform'},
#  {'game.name': 'Fallout: New Vegas', 'game.genre': 'Role-Playing'},
#  {'game.name': 'LEGO Batman: The Videogame', 'game.genre': 'Action'},
#  {'game.name': 'Rhythm Heaven', 'game.genre': 'Misc'},
#  {'game.name': 'Ace Combat 04: Shattered Skies', 'game.genre': 'Simulation'},
#  {'game.name': 'Club Penguin: Elite Penguin Force', 'game.genre': 'Adventure'},
#  {'game.name': 'Animal Crossing', 'game.genre': 'Simulation'},
#  {'game.name': 'LEGO Batman: The Videogame', 'game.genre': 'Action'},
#  {'game.name': 'Sonic Rush', 'game.genre': 'Platform'},
#  {'game.name': 'Resident Evil 6', 'game.genre': 'Shooter'},
#  {'game.name': 'Halo: The Master Chief Collection', 'game.genre': 'Shooter'},
#  {'game.name': 'FIFA Soccer 08', 'game.genre': 'Sports'},
#  {'game.name': 'Spider-Man', 'game.genre': 'Action'},
#  {'game.name': 'Need for Speed III: Hot Pursuit', 'game.genre': 'Racing'},
#  {'game.name': 'Star Wars Episode I Racer', 'game.genre': 'Racing'},
#  {'game.name': 'Personal Trainer: Cooking', 'game.genre': 'Misc'},
#  {'game.name': 'The Elder Scrolls IV: Oblivion', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Dragon Warrior IV', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Heavy Rain', 'game.genre': 'Adventure'},
#  {'game.name': 'Mass Effect 2', 'game.genre': 'Role-Playing'},
#  {'game.name': 'FIFA 15', 'game.genre': 'Sports'},
#  {'game.name': 'Dragon Ball Z: Budokai', 'game.genre': 'Fighting'},
#  {'game.name': 'Madden NFL 2002', 'game.genre': 'Sports'},
#  {'game.name': 'World Class Track Meet', 'game.genre': 'Sports'},
#  {'game.name': 'Borderlands 2', 'game.genre': 'Shooter'},
#  {'game.name': 'The Legend of Zelda: A Link Between Worlds',
#   'game.genre': 'Action'},
#  {'game.name': 'Donkey Kong', 'game.genre': 'Platform'},
#  {'game.name': 'The Sims: Vacation', 'game.genre': 'Simulation'},
#  {'game.name': 'Mass Effect 3', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Kung Fu Panda', 'game.genre': 'Action'},
#  {'game.name': 'Far Cry 3', 'game.genre': 'Shooter'},
#  {'game.name': 'Epic Mickey', 'game.genre': 'Platform'},
#  {'game.name': 'Saints Row 2', 'game.genre': 'Action'},
#  {'game.name': 'Rayman', 'game.genre': 'Platform'},
#  {'game.name': 'Killzone 2', 'game.genre': 'Shooter'},
#  {'game.name': "Tom Clancy's Splinter Cell", 'game.genre': 'Action'},
#  {'game.name': "Mike Tyson's Punch-Out!!", 'game.genre': 'Fighting'},
#  {'game.name': 'WWE SmackDown! Shut Your Mouth', 'game.genre': 'Sports'},
#  {'game.name': 'Gears of War: Ultimate Edition', 'game.genre': 'Shooter'},
#  {'game.name': 'NBA 2K13', 'game.genre': 'Sports'},
#  {'game.name': 'Dragon Ball Z: Budokai Tenkaichi 3', 'game.genre': 'Fighting'},
#  {'game.name': 'wwe Smackdown vs. Raw 2006', 'game.genre': 'Fighting'},
#  {'game.name': 'Middle-Earth: Shadow of Mordor', 'game.genre': 'Action'},
#  {'game.name': 'Star Fox', 'game.genre': 'Shooter'},
#  {'game.name': 'The Sims: Livin Large', 'game.genre': 'Misc'},
#  {'game.name': 'World Soccer Winning Eleven 6 International',
#   'game.genre': 'Sports'},
#  {'game.name': 'Devil May Cry', 'game.genre': 'Action'},
#  {'game.name': 'Animal Crossing: Happy Home Designer',
#   'game.genre': 'Simulation'},
#  {'game.name': 'Battlefield: Bad Company 2', 'game.genre': 'Shooter'},
#  {'game.name': 'The Sims 4', 'game.genre': 'Simulation'},
#  {'game.name': 'Star Wars: The Old Republic', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Sonic Heroes', 'game.genre': 'Platform'},
#  {'game.name': 'Kirby Super Star Ultra', 'game.genre': 'Platform'},
#  {'game.name': 'Hitman 2: Silent Assassin', 'game.genre': 'Action'},
#  {'game.name': 'Street Fighter IV', 'game.genre': 'Fighting'},
#  {'game.name': 'Wave Race 64', 'game.genre': 'Racing'},
#  {'game.name': 'SOCOM II: U.S. Navy SEALs', 'game.genre': 'Shooter'},
#  {'game.name': 'WWE SmackDown! vs. RAW 2006', 'game.genre': 'Fighting'},
#  {'game.name': 'inFAMOUS', 'game.genre': 'Action'},
#  {'game.name': 'Pac-Man Collection', 'game.genre': 'Puzzle'},
#  {'game.name': 'Mass Effect', 'game.genre': 'Role-Playing'},
#  {'game.name': 'WarioWare: Smooth Moves', 'game.genre': 'Puzzle'},
#  {'game.name': 'Cooking Mama: Cook Off', 'game.genre': 'Simulation'},
#  {'game.name': "Super Mario World 2: Yoshi's Island",
#   'game.genre': 'Platform'},
#  {'game.name': 'FIFA 14', 'game.genre': 'Sports'},
#  {'game.name': 'Titanfall', 'game.genre': 'Shooter'},
#  {'game.name': 'Sonic Mega Collection Plus', 'game.genre': 'Misc'},
#  {'game.name': 'Sega Superstars Tennis', 'game.genre': 'Sports'},
#  {'game.name': 'World Soccer Winning Eleven 7 International',
#   'game.genre': 'Sports'},
#  {'game.name': 'Need for Speed: Most Wanted', 'game.genre': 'Racing'},
#  {'game.name': 'Hot Shots Golf 3', 'game.genre': 'Sports'},
#  {'game.name': 'Call of Duty: Finest Hour', 'game.genre': 'Shooter'},
#  {'game.name': 'Zumba Fitness 2', 'game.genre': 'Sports'},
#  {'game.name': 'Syphon Filter', 'game.genre': 'Shooter'},
#  {'game.name': 'Imagine: Babyz', 'game.genre': 'Simulation'},
#  {'game.name': 'Colin McRae Rally', 'game.genre': 'Racing'},
#  {'game.name': 'Call of Duty: Ghosts', 'game.genre': 'Shooter'},
#  {'game.name': 'Madden NFL 13', 'game.genre': 'Sports'},
#  {'game.name': 'The Elder Scrolls III: Morrowind',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Mortal Kombat', 'game.genre': 'Fighting'},
#  {'game.name': 'F-Zero', 'game.genre': 'Racing'},
#  {'game.name': "Yoshi's Story", 'game.genre': 'Platform'},
#  {'game.name': 'Command & Conquer: Red Alert', 'game.genre': 'Strategy'},
#  {'game.name': "Skylanders: Spyro's Adventure", 'game.genre': 'Action'},
#  {'game.name': 'FIFA 16', 'game.genre': 'Sports'},
#  {'game.name': "Assassin's Creed: Brotherhood", 'game.genre': 'Action'},
#  {'game.name': 'BioShock', 'game.genre': 'Shooter'},
#  {'game.name': 'Madden NFL 10', 'game.genre': 'Sports'},
#  {'game.name': 'Medal of Honor', 'game.genre': 'Shooter'},
#  {'game.name': 'WWE SmackDown! vs. Raw', 'game.genre': 'Fighting'},
#  {'game.name': 'Metroid Prime', 'game.genre': 'Shooter'},
#  {'game.name': 'Finding Nemo', 'game.genre': 'Action'},
#  {'game.name': 'Myst', 'game.genre': 'Adventure'},
#  {'game.name': 'Need for Speed: Hot Pursuit', 'game.genre': 'Racing'},
#  {'game.name': 'Imagine: Fashion Designer', 'game.genre': 'Simulation'},
#  {'game.name': 'WWE SmackDown! Here Comes the Pain', 'game.genre': 'Fighting'},
#  {'game.name': 'Star Wars: The Force Unleashed', 'game.genre': 'Action'},
#  {'game.name': "Yoshi's Island DS", 'game.genre': 'Platform'},
#  {'game.name': 'Hot Shots Golf', 'game.genre': 'Sports'},
#  {'game.name': 'Killzone 3', 'game.genre': 'Shooter'},
#  {'game.name': "A Bug's Life", 'game.genre': 'Platform'},
#  {'game.name': 'WWF SmackDown! Just Bring It', 'game.genre': 'Fighting'},
#  {'game.name': 'Dragon Quest V: Tenkuu no Hanayome',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Mortal Kombat Trilogy', 'game.genre': 'Fighting'},
#  {'game.name': 'Battlefield 3', 'game.genre': 'Shooter'},
#  {'game.name': 'NBA Street', 'game.genre': 'Sports'},
#  {'game.name': 'Professor Layton and the Last Specter',
#   'game.genre': 'Puzzle'},
#  {'game.name': 'Monster Hunter Tri', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Jak II', 'game.genre': 'Platform'},
#  {'game.name': 'inFAMOUS: Second Son', 'game.genre': 'Action'},
#  {'game.name': 'Ratchet & Clank: Going Commando', 'game.genre': 'Platform'},
#  {'game.name': 'Tekken 6', 'game.genre': 'Fighting'},
#  {'game.name': 'The Sims', 'game.genre': 'Simulation'},
#  {'game.name': 'Sonic and the Secret Rings', 'game.genre': 'Platform'},
#  {'game.name': 'Saints Row: The Third', 'game.genre': 'Action'},
#  {'game.name': 'Missile Command', 'game.genre': 'Shooter'},
#  {'game.name': 'Mario Paint', 'game.genre': 'Misc'},
#  {'game.name': "Assassin's Creed IV: Black Flag", 'game.genre': 'Action'},
#  {'game.name': 'Pokémon Stadium 2', 'game.genre': 'Strategy'},
#  {'game.name': 'Metroid', 'game.genre': 'Action'},
#  {'game.name': 'L.A. Noire', 'game.genre': 'Adventure'},
#  {'game.name': 'Call of Duty 3', 'game.genre': 'Shooter'},
#  {'game.name': 'The Legend of Zelda: A Link to the Past',
#   'game.genre': 'Action'},
#  {'game.name': 'Onimusha: Warlords', 'game.genre': 'Action'},
#  {'game.name': 'Mortal Kombat X', 'game.genre': 'Fighting'},
#  {'game.name': 'Mario Party', 'game.genre': 'Misc'},
#  {'game.name': 'Madden NFL 12', 'game.genre': 'Sports'},
#  {'game.name': 'LEGO Star Wars II: The Original Trilogy',
#   'game.genre': 'Action'},
#  {'game.name': 'Madden NFL 11', 'game.genre': 'Sports'},
#  {'game.name': 'Mario vs. Donkey Kong: Mini-Land Mayhem!',
#   'game.genre': 'Puzzle'},
#  {'game.name': 'Skate 3', 'game.genre': 'Sports'},
#  {'game.name': 'Burnout 3: Takedown', 'game.genre': 'Racing'},
#  {'game.name': 'Yokai Watch 2 Shinuchi', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Need for Speed: Shift', 'game.genre': 'Racing'},
#  {'game.name': 'Final Fantasy XIII-2', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Mortal Kombat', 'game.genre': 'Fighting'},
#  {'game.name': 'Call Of Duty 2: Big Red One', 'game.genre': 'Shooter'},
#  {'game.name': 'Guitar Hero: World Tour', 'game.genre': 'Misc'},
#  {'game.name': 'Medal of Honor', 'game.genre': 'Shooter'},
#  {'game.name': 'Fable', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Hannah Montana', 'game.genre': 'Action'},
#  {'game.name': "Tom Clancy's Splinter Cell", 'game.genre': 'Action'},
#  {'game.name': 'Skylanders Giants', 'game.genre': 'Action'},
#  {'game.name': 'Medal of Honor Heroes', 'game.genre': 'Shooter'},
#  {'game.name': 'Super Mario Bros.: The Lost Levels', 'game.genre': 'Platform'},
#  {'game.name': 'Star Wars: Shadows of the Empire', 'game.genre': 'Action'},
#  {'game.name': 'LEGO Star Wars: The Complete Saga', 'game.genre': 'Action'},
#  {'game.name': 'Midnight Club: Street Racing', 'game.genre': 'Racing'},
#  {'game.name': 'Pac-Man: Adventures in Time', 'game.genre': 'Fighting'},
#  {'game.name': 'Halo Wars', 'game.genre': 'Strategy'},
#  {'game.name': 'God of War Collection', 'game.genre': 'Action'},
#  {'game.name': 'ESPN NFL 2K5', 'game.genre': 'Sports'},
#  {'game.name': 'Mario Strikers Charged', 'game.genre': 'Sports'},
#  {'game.name': 'Medal of Honor', 'game.genre': 'Shooter'},
#  {'game.name': 'FIFA Soccer 10', 'game.genre': 'Sports'},
#  {'game.name': 'NBA 2K12', 'game.genre': 'Sports'},
#  {'game.name': 'Style Savvy', 'game.genre': 'Simulation'},
#  {'game.name': 'Harry Potter and the Chamber of Secrets',
#   'game.genre': 'Action'},
#  {'game.name': 'Super Mario All-Stars: Limited Edition',
#   'game.genre': 'Platform'},
#  {'game.name': 'Streets of Rage', 'game.genre': 'Action'},
#  {'game.name': 'FIFA Soccer 09', 'game.genre': 'Sports'},
#  {'game.name': 'Ratchet & Clank Future: Tools of Destruction',
#   'game.genre': 'Platform'},
#  {'game.name': 'NBA Live 2005', 'game.genre': 'Sports'},
#  {'game.name': 'LittleBigPlanet', 'game.genre': 'Platform'},
#  {'game.name': 'Killzone: Shadow Fall', 'game.genre': 'Shooter'},
#  {'game.name': 'Ghostbusters: The Video Game (DS Version)',
#   'game.genre': 'Action'},
#  {'game.name': 'Monster Hunter Freedom 2', 'game.genre': 'Role-Playing'},
#  {'game.name': 'WWE SmackDown vs. RAW 2007', 'game.genre': 'Fighting'},
#  {'game.name': 'Ratchet & Clank: Up Your Arsenal', 'game.genre': 'Platform'},
#  {'game.name': 'Art Academy', 'game.genre': 'Misc'},
#  {'game.name': 'Dragon Age: Origins', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Madden NFL 08', 'game.genre': 'Sports'},
#  {'game.name': 'Sonic Adventure 2 Battle', 'game.genre': 'Platform'},
#  {'game.name': 'Dragon Warrior II', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Madden NFL 13', 'game.genre': 'Sports'},
#  {'game.name': 'Pokémon Colosseum', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Deca Sports', 'game.genre': 'Sports'},
#  {'game.name': 'Madden NFL 09', 'game.genre': 'Sports'},
#  {'game.name': 'Space Invaders', 'game.genre': 'Shooter'},
#  {'game.name': 'Crazy Taxi', 'game.genre': 'Racing'},
#  {'game.name': 'Perfect Dark', 'game.genre': 'Action'},
#  {'game.name': 'Game Party', 'game.genre': 'Misc'},
#  {'game.name': 'Dragon Warrior', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Tomb Raider (2013)', 'game.genre': 'Action'},
#  {'game.name': 'Marvel: Ultimate Alliance', 'game.genre': 'Role-Playing'},
#  {'game.name': 'PES 2009: Pro Evolution Soccer', 'game.genre': 'Sports'},
#  {'game.name': 'Mario Party 2', 'game.genre': 'Misc'},
#  {'game.name': 'Saints Row: The Third', 'game.genre': 'Action'},
#  {'game.name': 'Rockstar Games Double Pack: Grand Theft Auto III & Grand Theft Auto Vice City',
#   'game.genre': 'Action'},
#  {'game.name': 'LEGO Harry Potter: Years 1-4', 'game.genre': 'Action'},
#  {'game.name': 'Mortal Kombat: Deadly Alliance', 'game.genre': 'Fighting'},
#  {'game.name': 'Resistance 2', 'game.genre': 'Shooter'},
#  {'game.name': 'Pure', 'game.genre': 'Racing'},
#  {'game.name': 'Tomb Raider: The Last Revelation', 'game.genre': 'Action'},
#  {'game.name': 'NBA 2K13', 'game.genre': 'Sports'},
#  {'game.name': 'Rock Band', 'game.genre': 'Misc'},
#  {'game.name': 'NBA 2K14', 'game.genre': 'Sports'},
#  {'game.name': 'Mario Party 4', 'game.genre': 'Misc'},
#  {'game.name': 'uDraw Studio', 'game.genre': 'Misc'},
#  {'game.name': 'Midnight Club: Los Angeles', 'game.genre': 'Racing'},
#  {'game.name': 'Final Fantasy V', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Final Fantasy Tactics', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Twisted Metal 2', 'game.genre': 'Racing'},
#  {'game.name': 'Halo: Combat Evolved Anniversary', 'game.genre': 'Shooter'},
#  {'game.name': 'Need for Speed Carbon: Own the City', 'game.genre': 'Racing'},
#  {'game.name': "The Sims: Bustin' Out", 'game.genre': 'Simulation'},
#  {'game.name': 'Riven: The Sequel to Myst', 'game.genre': 'Adventure'},
#  {'game.name': "Tom Clancy's Rainbow Six: Vegas 2", 'game.genre': 'Shooter'},
#  {'game.name': 'Sonic Adventure', 'game.genre': 'Platform'},
#  {'game.name': 'Ice Hockey', 'game.genre': 'Sports'},
#  {'game.name': 'pro evolution soccer 2011', 'game.genre': 'Sports'},
#  {'game.name': 'Dragon Ball Z: Budokai 2', 'game.genre': 'Fighting'},
#  {'game.name': 'ATV Offroad Fury', 'game.genre': 'Racing'},
#  {'game.name': 'Dino Crisis', 'game.genre': 'Action'},
#  {'game.name': 'Minecraft', 'game.genre': 'Misc'},
#  {'game.name': 'Need for Speed: ProStreet', 'game.genre': 'Racing'},
#  {'game.name': 'Madden NFL 16', 'game.genre': 'Sports'},
#  {'game.name': 'Tetris Plus', 'game.genre': 'Puzzle'},
#  {'game.name': 'Pro Wrestling', 'game.genre': 'Fighting'},
#  {'game.name': 'Theme Hospital', 'game.genre': 'Strategy'},
#  {'game.name': "Frogger's Adventures: Temple of the Frog",
#   'game.genre': 'Adventure'},
#  {'game.name': 'Need for Speed (2015)', 'game.genre': 'Racing'},
#  {'game.name': 'Zumba Fitness', 'game.genre': 'Sports'},
#  {'game.name': 'LEGO Indiana Jones: The Original Adventures',
#   'game.genre': 'Action'},
#  {'game.name': 'Monopoly', 'game.genre': 'Misc'},
#  {'game.name': 'Batman: Arkham Origins', 'game.genre': 'Action'},
#  {'game.name': 'Dead Island', 'game.genre': 'Action'},
#  {'game.name': 'Guitar Hero', 'game.genre': 'Misc'},
#  {'game.name': 'LEGO Star Wars: The Complete Saga', 'game.genre': 'Action'},
#  {'game.name': 'Kinect: Disneyland Adventures', 'game.genre': 'Misc'},
#  {'game.name': 'WCW/nWo Revenge', 'game.genre': 'Fighting'},
#  {'game.name': 'Bloodborne', 'game.genre': 'Action'},
#  {'game.name': 'NBA 2K15', 'game.genre': 'Sports'},
#  {'game.name': 'Madden NFL 11', 'game.genre': 'Sports'},
#  {'game.name': 'Yu-Gi-Oh! The Duelists of the Roses', 'game.genre': 'Misc'},
#  {'game.name': 'Madden NFL 08', 'game.genre': 'Sports'},
#  {'game.name': 'Half-Life 2', 'game.genre': 'Shooter'},
#  {'game.name': 'The Incredibles', 'game.genre': 'Action'},
#  {'game.name': "Tony Hawk's Underground 2", 'game.genre': 'Sports'},
#  {'game.name': 'Madden NFL 10', 'game.genre': 'Sports'},
#  {'game.name': 'Kinect Sports: Season Two', 'game.genre': 'Sports'},
#  {'game.name': "Kirby's Dream Land 2", 'game.genre': 'Platform'},
#  {'game.name': 'LEGO Harry Potter: Years 1-4', 'game.genre': 'Action'},
#  {'game.name': 'Donkey Kong Land II', 'game.genre': 'Platform'},
#  {'game.name': 'Dragon Warrior Monsters', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Midnight Club: Los Angeles', 'game.genre': 'Racing'},
#  {'game.name': 'Skylanders SWAP Force', 'game.genre': 'Platform'},
#  {'game.name': 'WWE SmackDown vs Raw 2008', 'game.genre': 'Fighting'},
#  {'game.name': 'My Fitness Coach', 'game.genre': 'Sports'},
#  {'game.name': 'Resident Evil - Code: Veronica X', 'game.genre': 'Action'},
#  {'game.name': 'The Sims 3', 'game.genre': 'Simulation'},
#  {'game.name': "The Legend of Zelda: Majora's Mask 3D",
#   'game.genre': 'Action'},
#  {'game.name': 'NBA 2K16', 'game.genre': 'Sports'},
#  {'game.name': 'Just Dance Kids', 'game.genre': 'Misc'},
#  {'game.name': 'Mario Tennis', 'game.genre': 'Sports'},
#  {'game.name': 'Grand Theft Auto', 'game.genre': 'Action'},
#  {'game.name': 'James Bond 007: Everything or Nothing',
#   'game.genre': 'Shooter'},
#  {'game.name': 'WarioWare Touched!', 'game.genre': 'Puzzle'},
#  {'game.name': 'Need For Speed: High Stakes', 'game.genre': 'Racing'},
#  {'game.name': 'Chrono Trigger', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Cool Boarders 3', 'game.genre': 'Sports'},
#  {'game.name': 'LEGO Marvel Super Heroes', 'game.genre': 'Action'},
#  {'game.name': 'Guild Wars 2', 'game.genre': 'Action'},
#  {'game.name': 'Pokemon Ranger: Shadows of Almia',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Dead Island', 'game.genre': 'Action'},
#  {'game.name': 'Tomb Raider II', 'game.genre': 'Action'},
#  {'game.name': 'God of War: Ascension', 'game.genre': 'Action'},
#  {'game.name': 'Need for Speed Underground 2', 'game.genre': 'Racing'},
#  {'game.name': 'Pro Evolution Soccer 2010', 'game.genre': 'Sports'},
#  {'game.name': 'Just Dance 2015', 'game.genre': 'Misc'},
#  {'game.name': 'Yokai Watch Busters', 'game.genre': 'Action'},
#  {'game.name': 'Mario Bros.', 'game.genre': 'Platform'},
#  {'game.name': 'FIFA Soccer 09', 'game.genre': 'Sports'},
#  {'game.name': 'Star Wars: The Force Unleashed', 'game.genre': 'Action'},
#  {'game.name': 'Borderlands 2', 'game.genre': 'Shooter'},
#  {'game.name': 'TOCA Touring Car Championship', 'game.genre': 'Racing'},
#  {'game.name': 'Paper Mario: Sticker Star', 'game.genre': 'Role-Playing'},
#  {'game.name': "Sonic's Ultimate Genesis Collection", 'game.genre': 'Misc'},
#  {'game.name': 'Super Monkey Ball: Banana Blitz', 'game.genre': 'Misc'},
#  {'game.name': 'Kirby: Nightmare in Dream Land', 'game.genre': 'Platform'},
#  {'game.name': 'Wario Land 4', 'game.genre': 'Platform'},
#  {'game.name': 'Guitar Hero III: Legends of Rock', 'game.genre': 'Misc'},
#  {'game.name': 'Call of Duty 3', 'game.genre': 'Shooter'},
#  {'game.name': 'Resident Evil 4', 'game.genre': 'Action'},
#  {'game.name': 'Minecraft', 'game.genre': 'Misc'},
#  {'game.name': "Onimusha 2: Samurai's Destiny", 'game.genre': 'Adventure'},
#  {'game.name': 'Cool Boarders 2', 'game.genre': 'Sports'},
#  {'game.name': 'Paper Mario: The Thousand-Year Door',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Madden NFL 12', 'game.genre': 'Sports'},
#  {'game.name': 'Monster Hunter Tri', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Dissidia: Final Fantasy', 'game.genre': 'Fighting'},
#  {'game.name': 'Sonic Advance', 'game.genre': 'Platform'},
#  {'game.name': 'Spyro: Season of Ice', 'game.genre': 'Platform'},
#  {'game.name': 'Teenage Mutant Ninja Turtles II: The Arcade Game',
#   'game.genre': 'Action'},
#  {'game.name': 'LEGO Indiana Jones: The Original Adventures',
#   'game.genre': 'Action'},
#  {'game.name': 'Dance Dance Revolution X2', 'game.genre': 'Simulation'},
#  {'game.name': 'New Super Luigi U', 'game.genre': 'Platform'},
#  {'game.name': 'Prince of Persia: The Sands of Time', 'game.genre': 'Action'},
# ...
#  {'game.name': 'Syphon Filter 2', 'game.genre': 'Shooter'},
#  {'game.name': "Tom Clancy's Rainbow Six: Siege", 'game.genre': 'Shooter'},
#  {'game.name': 'Volleyball', 'game.genre': 'Sports'},
#  {'game.name': 'FIFA 15', 'game.genre': 'Sports'},
#  {'game.name': 'Call of Duty: Roads to Victory', 'game.genre': 'Shooter'},
#  {'game.name': 'Super Mario RPG: Legend of the Seven Stars',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Mahjong', 'game.genre': 'Misc'},
#  {'game.name': 'R.C. Pro-Am', 'game.genre': 'Racing'},
#  {'game.name': 'SimCity 2000', 'game.genre': 'Simulation'},
#  {'game.name': 'Demon Attack', 'game.genre': 'Shooter'},
#  {'game.name': 'Dance Dance Revolution Extreme', 'game.genre': 'Simulation'},
#  {'game.name': 'Tetris DS', 'game.genre': 'Puzzle'},
#  {'game.name': 'Final Fantasy Tactics Advance', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Far Cry: Primal', 'game.genre': 'Action'},
#  {'game.name': 'Toy Story 3: The Video Game', 'game.genre': 'Action'},
#  {'game.name': 'Final Fantasy III', 'game.genre': 'Role-Playing'},
#  {'game.name': "Kirby's Epic Yarn", 'game.genre': 'Platform'},
#  {'game.name': 'Project Gotham Racing', 'game.genre': 'Racing'},
#  {'game.name': 'Golf', 'game.genre': 'Sports'},
#  {'game.name': 'NBA 2K12', 'game.genre': 'Sports'},
#  {'game.name': 'Borderlands', 'game.genre': 'Shooter'},
#  {'game.name': "Tony Hawk's Pro Skater", 'game.genre': 'Sports'},
#  {'game.name': 'PES 2009: Pro Evolution Soccer', 'game.genre': 'Sports'},
#  {'game.name': 'Need for Speed: Hot Pursuit 2', 'game.genre': 'Racing'},
#  {'game.name': 'Mario Sports Mix', 'game.genre': 'Sports'},
#  {'game.name': 'Rock Band', 'game.genre': 'Misc'},
#  {'game.name': 'Dynasty Warriors 4', 'game.genre': 'Action'},
#  {'game.name': 'Mortal Kombat', 'game.genre': 'Fighting'},
#  {'game.name': 'Parasite Eve', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Scooby-Doo! Night of 100 Frights', 'game.genre': 'Platform'},
#  {'game.name': 'Project Gotham Racing (JP weekly sales)',
#   'game.genre': 'Action'},
#  {'game.name': 'Need for Speed: Most Wanted 5-1-0', 'game.genre': 'Racing'},
#  {'game.name': 'Portal 2', 'game.genre': 'Shooter'},
#  {'game.name': "Devil May Cry 3: Dante's Awakening", 'game.genre': 'Action'},
#  {'game.name': 'Derby Stallion', 'game.genre': 'Sports'},
#  {'game.name': 'Dead Rising', 'game.genre': 'Action'},
#  {'game.name': 'Finding Nemo', 'game.genre': 'Action'},
#  {'game.name': 'NBA 2K11', 'game.genre': 'Action'},
#  {'game.name': 'Wipeout: The Game', 'game.genre': 'Misc'},
#  {'game.name': 'The Sims 2: Pets', 'game.genre': 'Simulation'},
#  {'game.name': 'Battlefield: Hardline', 'game.genre': 'Shooter'},
#  {'game.name': 'Metal Gear Solid: Peace Walker', 'game.genre': 'Action'},
#  {'game.name': 'World of Warcraft: Cataclysm', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Tetris Worlds', 'game.genre': 'Puzzle'},
#  {'game.name': 'Need For Speed: Undercover', 'game.genre': 'Racing'},
#  {'game.name': 'Dance Dance Revolution: Hottest Party',
#   'game.genre': 'Simulation'},
#  {'game.name': 'Mario Party 5', 'game.genre': 'Misc'},
#  {'game.name': 'Ghostbusters: The Video Game (DS Version)',
#   'game.genre': 'Action'},
#  {'game.name': 'Sim Theme Park', 'game.genre': 'Strategy'},
#  {'game.name': 'Warcraft: Orcs & Humans', 'game.genre': 'Strategy'},
#  {'game.name': 'Skate 3', 'game.genre': 'Sports'},
#  {'game.name': 'Spec Ops: Airborne Commando', 'game.genre': 'Shooter'},
#  {'game.name': 'Kingdom Hearts: Birth by Sleep', 'game.genre': 'Role-Playing'},
#  {'game.name': 'UFC 2009 Undisputed', 'game.genre': 'Fighting'},
#  {'game.name': 'Dark Souls', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Yu-Gi-Oh! The Eternal Duelist Soul', 'game.genre': 'Strategy'},
#  {'game.name': 'Need for Speed: ProStreet', 'game.genre': 'Racing'},
#  {'game.name': 'The Sims 3', 'game.genre': 'Simulation'},
#  {'game.name': "Tom Clancy's Splinter Cell: Conviction",
#   'game.genre': 'Action'},
#  {'game.name': 'Pokemon Mystery Dungeon: Red/Blue Rescue Team',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'The Incredibles', 'game.genre': 'Action'},
#  {'game.name': 'R4: Ridge Racer Type 4', 'game.genre': 'Racing'},
#  {'game.name': 'SoulCalibur II', 'game.genre': 'Fighting'},
#  {'game.name': 'Mario & Luigi: Dream Team', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Need for Speed: ProStreet', 'game.genre': 'Racing'},
#  {'game.name': 'Carnival Games', 'game.genre': 'Misc'},
#  {'game.name': 'NBA 2K14', 'game.genre': 'Sports'},
#  {'game.name': 'Pokémon Mystery Dungeon: Blue Rescue Team',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Sonic Mega Collection', 'game.genre': 'Misc'},
#  {'game.name': 'Diablo III', 'game.genre': 'Role-Playing'},
#  {'game.name': 'NBA Jam', 'game.genre': 'Sports'},
#  {'game.name': 'PGR4 - Project Gotham Racing 4', 'game.genre': 'Racing'},
#  {'game.name': 'Kingdom Hearts 358/2 Days', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Dance Central 2', 'game.genre': 'Misc'},
#  {'game.name': 'Rayman Raving Rabbids: TV Party', 'game.genre': 'Misc'},
#  {'game.name': 'SOCOM: U.S. Navy SEALs: Combined Assault',
#   'game.genre': 'Shooter'},
#  {'game.name': "Peter Jackson's King Kong: The Official Game of the Movie",
#   'game.genre': 'Action'},
#  {'game.name': 'Donkey Kong Country', 'game.genre': 'Platform'},
#  {'game.name': 'Need for Speed: The Run', 'game.genre': 'Action'},
#  {'game.name': 'Madden NFL 15', 'game.genre': 'Sports'},
#  {'game.name': '1080°: TenEighty Snowboarding', 'game.genre': 'Sports'},
#  {'game.name': 'Just Dance 3', 'game.genre': 'Misc'},
#  {'game.name': 'NBA Live 2004', 'game.genre': 'Sports'},
#  {'game.name': 'Dead Space', 'game.genre': 'Action'},
#  {'game.name': 'Call of Duty 2', 'game.genre': 'Shooter'},
#  {'game.name': 'Madden NFL 15', 'game.genre': 'Sports'},
#  {'game.name': 'Forza Horizon', 'game.genre': 'Racing'},
#  {'game.name': 'TouchMaster', 'game.genre': 'Puzzle'},
#  {'game.name': "Tom Clancy's The Division", 'game.genre': 'Shooter'},
#  {'game.name': 'LEGO Marvel Super Heroes', 'game.genre': 'Action'},
#  {'game.name': 'Fire Emblem: Awakening', 'game.genre': 'Role-Playing'},
#  {'game.name': 'DriveClub', 'game.genre': 'Racing'},
#  {'game.name': 'Super Street Fighter II', 'game.genre': 'Fighting'},
#  {'game.name': 'Mortal Kombat vs. DC Universe', 'game.genre': 'Fighting'},
#  {'game.name': 'Tenchu: Stealth Assassins', 'game.genre': 'Action'},
#  {'game.name': 'Tennis', 'game.genre': 'Sports'},
#  {'game.name': 'Harry Potter and the Chamber of Secrets',
#   'game.genre': 'Action'},
#  {'game.name': 'Harry Potter and the Chamber of Secrets',
#   'game.genre': 'Action'},
#  {'game.name': 'SimCity', 'game.genre': 'Simulation'},
#  {'game.name': 'Battlefield 4', 'game.genre': 'Shooter'},
#  {'game.name': 'Resident Evil 6', 'game.genre': 'Shooter'},
#  {'game.name': 'Dragon Age: Inquisition', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Sonic Classic Collection', 'game.genre': 'Platform'},
#  {'game.name': 'Spyro: Enter the Dragonfly', 'game.genre': 'Platform'},
#  {'game.name': 'Call of Duty: World at War', 'game.genre': 'Shooter'},
#  {'game.name': 'Devil May Cry 2', 'game.genre': 'Action'},
#  {'game.name': 'Burnout Paradise', 'game.genre': 'Racing'},
#  {'game.name': 'E.T.: The Extra Terrestrial', 'game.genre': 'Action'},
#  {'game.name': 'BioShock Infinite', 'game.genre': 'Shooter'},
#  {'game.name': 'Hot Shots Golf: Open Tee', 'game.genre': 'Sports'},
#  {'game.name': 'Rad Racer', 'game.genre': 'Racing'},
#  {'game.name': 'Soccer', 'game.genre': 'Sports'},
#  {'game.name': 'Kirby Squeak Squad', 'game.genre': 'Platform'},
#  {'game.name': "Tom Clancy's Rainbow Six: Vegas", 'game.genre': 'Shooter'},
#  {'game.name': 'Destiny', 'game.genre': 'Shooter'},
#  {'game.name': 'Crash Nitro Kart', 'game.genre': 'Racing'},
#  {'game.name': 'Grand Theft Auto: San Andreas', 'game.genre': 'Action'},
#  {'game.name': 'Star Wars: Dark Forces', 'game.genre': 'Shooter'},
#  {'game.name': 'NBA Street Vol. 2', 'game.genre': 'Sports'},
#  {'game.name': 'Def Jam Vendetta', 'game.genre': 'Fighting'},
#  {'game.name': 'FIFA Soccer 09', 'game.genre': 'Sports'},
#  {'game.name': 'Who wants to be a millionaire', 'game.genre': 'Misc'},
#  {'game.name': 'Scooby Doo and the Cyber Chase', 'game.genre': 'Adventure'},
#  {'game.name': 'Alleyway', 'game.genre': 'Puzzle'},
#  {'game.name': 'Dragon Ball Z: Budokai 3', 'game.genre': 'Fighting'},
#  {'game.name': 'Jet Moto 2', 'game.genre': 'Racing'},
#  {'game.name': "Tom Clancy's Ghost Recon", 'game.genre': 'Shooter'},
#  {'game.name': 'X-Men Legends', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Batman: Arkham Origins', 'game.genre': 'Action'},
#  {'game.name': 'Guitar Hero: World Tour', 'game.genre': 'Misc'},
#  {'game.name': 'Mortal Kombat II', 'game.genre': 'Fighting'},
#  {'game.name': 'Virtua Fighter 2', 'game.genre': 'Fighting'},
#  {'game.name': 'Tetris DX', 'game.genre': 'Puzzle'},
#  {'game.name': 'Mortal Kombat vs. DC Universe', 'game.genre': 'Fighting'},
#  {'game.name': 'Watch Dogs', 'game.genre': 'Action'},
#  {'game.name': 'Mario Super Sluggers', 'game.genre': 'Sports'},
#  {'game.name': 'Tomb Raider (2013)', 'game.genre': 'Action'},
#  {'game.name': 'The Legend of Zelda: Oracle of Ages', 'game.genre': 'Action'},
#  {'game.name': 'Need for Speed: Shift', 'game.genre': 'Racing'},
#  {'game.name': 'Monopoly', 'game.genre': 'Misc'},
#  {'game.name': 'Red Faction', 'game.genre': 'Shooter'},
#  {'game.name': "The Sims: Makin' Magic", 'game.genre': 'Simulation'},
#  {'game.name': 'MX Unleashed', 'game.genre': 'Racing'},
#  {'game.name': 'PaRappa The Rapper', 'game.genre': 'Misc'},
#  {'game.name': 'Toy Story Mania!', 'game.genre': 'Misc'},
#  {'game.name': 'Mario Party 3', 'game.genre': 'Misc'},
#  {'game.name': 'Star Wars: The Force Unleashed', 'game.genre': 'Action'},
#  {'game.name': 'Game Party 2', 'game.genre': 'Misc'},
#  {'game.name': 'Destiny: The Taken King', 'game.genre': 'Shooter'},
#  {'game.name': 'LEGO Star Wars III: The Clone Wars', 'game.genre': 'Action'},
#  {'game.name': 'Star Wars Rogue Leader: Rogue Squadron II',
#   'game.genre': 'Simulation'},
#  {'game.name': 'Max Payne 3', 'game.genre': 'Shooter'},
#  {'game.name': 'Need for Speed Rivals', 'game.genre': 'Racing'},
#  {'game.name': 'Madden NFL 09', 'game.genre': 'Sports'},
#  {'game.name': 'Yokai Watch', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Ratchet & Clank Future: A Crack in Time',
#   'game.genre': 'Platform'},
#  {'game.name': 'Yu-Gi-Oh! Forbidden Memories', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Mortal Kombat: Deception', 'game.genre': 'Fighting'},
#  {'game.name': 'Hot Shots Golf 2', 'game.genre': 'Sports'},
#  {'game.name': 'Medal of Honor: European Assault (All Region sales)',
#   'game.genre': 'Shooter'},
#  {'game.name': 'WCW Nitro', 'game.genre': 'Fighting'},
#  {'game.name': 'High School Musical: Sing It!', 'game.genre': 'Misc'},
#  {'game.name': 'Star Fox Adventures', 'game.genre': 'Adventure'},
#  {'game.name': 'FIFA 2000', 'game.genre': 'Sports'},
#  {'game.name': 'Dynasty Warriors 3', 'game.genre': 'Action'},
#  {'game.name': 'Donkey Kong Country Returns', 'game.genre': 'Platform'},
#  {'game.name': 'The Legend of Zelda: Oracle of Seasons',
#   'game.genre': 'Adventure'},
#  {'game.name': 'Madden NFL 06', 'game.genre': 'Sports'},
#  {'game.name': 'Shrek 2', 'game.genre': 'Platform'},
#  {'game.name': 'The Legend of Dragoon', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Turok 2: Seeds of Evil', 'game.genre': 'Platform'},
#  {'game.name': 'SingStar', 'game.genre': 'Misc'},
#  {'game.name': 'LittleBigPlanet 3', 'game.genre': 'Platform'},
#  {'game.name': 'NBA Live 2002', 'game.genre': 'Sports'},
#  {'game.name': 'Phineas and Ferb', 'game.genre': 'Action'},
#  {'game.name': 'Chrono Cross', 'game.genre': 'Role-Playing'},
#  {'game.name': 'GoldenEye 007 (2010)', 'game.genre': 'Action'},
#  {'game.name': 'Mario Party: Island Tour', 'game.genre': 'Misc'},
#  {'game.name': 'Jak 3', 'game.genre': 'Platform'},
#  {'game.name': 'Rayman Raving Rabbids 2', 'game.genre': 'Misc'},
#  {'game.name': 'Kingdom Hearts: Chain of Memories',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Pinball', 'game.genre': 'Action'},
#  {'game.name': 'inFAMOUS 2', 'game.genre': 'Action'},
#  {'game.name': 'Gran Turismo Concept 2001 Tokyo', 'game.genre': 'Racing'},
#  {'game.name': "Demon's Souls", 'game.genre': 'Role-Playing'},
#  {'game.name': 'NCAA Football 06', 'game.genre': 'Sports'},
#  {'game.name': 'Hey You, Pikachu!', 'game.genre': 'Simulation'},
#  {'game.name': '2 Games in 1: Sonic Advance & ChuChu Rocket!',
#   'game.genre': 'Misc'},
#  {'game.name': 'World of Warcraft: Mists of Pandaria',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'Jet Moto', 'game.genre': 'Racing'},
#  {'game.name': 'Just Cause 3', 'game.genre': 'Action'},
#  {'game.name': 'Secret of Mana', 'game.genre': 'Role-Playing'},
#  {'game.name': 'The Orange Box', 'game.genre': 'Shooter'},
#  {'game.name': 'Air Combat', 'game.genre': 'Simulation'},
#  {'game.name': 'Kirby: Triple Deluxe', 'game.genre': 'Platform'},
#  {'game.name': 'Sonic & Knuckles', 'game.genre': 'Platform'},
#  {'game.name': 'Namco Museum', 'game.genre': 'Misc'},
#  {'game.name': 'The Sims: Hot Date', 'game.genre': 'Simulation'},
#  {'game.name': 'Metroid Prime 3: Corruption', 'game.genre': 'Shooter'},
#  {'game.name': 'Dragon Quest VI: Realms of Revelation',
#   'game.genre': 'Role-Playing'},
#  {'game.name': 'The Evil Within', 'game.genre': 'Action'},
#  {'game.name': 'DDRMAX2: Dance Dance Revolution', 'game.genre': 'Simulation'},
#  {'game.name': 'Crazy Taxi', 'game.genre': 'Racing'},
#  {'game.name': 'Virtua Fighter 4', 'game.genre': 'Fighting'},
#  {'game.name': 'Sly 2: Band of Thieves', 'game.genre': 'Platform'},
#  {'game.name': 'Guitar Hero: World Tour', 'game.genre': 'Misc'},
#  {'game.name': 'Sonic Advance 2', 'game.genre': 'Platform'},
#  {'game.name': 'Madden NFL 07', 'game.genre': 'Sports'},
#  {'game.name': 'NBA 2K11', 'game.genre': 'Action'},
#  {'game.name': 'NFL GameDay 2000', 'game.genre': 'Sports'},
#  {'game.name': 'Call of Duty: Black Ops 3', 'game.genre': 'Shooter'},
#  {'game.name': "Disney's The Lion King", 'game.genre': 'Platform'},
#  {'game.name': 'Beyond: Two Souls', 'game.genre': 'Adventure'},
#  {'game.name': 'Kinect Star Wars', 'game.genre': 'Action'},
#  {'game.name': 'Midnight Club II', 'game.genre': 'Racing'},
#  {'game.name': 'Dragon Quest Monsters: Joker', 'game.genre': 'Role-Playing'},
#  {'game.name': 'SpongeBob SquarePants: SuperSponge', 'game.genre': 'Action'},
#  {'game.name': 'The Getaway: Black Monday', 'game.genre': 'Action'},
#  {'game.name': 'Professor Layton and the Mask of Miracle',
#   'game.genre': 'Puzzle'},
#  {'game.name': 'Just Cause 2', 'game.genre': 'Action'},
#  {'game.name': "Dragon's Dogma", 'game.genre': 'Role-Playing'},
#  {'game.name': 'The Legend of Zelda: The Wind Waker', 'game.genre': 'Action'},
#  {'game.name': '50 Cent: Bulletproof', 'game.genre': 'Action'},
#  {'game.name': 'High School Musical: Sing It!', 'game.genre': 'Misc'},
#  {'game.name': 'Wii Party U', 'game.genre': 'Misc'},
#  {'game.name': 'Madden NFL 25', 'game.genre': 'Sports'},
#  {'game.name': 'Final Fantasy II', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Kirby 64: The Crystal Shards', 'game.genre': 'Platform'},
#  {'game.name': 'Dead or Alive 3', 'game.genre': 'Fighting'},
#  {'game.name': 'UFC 2009 Undisputed', 'game.genre': 'Fighting'},
#  {'game.name': 'Metroid II: Return of Samus', 'game.genre': 'Adventure'},
#  {'game.name': 'WWF Attitude', 'game.genre': 'Fighting'},
#  {'game.name': 'The SpongeBob SquarePants Movie', 'game.genre': 'Platform'},
#  {'game.name': 'Golden Sun', 'game.genre': 'Role-Playing'},
#  {'game.name': 'Sonic the Hedgehog 3', 'game.genre': 'Platform'},
#  {'game.name': 'Kid Icarus', 'game.genre': 'Platform'},
#  {'game.name': 'Def Jam: Fight for NY', 'game.genre': 'Fighting'},
#  {'game.name': "Tom Clancy's Ghost Recon", 'game.genre': 'Shooter'},
#  {'game.name': 'State of Emergency', 'game.genre': 'Action'},
#  {'game.name': 'BioShock Infinite', 'game.genre': 'Shooter'},
#  {'game.name': 'Hitman: Absolution', 'game.genre': 'Action'},
#  {'game.name': '2 Games in 1 Double Pack: The Incredibles / Finding Nemo: The Continuing Adventures',
#   'game.genre': 'Action'},
#  {'game.name': 'Call of Duty: Black Ops 3', 'game.genre': 'Shooter'},
#  ...]

# %%
cypher = """
  MATCH (game:Game {name:"New Super Mario Bros."})-[:PUBLISHED_BY]->(m)<-[:PUBLISHED_BY]-(otherGames)
  RETURN otherGames.name, otherGames.global_sales
  """
kg.query(cypher)
# Out:
# [{'otherGames.name': 'Wii Sports', 'otherGames.global_sales': 82.74},
#  {'otherGames.name': 'Super Mario Bros.', 'otherGames.global_sales': 40.24},
#  {'otherGames.name': 'Mario Kart Wii', 'otherGames.global_sales': 35.82},
#  {'otherGames.name': 'Wii Sports Resort', 'otherGames.global_sales': 33.0},
#  {'otherGames.name': 'Pokemon Red/Pokemon Blue',
#   'otherGames.global_sales': 31.37},
#  {'otherGames.name': 'Tetris', 'otherGames.global_sales': 30.26},
#  {'otherGames.name': 'Wii Play', 'otherGames.global_sales': 29.02},
#  {'otherGames.name': 'New Super Mario Bros. Wii',
#   'otherGames.global_sales': 28.62},
#  {'otherGames.name': 'Duck Hunt', 'otherGames.global_sales': 28.31},
#  {'otherGames.name': 'Nintendogs', 'otherGames.global_sales': 24.76},
#  {'otherGames.name': 'Mario Kart DS', 'otherGames.global_sales': 23.42},
#  {'otherGames.name': 'Pokemon Gold/Pokemon Silver',
#   'otherGames.global_sales': 23.1},
#  {'otherGames.name': 'Wii Fit', 'otherGames.global_sales': 22.72},
#  {'otherGames.name': 'Wii Fit Plus', 'otherGames.global_sales': 22.0},
#  {'otherGames.name': 'Super Mario World', 'otherGames.global_sales': 20.61},
#  {'otherGames.name': 'Brain Age: Train Your Brain in Minutes a Day',
#   'otherGames.global_sales': 20.22},
#  {'otherGames.name': 'Pokemon Diamond/Pokemon Pearl',
#   'otherGames.global_sales': 18.36},
#  {'otherGames.name': 'Super Mario Land', 'otherGames.global_sales': 18.14},
#  {'otherGames.name': 'Super Mario Bros. 3', 'otherGames.global_sales': 17.28},
#  {'otherGames.name': 'Pokemon Ruby/Pokemon Sapphire',
#   'otherGames.global_sales': 15.85},
#  {'otherGames.name': 'Pokemon Black/Pokemon White',
#   'otherGames.global_sales': 15.32},
#  {'otherGames.name': 'Brain Age 2: More Training in Minutes a Day',
#   'otherGames.global_sales': 15.3},
#  {'otherGames.name': 'Pokémon Yellow: Special Pikachu Edition',
#   'otherGames.global_sales': 14.64},
#  {'otherGames.name': 'Pokemon X/Pokemon Y', 'otherGames.global_sales': 14.35},
#  {'otherGames.name': 'Super Smash Bros. Brawl',
#   'otherGames.global_sales': 13.04},
#  {'otherGames.name': 'Animal Crossing: Wild World',
#   'otherGames.global_sales': 12.27},
#  {'otherGames.name': 'Mario Kart 7', 'otherGames.global_sales': 12.21},
#  {'otherGames.name': 'Pokemon HeartGold/Pokemon SoulSilver',
#   'otherGames.global_sales': 11.9},
#  {'otherGames.name': 'Super Mario 64', 'otherGames.global_sales': 11.89},
#  {'otherGames.name': 'Super Mario Galaxy', 'otherGames.global_sales': 11.52},
#  {'otherGames.name': 'Pokemon Omega Ruby/Pokemon Alpha Sapphire',
#   'otherGames.global_sales': 11.33},
#  {'otherGames.name': 'Super Mario Land 2: 6 Golden Coins',
#   'otherGames.global_sales': 11.18},
#  {'otherGames.name': 'Super Mario 3D Land', 'otherGames.global_sales': 10.79},
#  {'otherGames.name': 'Super Mario All-Stars',
#   'otherGames.global_sales': 10.55},
#  {'otherGames.name': 'Pokemon FireRed/Pokemon LeafGreen',
#   'otherGames.global_sales': 10.49},
#  {'otherGames.name': 'Super Mario 64', 'otherGames.global_sales': 10.42},
#  {'otherGames.name': 'Mario Kart 64', 'otherGames.global_sales': 9.87},
#  {'otherGames.name': 'New Super Mario Bros. 2',
#   'otherGames.global_sales': 9.82},
#  {'otherGames.name': 'Donkey Kong Country', 'otherGames.global_sales': 9.3},
#  {'otherGames.name': 'Animal Crossing: New Leaf',
#   'otherGames.global_sales': 9.09},
#  {'otherGames.name': 'Mario Party DS', 'otherGames.global_sales': 9.02},
#  {'otherGames.name': 'Super Mario Kart', 'otherGames.global_sales': 8.76},
#  {'otherGames.name': 'Wii Party', 'otherGames.global_sales': 8.49},
#  {'otherGames.name': 'Mario Party 8', 'otherGames.global_sales': 8.42},
#  {'otherGames.name': 'Pokemon Black 2/Pokemon White 2',
#   'otherGames.global_sales': 8.33},
#  {'otherGames.name': 'GoldenEye 007', 'otherGames.global_sales': 8.09},
#  {'otherGames.name': 'Pokémon Platinum Version',
#   'otherGames.global_sales': 7.84},
#  {'otherGames.name': 'Super Mario Galaxy 2', 'otherGames.global_sales': 7.69},
#  {'otherGames.name': 'The Legend of Zelda: Ocarina of Time',
#   'otherGames.global_sales': 7.6},
#  {'otherGames.name': 'Super Mario Bros. 2', 'otherGames.global_sales': 7.46},
#  {'otherGames.name': 'Super Smash Bros. for Wii U and 3DS',
#   'otherGames.global_sales': 7.45},
#  {'otherGames.name': 'The Legend of Zelda: Twilight Princess',
#   'otherGames.global_sales': 7.31},
#  {'otherGames.name': 'Super Smash Bros. Melee',
#   'otherGames.global_sales': 7.07},
#  {'otherGames.name': 'Mario Kart 8', 'otherGames.global_sales': 6.96},
#  {'otherGames.name': 'Mario Kart: Double Dash!!',
#   'otherGames.global_sales': 6.95},
#  {'otherGames.name': 'Big Brain Academy', 'otherGames.global_sales': 6.67},
#  {'otherGames.name': 'Donkey Kong Country Returns',
#   'otherGames.global_sales': 6.59},
#  {'otherGames.name': 'The Legend of Zelda', 'otherGames.global_sales': 6.51},
#  {'otherGames.name': 'Pokémon Emerald Version',
#   'otherGames.global_sales': 6.41},
#  {'otherGames.name': 'Pokémon Crystal Version',
#   'otherGames.global_sales': 6.39},
#  {'otherGames.name': 'Super Mario Sunshine', 'otherGames.global_sales': 6.31},
#  {'otherGames.name': 'Dragon Quest IX: Sentinels of the Starry Skies',
#   'otherGames.global_sales': 5.84},
#  {'otherGames.name': 'Tetris', 'otherGames.global_sales': 5.58},
#  {'otherGames.name': 'Super Smash Bros.', 'otherGames.global_sales': 5.55},
#  {'otherGames.name': 'Super Mario Advance', 'otherGames.global_sales': 5.49},
#  {'otherGames.name': 'Mario Kart: Super Circuit',
#   'otherGames.global_sales': 5.47},
#  {'otherGames.name': 'Super Mario World', 'otherGames.global_sales': 5.46},
#  {'otherGames.name': 'Pokemon Stadium', 'otherGames.global_sales': 5.45},
#  {'otherGames.name': 'Dr. Mario', 'otherGames.global_sales': 5.34},
#  {'otherGames.name': 'Pokemon Pinball', 'otherGames.global_sales': 5.31},
#  {'otherGames.name': 'Donkey Kong 64', 'otherGames.global_sales': 5.27},
#  {'otherGames.name': 'Professor Layton and the Curious Village',
#   'otherGames.global_sales': 5.26},
#  {'otherGames.name': 'Super Mario Bros. 3', 'otherGames.global_sales': 5.2},
#  {'otherGames.name': 'New Super Mario Bros. U',
#   'otherGames.global_sales': 5.19},
#  {'otherGames.name': 'Super Mario Land 3: Wario Land',
#   'otherGames.global_sales': 5.19},
#  {'otherGames.name': 'The Legend of Zelda: Phantom Hourglass',
#   'otherGames.global_sales': 5.17},
#  {'otherGames.name': "Donkey Kong Country 2: Diddy's Kong Quest",
#   'otherGames.global_sales': 5.15},
#  {'otherGames.name': 'Tomodachi Life', 'otherGames.global_sales': 5.15},
#  {'otherGames.name': "Kirby's Dream Land", 'otherGames.global_sales': 5.13},
#  {'otherGames.name': 'Super Mario Bros.', 'otherGames.global_sales': 5.07},
#  {'otherGames.name': 'Super Smash Bros. for Wii U and 3DS',
#   'otherGames.global_sales': 5.02},
#  {'otherGames.name': "Link's Crossbow Training",
#   'otherGames.global_sales': 5.0},
#  {'otherGames.name': 'Pokemon Mystery Dungeon: Explorers of Time/Explorers of Darkness',
#   'otherGames.global_sales': 4.96},
#  {'otherGames.name': 'Diddy Kong Racing', 'otherGames.global_sales': 4.88},
#  {'otherGames.name': 'Dr. Mario', 'otherGames.global_sales': 4.85},
#  {'otherGames.name': 'Animal Crossing: City Folk',
#   'otherGames.global_sales': 4.68},
#  {'otherGames.name': 'The Legend of Zelda: A Link to the Past',
#   'otherGames.global_sales': 4.61},
#  {'otherGames.name': 'The Legend of Zelda: The Wind Waker',
#   'otherGames.global_sales': 4.6},
#  {'otherGames.name': "Luigi's Mansion: Dark Moon",
#   'otherGames.global_sales': 4.58},
#  {'otherGames.name': 'Splatoon', 'otherGames.global_sales': 4.57},
#  {'otherGames.name': 'Nintendo Land', 'otherGames.global_sales': 4.44},
#  {'otherGames.name': 'Zelda II: The Adventure of Link',
#   'otherGames.global_sales': 4.38},
#  {'otherGames.name': 'Super Mario 3D World', 'otherGames.global_sales': 4.25},
#  {'otherGames.name': 'The Legend of Zelda: Ocarina of Time',
#   'otherGames.global_sales': 4.21},
#  {'otherGames.name': 'Excitebike', 'otherGames.global_sales': 4.16},
#  {'otherGames.name': "Super Mario World 2: Yoshi's Island",
#   'otherGames.global_sales': 4.12},
#  {'otherGames.name': 'The Legend of Zelda: Skyward Sword',
#   'otherGames.global_sales': 4.1},
#  {'otherGames.name': 'Star Fox 64', 'otherGames.global_sales': 4.03},
#  {'otherGames.name': 'Golf', 'otherGames.global_sales': 4.01},
#  {'otherGames.name': 'Professor Layton and the Diabolical Box',
#   'otherGames.global_sales': 4.0},
#  {'otherGames.name': 'Donkey Kong Land', 'otherGames.global_sales': 3.91},
#  {'otherGames.name': 'Monster Hunter 4 Ultimate',
#   'otherGames.global_sales': 3.89},
#  {'otherGames.name': 'Flash Focus: Vision Training in Minutes a Day',
#   'otherGames.global_sales': 3.84},
#  {'otherGames.name': "The Legend of Zelda: Link's Awakening",
#   'otherGames.global_sales': 3.83},
#  {'otherGames.name': "Mario & Luigi: Bowser's Inside Story",
#   'otherGames.global_sales': 3.83},
#  {'otherGames.name': 'Big Brain Academy: Wii Degree',
#   'otherGames.global_sales': 3.82},
#  {'otherGames.name': 'Nintendogs + cats', 'otherGames.global_sales': 3.81},
#  {'otherGames.name': 'Super Paper Mario', 'otherGames.global_sales': 3.76},
#  {'otherGames.name': 'Pokémon Trading Card Game',
#   'otherGames.global_sales': 3.7},
#  {'otherGames.name': 'Friend Collection', 'otherGames.global_sales': 3.67},
#  {'otherGames.name': 'Banjo-Kazooie', 'otherGames.global_sales': 3.65},
#  {'otherGames.name': 'Pokemon Snap', 'otherGames.global_sales': 3.63},
#  {'otherGames.name': "Luigi's Mansion", 'otherGames.global_sales': 3.6},
#  {'otherGames.name': "Donkey Kong Country 3: Dixie Kong's Double Trouble!",
#   'otherGames.global_sales': 3.51},
#  {'otherGames.name': 'Kung Fu', 'otherGames.global_sales': 3.5},
#  {'otherGames.name': 'Clubhouse Games', 'otherGames.global_sales': 3.5},
#  {'otherGames.name': 'F-1 Race', 'otherGames.global_sales': 3.41},
#  {'otherGames.name': 'The Legend of Zelda: Spirit Tracks',
#   'otherGames.global_sales': 3.38},
#  {'otherGames.name': "The Legend of Zelda: Majora's Mask",
#   'otherGames.global_sales': 3.36},
#  {'otherGames.name': 'Professor Layton and the Unwound Future',
#   'otherGames.global_sales': 3.36},
#  {'otherGames.name': 'English Training: Have Fun Improving Your Skills!',
#   'otherGames.global_sales': 3.33},
#  {'otherGames.name': 'Mario Party 9', 'otherGames.global_sales': 3.32},
#  {'otherGames.name': 'Wii Music', 'otherGames.global_sales': 3.27},
#  {'otherGames.name': 'Yokai Watch 2 Ganso/Honke',
#   'otherGames.global_sales': 3.22},
#  {'otherGames.name': 'Baseball', 'otherGames.global_sales': 3.2},
#  {'otherGames.name': 'Killer Instinct', 'otherGames.global_sales': 3.2},
#  {'otherGames.name': 'Super Mario Maker', 'otherGames.global_sales': 3.18},
#  {'otherGames.name': 'Rhythm Heaven', 'otherGames.global_sales': 3.17},
#  {'otherGames.name': 'Animal Crossing', 'otherGames.global_sales': 3.15},
#  {'otherGames.name': 'Star Wars Episode I Racer',
#   'otherGames.global_sales': 3.12},
#  {'otherGames.name': 'Personal Trainer: Cooking',
#   'otherGames.global_sales': 3.12},
#  {'otherGames.name': 'The Legend of Zelda: A Link Between Worlds',
#   'otherGames.global_sales': 3.07},
#  {'otherGames.name': 'Donkey Kong', 'otherGames.global_sales': 3.07},
#  {'otherGames.name': "Mike Tyson's Punch-Out!!",
#   'otherGames.global_sales': 3.02},
#  {'otherGames.name': 'Star Fox', 'otherGames.global_sales': 2.99},
#  {'otherGames.name': 'Animal Crossing: Happy Home Designer',
#   'otherGames.global_sales': 2.98},
#  {'otherGames.name': 'Kirby Super Star Ultra',
#   'otherGames.global_sales': 2.96},
#  {'otherGames.name': 'Wave Race 64', 'otherGames.global_sales': 2.94},
#  {'otherGames.name': 'WarioWare: Smooth Moves',
#   'otherGames.global_sales': 2.92},
#  {'otherGames.name': "Super Mario World 2: Yoshi's Island",
#   'otherGames.global_sales': 2.91},
#  {'otherGames.name': 'F-Zero', 'otherGames.global_sales': 2.85},
#  {'otherGames.name': "Yoshi's Story", 'otherGames.global_sales': 2.85},
#  {'otherGames.name': 'Metroid Prime', 'otherGames.global_sales': 2.82},
#  {'otherGames.name': "Yoshi's Island DS", 'otherGames.global_sales': 2.8},
#  {'otherGames.name': 'Professor Layton and the Last Specter',
#   'otherGames.global_sales': 2.79},
#  {'otherGames.name': 'Monster Hunter Tri', 'otherGames.global_sales': 2.79},
#  {'otherGames.name': 'Mario Paint', 'otherGames.global_sales': 2.75},
#  {'otherGames.name': 'Pokémon Stadium 2', 'otherGames.global_sales': 2.73},
#  {'otherGames.name': 'Metroid', 'otherGames.global_sales': 2.73},
#  {'otherGames.name': 'The Legend of Zelda: A Link to the Past',
#   'otherGames.global_sales': 2.7},
#  {'otherGames.name': 'Mario Party', 'otherGames.global_sales': 2.7},
#  {'otherGames.name': 'Mario vs. Donkey Kong: Mini-Land Mayhem!',
#   'otherGames.global_sales': 2.69},
#  {'otherGames.name': 'Super Mario Bros.: The Lost Levels',
#   'otherGames.global_sales': 2.65},
#  {'otherGames.name': 'Star Wars: Shadows of the Empire',
#   'otherGames.global_sales': 2.65},
#  {'otherGames.name': 'Mario Strikers Charged',
#   'otherGames.global_sales': 2.62},
#  {'otherGames.name': 'Style Savvy', 'otherGames.global_sales': 2.61},
#  {'otherGames.name': 'Super Mario All-Stars: Limited Edition',
#   'otherGames.global_sales': 2.6},
#  {'otherGames.name': 'Art Academy', 'otherGames.global_sales': 2.57},
#  {'otherGames.name': 'Pokémon Colosseum', 'otherGames.global_sales': 2.54},
#  {'otherGames.name': 'Perfect Dark', 'otherGames.global_sales': 2.52},
#  {'otherGames.name': 'Mario Party 2', 'otherGames.global_sales': 2.5},
#  {'otherGames.name': 'Mario Party 4', 'otherGames.global_sales': 2.47},
#  {'otherGames.name': 'Ice Hockey', 'otherGames.global_sales': 2.42},
#  {'otherGames.name': 'Pro Wrestling', 'otherGames.global_sales': 2.4},
#  {'otherGames.name': "Kirby's Dream Land 2", 'otherGames.global_sales': 2.36},
#  {'otherGames.name': 'Donkey Kong Land II', 'otherGames.global_sales': 2.35},
#  {'otherGames.name': "The Legend of Zelda: Majora's Mask 3D",
#   'otherGames.global_sales': 2.32},
#  {'otherGames.name': 'Mario Tennis', 'otherGames.global_sales': 2.32},
#  {'otherGames.name': 'WarioWare Touched!', 'otherGames.global_sales': 2.31},
#  {'otherGames.name': 'Pokemon Ranger: Shadows of Almia',
#   'otherGames.global_sales': 2.3},
#  {'otherGames.name': 'Mario Bros.', 'otherGames.global_sales': 2.28},
#  {'otherGames.name': 'Paper Mario: Sticker Star',
#   'otherGames.global_sales': 2.27},
#  {'otherGames.name': 'Kirby: Nightmare in Dream Land',
#   'otherGames.global_sales': 2.27},
#  {'otherGames.name': 'Wario Land 4', 'otherGames.global_sales': 2.26},
#  {'otherGames.name': 'Paper Mario: The Thousand-Year Door',
#   'otherGames.global_sales': 2.25},
#  {'otherGames.name': 'Monster Hunter Tri', 'otherGames.global_sales': 2.25},
#  {'otherGames.name': 'New Super Luigi U', 'otherGames.global_sales': 2.22},
#  {'otherGames.name': "The Legend of Zelda: Link's Awakening DX",
#   'otherGames.global_sales': 2.22},
#  {'otherGames.name': 'Wario Land 3', 'otherGames.global_sales': 2.2},
#  {'otherGames.name': "Kirby's Pinball Land", 'otherGames.global_sales': 2.19},
#  {'otherGames.name': 'Donkey Kong Country', 'otherGames.global_sales': 2.19},
#  {'otherGames.name': 'Pokemon Ranger', 'otherGames.global_sales': 2.18},
#  {'otherGames.name': 'Mario & Luigi: Superstar Saga',
#   'otherGames.global_sales': 2.17},
#  {'otherGames.name': 'Star Wars: Rogue Squadron',
#   'otherGames.global_sales': 2.17},
#  {'otherGames.name': 'Tennis', 'otherGames.global_sales': 2.17},
#  {'otherGames.name': 'Volleyball', 'otherGames.global_sales': 2.15},
#  {'otherGames.name': 'Super Mario RPG: Legend of the Seven Stars',
#   'otherGames.global_sales': 2.14},
#  {'otherGames.name': 'Mahjong', 'otherGames.global_sales': 2.14},
#  {'otherGames.name': 'R.C. Pro-Am', 'otherGames.global_sales': 2.14},
#  {'otherGames.name': 'Tetris DS', 'otherGames.global_sales': 2.13},
#  {'otherGames.name': "Kirby's Epic Yarn", 'otherGames.global_sales': 2.12},
#  {'otherGames.name': 'Golf', 'otherGames.global_sales': 2.12},
#  {'otherGames.name': 'Mario Sports Mix', 'otherGames.global_sales': 2.11},
#  {'otherGames.name': 'Mario Party 5', 'otherGames.global_sales': 2.08},
#  {'otherGames.name': 'Pokemon Mystery Dungeon: Red/Blue Rescue Team',
#   'otherGames.global_sales': 2.06},
#  {'otherGames.name': 'Mario & Luigi: Dream Team',
#   'otherGames.global_sales': 2.06},
#  {'otherGames.name': 'Pokémon Mystery Dungeon: Blue Rescue Team',
#   'otherGames.global_sales': 2.05},
#  {'otherGames.name': 'Donkey Kong Country', 'otherGames.global_sales': 2.04},
#  {'otherGames.name': '1080°: TenEighty Snowboarding',
#   'otherGames.global_sales': 2.03},
#  {'otherGames.name': 'Fire Emblem: Awakening', 'otherGames.global_sales': 2.0},
#  {'otherGames.name': 'Super Street Fighter II',
#   'otherGames.global_sales': 2.0},
#  {'otherGames.name': 'Tennis', 'otherGames.global_sales': 1.99},
#  {'otherGames.name': 'SimCity', 'otherGames.global_sales': 1.98},
#  {'otherGames.name': 'Rad Racer', 'otherGames.global_sales': 1.96},
#  {'otherGames.name': 'Soccer', 'otherGames.global_sales': 1.96},
#  {'otherGames.name': 'Kirby Squeak Squad', 'otherGames.global_sales': 1.96},
#  {'otherGames.name': 'Alleyway', 'otherGames.global_sales': 1.94},
#  {'otherGames.name': 'Tetris DX', 'otherGames.global_sales': 1.93},
#  {'otherGames.name': 'Mario Super Sluggers', 'otherGames.global_sales': 1.93},
#  {'otherGames.name': 'The Legend of Zelda: Oracle of Ages',
#   'otherGames.global_sales': 1.92},
#  {'otherGames.name': 'Mario Party 3', 'otherGames.global_sales': 1.91},
#  {'otherGames.name': 'Yokai Watch', 'otherGames.global_sales': 1.89},
#  {'otherGames.name': 'Star Fox Adventures', 'otherGames.global_sales': 1.87},
#  {'otherGames.name': 'Donkey Kong Country Returns',
#   'otherGames.global_sales': 1.87},
#  {'otherGames.name': 'The Legend of Zelda: Oracle of Seasons',
#   'otherGames.global_sales': 1.86},
#  {'otherGames.name': 'Mario Party: Island Tour',
#   'otherGames.global_sales': 1.85},
#  {'otherGames.name': 'Pinball', 'otherGames.global_sales': 1.85},
#  {'otherGames.name': 'Hey You, Pikachu!', 'otherGames.global_sales': 1.83},
#  {'otherGames.name': 'Kirby: Triple Deluxe', 'otherGames.global_sales': 1.82},
#  {'otherGames.name': 'Metroid Prime 3: Corruption',
#   'otherGames.global_sales': 1.82},
#  {'otherGames.name': 'Dragon Quest VI: Realms of Revelation',
#   'otherGames.global_sales': 1.81},
#  {'otherGames.name': 'Professor Layton and the Mask of Miracle',
#   'otherGames.global_sales': 1.78},
#  {'otherGames.name': 'The Legend of Zelda: The Wind Waker',
#   'otherGames.global_sales': 1.77},
#  {'otherGames.name': 'Wii Party U', 'otherGames.global_sales': 1.77},
#  {'otherGames.name': 'Kirby 64: The Crystal Shards',
#   'otherGames.global_sales': 1.77},
#  {'otherGames.name': 'Metroid II: Return of Samus',
#   'otherGames.global_sales': 1.76},
#  {'otherGames.name': 'Golden Sun', 'otherGames.global_sales': 1.76},
#  {'otherGames.name': 'Kid Icarus', 'otherGames.global_sales': 1.76},
#  {'otherGames.name': 'Yoshi', 'otherGames.global_sales': 1.75},
#  {'otherGames.name': "Kirby's Adventure", 'otherGames.global_sales': 1.75},
#  {'otherGames.name': "Cruis'n USA", 'otherGames.global_sales': 1.74},
#  {'otherGames.name': 'Kanshuu Nippon Joushikiryoku Kentei Kyoukai: Imasara Hito ni wa Kikenai Otona no Joushikiryoku Training DS',
#   'otherGames.global_sales': 1.71},
#  {'otherGames.name': 'Personal Trainer: Math', 'otherGames.global_sales': 1.7},
#  {'otherGames.name': "Kirby's Return to Dreamland",
#   'otherGames.global_sales': 1.7},
#  {'otherGames.name': "Yoshi's Cookie", 'otherGames.global_sales': 1.68},
#  {'otherGames.name': 'Metroid Fusion', 'otherGames.global_sales': 1.68},
#  {'otherGames.name': 'Mario Party 6', 'otherGames.global_sales': 1.65},
#  {'otherGames.name': 'Super Scope 6', 'otherGames.global_sales': 1.65},
#  {'otherGames.name': 'Kirby & the Amazing Mirror',
#   'otherGames.global_sales': 1.64},
#  {'otherGames.name': 'Pikmin', 'otherGames.global_sales': 1.63},
#  {'otherGames.name': 'Mario Hoops 3 on 3', 'otherGames.global_sales': 1.62},
#  {'otherGames.name': 'Kirby Air Ride', 'otherGames.global_sales': 1.62},
#  {'otherGames.name': 'Pokemon Battle Revolution',
#   'otherGames.global_sales': 1.61},
#  {'otherGames.name': 'Baseball', 'otherGames.global_sales': 1.61},
#  {'otherGames.name': 'Super Mario Strikers', 'otherGames.global_sales': 1.61},
#  {'otherGames.name': 'The Legend of Zelda: Twilight Princess',
#   'otherGames.global_sales': 1.59},
#  {'otherGames.name': 'Pokemon Mystery Dungeon: Explorers of Sky',
#   'otherGames.global_sales': 1.58},
#  {'otherGames.name': 'Mario Party 7', 'otherGames.global_sales': 1.57},
#  {'otherGames.name': 'Donkey Kong Classics', 'otherGames.global_sales': 1.56},
#  {'otherGames.name': 'Pokemon Pinball: Ruby & Sapphire',
#   'otherGames.global_sales': 1.56},
#  {'otherGames.name': 'Mario Party 10', 'otherGames.global_sales': 1.55},
#  {'otherGames.name': 'Fire Emblem Fates', 'otherGames.global_sales': 1.54},
#  {'otherGames.name': 'Mario Golf: Toadstool Tour',
#   'otherGames.global_sales': 1.53},
#  {'otherGames.name': 'Donkey Kong Country: Tropical Freeze',
#   'otherGames.global_sales': 1.52},
#  {'otherGames.name': 'F1 Race', 'otherGames.global_sales': 1.52},
#  {'otherGames.name': 'Ice Climber', 'otherGames.global_sales': 1.5},
#  {'otherGames.name': 'Final Fantasy: Crystal Chronicles',
#   'otherGames.global_sales': 1.49},
#  {'otherGames.name': 'Banjo-Tooie', 'otherGames.global_sales': 1.49},
#  {'otherGames.name': 'New Play Control! Mario Power Tennis',
#   'otherGames.global_sales': 1.48},
#  {'otherGames.name': 'Nintendo World Cup', 'otherGames.global_sales': 1.48},
#  {'otherGames.name': 'Wario Land II', 'otherGames.global_sales': 1.48},
#  {'otherGames.name': 'Mario Golf', 'otherGames.global_sales': 1.47},
#  {'otherGames.name': 'Mario Superstar Baseball',
#   'otherGames.global_sales': 1.46},
#  {'otherGames.name': 'LEGO City Undercover', 'otherGames.global_sales': 1.46},
#  {'otherGames.name': '4 Nin uchi Mahjong', 'otherGames.global_sales': 1.45},
#  {'otherGames.name': 'Kirby Super Star', 'otherGames.global_sales': 1.44},
#  {'otherGames.name': 'Classic NES Series: Super Mario Bros.',
#   'otherGames.global_sales': 1.43},
#  {'otherGames.name': 'The Legend of Zelda: The Minish Cap',
#   'otherGames.global_sales': 1.42},
#  {'otherGames.name': 'Super Metroid', 'otherGames.global_sales': 1.42},
#  {'otherGames.name': 'Inazuma Eleven 2', 'otherGames.global_sales': 1.42},
#  {'otherGames.name': 'Metroid: Other M', 'otherGames.global_sales': 1.41},
#  {'otherGames.name': 'Paper Mario', 'otherGames.global_sales': 1.38},
#  {'otherGames.name': 'Bravely Default: Flying Fairy',
#   'otherGames.global_sales': 1.38},
#  {'otherGames.name': 'Pocket Monsters Stadium',
#   'otherGames.global_sales': 1.37},
#  {'otherGames.name': "Yoshi's New Island", 'otherGames.global_sales': 1.36},
#  {'otherGames.name': 'Mario & Luigi: Partners in Time',
#   'otherGames.global_sales': 1.34},
#  {'otherGames.name': 'Donkey Kong Jungle Beat',
#   'otherGames.global_sales': 1.34},
#  {'otherGames.name': 'Metroid Prime 2: Echoes',
#   'otherGames.global_sales': 1.33},
#  {'otherGames.name': 'Pokemon Ranger: Guardian Signs',
#   'otherGames.global_sales': 1.33},
#  {'otherGames.name': 'Gyromite', 'otherGames.global_sales': 1.32},
#  {'otherGames.name': "Yoshi's Woolly World", 'otherGames.global_sales': 1.29},
#  {'otherGames.name': 'Mystery Case Files: MillionHeir',
#   'otherGames.global_sales': 1.29},
#  {'otherGames.name': 'Yakuman', 'otherGames.global_sales': 1.28},
#  {'otherGames.name': 'Kid Icarus: Uprising', 'otherGames.global_sales': 1.28},
#  {'otherGames.name': 'Pokemon Mystery Dungeon: Gates to Infinity',
#   'otherGames.global_sales': 1.27},
#  {'otherGames.name': "Hogan's Alley", 'otherGames.global_sales': 1.27},
#  {'otherGames.name': 'Hyrule Warriors', 'otherGames.global_sales': 1.26},
#  {'otherGames.name': 'Pokemon XD: Gale of Darkness',
#   'otherGames.global_sales': 1.25},
#  {'otherGames.name': 'Diddy Kong Racing DS', 'otherGames.global_sales': 1.24},
#  {'otherGames.name': 'Tetris 2 (All region sales)',
#   'otherGames.global_sales': 1.24},
#  {'otherGames.name': "Kirby Tilt 'n' Tumble", 'otherGames.global_sales': 1.23},
#  {'otherGames.name': 'Donkey Kong Country 2', 'otherGames.global_sales': 1.23},
#  {'otherGames.name': 'WarioWare, Inc.: Mega MicroGame$',
#   'otherGames.global_sales': 1.23},
#  {'otherGames.name': 'Mario Power Tennis', 'otherGames.global_sales': 1.22},
#  {'otherGames.name': 'Game & Watch Gallery 2',
#   'otherGames.global_sales': 1.22},
#  {'otherGames.name': 'Game & Watch Gallery 3',
#   'otherGames.global_sales': 1.22},
#  {'otherGames.name': 'Golden Sun: The Lost Age',
#   'otherGames.global_sales': 1.22},
#  {'otherGames.name': 'Pikmin 2', 'otherGames.global_sales': 1.2},
#  {'otherGames.name': 'SolarStriker', 'otherGames.global_sales': 1.2},
#  {'otherGames.name': 'Mario vs. Donkey Kong 2: March of the Minis',
#   'otherGames.global_sales': 1.2},
#  {'otherGames.name': "PokéPark Wii: Pikachu's Adventure",
#   'otherGames.global_sales': 1.2},
#  {'otherGames.name': 'Captain Toad: Treasure Tracker',
#   'otherGames.global_sales': 1.19},
#  {'otherGames.name': 'Kobe Bryant in NBA Courtside',
#   'otherGames.global_sales': 1.19},
#  {'otherGames.name': 'Final Fantasy I & II: Dawn of Souls',
#   'otherGames.global_sales': 1.19},
#  {'otherGames.name': 'Pokemon Super Mystery Dungeon',
#   'otherGames.global_sales': 1.19},
#  {'otherGames.name': 'Mario Tennis', 'otherGames.global_sales': 1.18},
#  {'otherGames.name': 'Wario Land: Shake It!', 'otherGames.global_sales': 1.17},
#  {'otherGames.name': 'Mario vs. Donkey Kong', 'otherGames.global_sales': 1.17},
#  {'otherGames.name': 'Jet Force Gemini', 'otherGames.global_sales': 1.16},
#  {'otherGames.name': 'Qix', 'otherGames.global_sales': 1.15},
#  {'otherGames.name': 'Donkey Konga', 'otherGames.global_sales': 1.15},
#  {'otherGames.name': 'Pokemon Rumble Blast', 'otherGames.global_sales': 1.14},
#  {'otherGames.name': 'Pilotwings', 'otherGames.global_sales': 1.14},
#  {'otherGames.name': 'Super R.C. Pro-Am', 'otherGames.global_sales': 1.14},
#  {'otherGames.name': 'Fantasy Life', 'otherGames.global_sales': 1.13},
#  {'otherGames.name': 'Donkey Kong', 'otherGames.global_sales': 1.13},
#  {'otherGames.name': 'Pokémon Mystery Dungeon: Red Rescue Team (US weekly sales)',
#   'otherGames.global_sales': 1.13},
#  {'otherGames.name': 'Pilotwings 64', 'otherGames.global_sales': 1.12},
#  {'otherGames.name': "Yoshi's Cookie", 'otherGames.global_sales': 1.12},
#  {'otherGames.name': 'Donkey Kong Jr.', 'otherGames.global_sales': 1.11},
#  {'otherGames.name': 'Pikmin 3', 'otherGames.global_sales': 1.11},
#  {'otherGames.name': 'The Legend of Zelda: Tri Force Heroes',
#   'otherGames.global_sales': 1.1},
#  {'otherGames.name': 'F-Zero X', 'otherGames.global_sales': 1.1},
#  {'otherGames.name': 'Popeye', 'otherGames.global_sales': 1.1},
#  {'otherGames.name': 'Tales of Symphonia', 'otherGames.global_sales': 1.1},
#  {'otherGames.name': 'Endless Ocean', 'otherGames.global_sales': 1.09},
#  {'otherGames.name': 'LEGO City Undercover', 'otherGames.global_sales': 1.08},
#  {'otherGames.name': 'Star Fox: Assault', 'otherGames.global_sales': 1.08},
#  {'otherGames.name': 'Super Princess Peach', 'otherGames.global_sales': 1.07},
#  {'otherGames.name': 'Pokemon Conquest', 'otherGames.global_sales': 1.05},
#  {'otherGames.name': 'Naruto: Clash of Ninja 2',
#   'otherGames.global_sales': 1.04},
#  {'otherGames.name': 'F-Zero: Maximum Velocity',
#   'otherGames.global_sales': 1.04},
#  {'otherGames.name': 'Kirby: Mass Attack', 'otherGames.global_sales': 1.04},
#  {'otherGames.name': 'Donkey Kong Land III', 'otherGames.global_sales': 1.03},
#  {'otherGames.name': 'Bayonetta 2', 'otherGames.global_sales': 1.01},
#  {'otherGames.name': 'Excitebike 64', 'otherGames.global_sales': 1.0},
#  {'otherGames.name': 'NES Open Tournament Golf',
#   'otherGames.global_sales': 1.0},
#  {'otherGames.name': 'Game & Watch Gallery', 'otherGames.global_sales': 1.0},
#  {'otherGames.name': 'Xenoblade Chronicles', 'otherGames.global_sales': 0.98},
#  {'otherGames.name': 'Mario Party Advance', 'otherGames.global_sales': 0.98},
#  {'otherGames.name': 'Tetris 2', 'otherGames.global_sales': 0.98},
#  {'otherGames.name': 'Fire Emblem', 'otherGames.global_sales': 0.97},
#  {'otherGames.name': 'PilotWings Resort', 'otherGames.global_sales': 0.96},
#  {'otherGames.name': 'Wii Play: Motion', 'otherGames.global_sales': 0.95},
#  {'otherGames.name': 'Star Fox 64 3D', 'otherGames.global_sales': 0.94},
#  {'otherGames.name': 'Mario Tennis Open', 'otherGames.global_sales': 0.94},
#  {'otherGames.name': 'The Legend of Zelda: Twilight Princess HD',
#   'otherGames.global_sales': 0.94},
#  {'otherGames.name': 'Balloon Fight', 'otherGames.global_sales': 0.92},
#  {'otherGames.name': 'Disney Magical World', 'otherGames.global_sales': 0.92},
#  {'otherGames.name': 'Fossil Fighters', 'otherGames.global_sales': 0.9},
#  {'otherGames.name': 'Classic NES Series: The Legend of Zelda',
#   'otherGames.global_sales': 0.89},
#  {'otherGames.name': 'Fire Emblem: The Sacred Stones',
#   'otherGames.global_sales': 0.89},
#  {'otherGames.name': 'Pokemon Card GB2: Here Comes Team GR!',
#   'otherGames.global_sales': 0.89},
#  {'otherGames.name': 'Wii Fit U', 'otherGames.global_sales': 0.89},
#  {'otherGames.name': 'Endless Ocean: Blue World',
#   'otherGames.global_sales': 0.88},
#  {'otherGames.name': 'The Legendary Starfy', 'otherGames.global_sales': 0.86},
#  {'otherGames.name': 'Kirby: Planet Robobot', 'otherGames.global_sales': 0.85},
#  {'otherGames.name': 'Golden Sun: Dark Dawn', 'otherGames.global_sales': 0.84},
#  {'otherGames.name': 'Xenoblade Chronicles X',
#   'otherGames.global_sales': 0.84},
#  {'otherGames.name': 'Metroid: Zero Mission', 'otherGames.global_sales': 0.84},
#  {'otherGames.name': 'Clu Clu Land', 'otherGames.global_sales': 0.82},
#  {'otherGames.name': 'Killer Instinct Gold', 'otherGames.global_sales': 0.82},
#  {'otherGames.name': 'The Legend of Zelda: Four Swords Adventures',
#   'otherGames.global_sales': 0.81},
#  {'otherGames.name': 'EarthBound', 'otherGames.global_sales': 0.81},
#  {'otherGames.name': 'Mario & Sonic at the Sochi 2014 Olympic Winter Games',
#   'otherGames.global_sales': 0.8},
#  {'otherGames.name': "Capcom's Soccer Shootout",
#   'otherGames.global_sales': 0.8},
#  {'otherGames.name': 'Major League Baseball Featuring Ken Griffey Jr',
#   'otherGames.global_sales': 0.79},
#  {'otherGames.name': 'Personal Trainer: Walking',
#   'otherGames.global_sales': 0.79},
#  {'otherGames.name': 'PokePark 2: Wonders Beyond',
#   'otherGames.global_sales': 0.79},
#  {'otherGames.name': 'Professor Layton and the Azran Legacy',
#   'otherGames.global_sales': 0.78},
#  {'otherGames.name': 'Metroid Prime Hunters', 'otherGames.global_sales': 0.78},
#  {'otherGames.name': 'Tetris Party Deluxe', 'otherGames.global_sales': 0.78},
#  {'otherGames.name': 'Pokemon Dash', 'otherGames.global_sales': 0.77},
#  {'otherGames.name': 'Donkey Kong Country 3', 'otherGames.global_sales': 0.77},
#  {'otherGames.name': 'Jump Ultimate Stars', 'otherGames.global_sales': 0.74},
#  {'otherGames.name': 'Mario & Luigi: Paper Jam',
#   'otherGames.global_sales': 0.74},
#  {'otherGames.name': 'Sword of Mana', 'otherGames.global_sales': 0.74},
#  {'otherGames.name': 'Classic NES Series: Donkey Kong',
#   'otherGames.global_sales': 0.73},
#  {'otherGames.name': 'Yoshi', 'otherGames.global_sales': 0.73},
#  {'otherGames.name': 'Kirby: Canvas Curse', 'otherGames.global_sales': 0.73},
#  {'otherGames.name': 'Practise English!', 'otherGames.global_sales': 0.73},
#  {'otherGames.name': 'Just Dance Wii', 'otherGames.global_sales': 0.73},
#  {'otherGames.name': 'Style Savvy: Trendsetters',
#   'otherGames.global_sales': 0.72},
#  {'otherGames.name': 'Monster Hunter Tri', 'otherGames.global_sales': 0.72},
#  {'otherGames.name': 'Rhythm Heaven: The Best+',
#   'otherGames.global_sales': 0.71},
#  {'otherGames.name': 'Blast Corps', 'otherGames.global_sales': 0.71},
#  {'otherGames.name': 'WarioWare, Inc.: Mega Party Game$',
#   'otherGames.global_sales': 0.71},
#  {'otherGames.name': 'Advance Wars', 'otherGames.global_sales': 0.7},
#  {'otherGames.name': 'Classic NES Series: Zelda II: The Adventure of Link',
#   'otherGames.global_sales': 0.7},
#  {'otherGames.name': 'Fire Emblem: Monsh? no Nazo',
#   'otherGames.global_sales': 0.7},
#  {'otherGames.name': 'Mario Pinball Land', 'otherGames.global_sales': 0.69},
#  {'otherGames.name': 'Nintendo Presents: New Style Boutique 2 - Fashion Forward',
#   'otherGames.global_sales': 0.69},
#  {'otherGames.name': "Kirby's Dream Collection: Special Edition",
#   'otherGames.global_sales': 0.68},
#  {'otherGames.name': 'The Last Story', 'otherGames.global_sales': 0.68},
#  {'otherGames.name': 'Fossil Fighters: Champions',
#   'otherGames.global_sales': 0.68},
#  {'otherGames.name': '100 Classic Books', 'otherGames.global_sales': 0.67},
#  {'otherGames.name': 'Wario: Master of Disguise',
#   'otherGames.global_sales': 0.66},
#  {'otherGames.name': 'New Play Control! Pikmin',
#   'otherGames.global_sales': 0.66},
#  {'otherGames.name': 'F-Zero GX', 'otherGames.global_sales': 0.65},
#  {'otherGames.name': 'Yoshi Topsy-Turvy', 'otherGames.global_sales': 0.65},
#  {'otherGames.name': 'Advance Wars 2: Black Hole Rising',
#   'otherGames.global_sales': 0.65},
#  {'otherGames.name': 'Fire Emblem: Shadow Dragon',
#   'otherGames.global_sales': 0.65},
#  {'otherGames.name': "Cruis'n World", 'otherGames.global_sales': 0.64},
#  {'otherGames.name': 'Donkey Kong Barrel Blast',
#   'otherGames.global_sales': 0.64},
#  {'otherGames.name': 'Metroid Prime: Trilogy',
#   'otherGames.global_sales': 0.63},
#  {'otherGames.name': 'Advance Wars: Days of Ruin',
#   'otherGames.global_sales': 0.63},
#  {'otherGames.name': "Mario's Picross", 'otherGames.global_sales': 0.62},
#  {'otherGames.name': 'Ganbaru Watashi no Kakei Diary',
#   'otherGames.global_sales': 0.61},
#  {'otherGames.name': 'New Play Control! Donkey Kong Jungle Beat',
#   'otherGames.global_sales': 0.61},
#  {'otherGames.name': 'Final Fantasy IV Advance',
#   'otherGames.global_sales': 0.61},
#  {'otherGames.name': 'Game & Watch Gallery 4',
#   'otherGames.global_sales': 0.61},
#  {'otherGames.name': 'New Play Control! Pikmin 2',
#   'otherGames.global_sales': 0.6},
#  {'otherGames.name': 'Wave Race: Blue Storm', 'otherGames.global_sales': 0.6},
#  {'otherGames.name': 'WarioWare D.I.Y.', 'otherGames.global_sales': 0.6},
#  {'otherGames.name': "Mickey's Speedway USA", 'otherGames.global_sales': 0.6},
#  {'otherGames.name': 'Pokemon Trozei!', 'otherGames.global_sales': 0.6},
#  {'otherGames.name': "Kirby's Dream Course", 'otherGames.global_sales': 0.59},
#  {'otherGames.name': 'Fire Emblem: Seisen no Keifu',
#   'otherGames.global_sales': 0.58},
#  {'otherGames.name': 'Rooms: The Main Building',
#   'otherGames.global_sales': 0.58},
#  {'otherGames.name': 'Tetris Party Deluxe', 'otherGames.global_sales': 0.58},
#  {'otherGames.name': 'The Mysterious Murasame Castle',
#   'otherGames.global_sales': 0.57},
#  {'otherGames.name': 'Donkey Kong Jungle Climber',
#   'otherGames.global_sales': 0.56},
#  {'otherGames.name': 'Classic NES Series: Dr. Mario',
#   'otherGames.global_sales': 0.56},
#  {'otherGames.name': 'Hotel Dusk: Room 215', 'otherGames.global_sales': 0.56},
#  {'otherGames.name': 'Xenoblade Chronicles', 'otherGames.global_sales': 0.56},
#  {'otherGames.name': 'Hamtaro: Ham-Hams Unite!',
#   'otherGames.global_sales': 0.56},
#  {'otherGames.name': 'DS Bimoji Training', 'otherGames.global_sales': 0.56},
#  {'otherGames.name': 'Jump Super Stars', 'otherGames.global_sales': 0.55},
#  {'otherGames.name': 'Excite Truck', 'otherGames.global_sales': 0.54},
#  {'otherGames.name': 'Inazuma Eleven', 'otherGames.global_sales': 0.54},
#  {'otherGames.name': 'Fire Emblem: Path of Radiance',
#   'otherGames.global_sales': 0.54},
#  {'otherGames.name': 'Star Fox Command', 'otherGames.global_sales': 0.54},
#  {'otherGames.name': 'Inazuma Eleven GO', 'otherGames.global_sales': 0.54},
#  {'otherGames.name': 'Kirby and the Rainbow Curse',
#   'otherGames.global_sales': 0.53},
#  {'otherGames.name': 'Picross 3D', 'otherGames.global_sales': 0.53},
#  {'otherGames.name': "Wayne Gretzky's 3D Hockey",
#   'otherGames.global_sales': 0.53},
#  {'otherGames.name': 'Mario Tennis: Power Tour',
#   'otherGames.global_sales': 0.52},
#  {'otherGames.name': 'Naruto Shippuden: Clash of Ninja Revolution 3',
#   'otherGames.global_sales': 0.52},
#  {'otherGames.name': 'Kenkou Ouen Recipe 1000: DS Kondate Zenshuu',
#   'otherGames.global_sales': 0.52},
#  {'otherGames.name': 'Jam With the Band', 'otherGames.global_sales': 0.51},
#  {'otherGames.name': 'Fire Emblem: Radiant Dawn',
#   'otherGames.global_sales': 0.51},
#  {'otherGames.name': 'Wrecking Crew', 'otherGames.global_sales': 0.51},
#  {'otherGames.name': 'Picross DS', 'otherGames.global_sales': 0.51},
#  {'otherGames.name': 'Tactics Ogre: The Knight of Lodis',
#   'otherGames.global_sales': 0.5},
#  {'otherGames.name': 'Fortune Street', 'otherGames.global_sales': 0.5},
#  {'otherGames.name': 'Mario & Wario', 'otherGames.global_sales': 0.49},
#  {'otherGames.name': 'Pokemon Art Academy', 'otherGames.global_sales': 0.49},
#  {'otherGames.name': 'Steel Diver', 'otherGames.global_sales': 0.49},
#  {'otherGames.name': 'Children of Mana', 'otherGames.global_sales': 0.48},
#  {'otherGames.name': 'Mario Golf: World Tour',
#   'otherGames.global_sales': 0.48},
#  {'otherGames.name': 'FlingSmash', 'otherGames.global_sales': 0.48},
#  {'otherGames.name': 'Bravely Second: End Layer',
#   'otherGames.global_sales': 0.47},
#  {'otherGames.name': 'Densetsu no Stafi', 'otherGames.global_sales': 0.47},
#  {'otherGames.name': 'Bomberman Hero', 'otherGames.global_sales': 0.47},
#  {'otherGames.name': 'Dance Dance Revolution: Mario Mix',
#   'otherGames.global_sales': 0.47},
#  {'otherGames.name': 'Classic NES Series: Pac-Man',
#   'otherGames.global_sales': 0.46},
#  {'otherGames.name': 'Art Academy: Lessons for Everyone',
#   'otherGames.global_sales': 0.46},
#  {'otherGames.name': 'Mario & Sonic at the Rio 2016 Olympic Games',
#   'otherGames.global_sales': 0.46},
#  {'otherGames.name': 'Mother 1+2', 'otherGames.global_sales': 0.46},
#  {'otherGames.name': 'Puzzle & Dragons Z + Super Mario Bros. Edition',
#   'otherGames.global_sales': 0.46},
#  {'otherGames.name': 'Samurai Warriors 3', 'otherGames.global_sales': 0.45},
#  {'otherGames.name': 'Pokemon Puzzle League', 'otherGames.global_sales': 0.45},
#  {'otherGames.name': 'Mario Tennis Ultra Smash',
#   'otherGames.global_sales': 0.45},
#  {'otherGames.name': 'Mario Golf: Advance Tour',
#   'otherGames.global_sales': 0.45},
#  {'otherGames.name': 'Densetsu no Stafi 2', 'otherGames.global_sales': 0.44},
#  {'otherGames.name': 'Sin and Punishment: Star Successor',
#   'otherGames.global_sales': 0.44},
#  {'otherGames.name': 'Wario World', 'otherGames.global_sales': 0.44},
#  {'otherGames.name': "Eternal Darkness: Sanity's Requiem",
#   'otherGames.global_sales': 0.44},
#  {'otherGames.name': 'Master of Illusion', 'otherGames.global_sales': 0.44},
#  {'otherGames.name': 'Classic NES Series: Metroid',
#   'otherGames.global_sales': 0.43},
#  {'otherGames.name': 'Mischief Makers', 'otherGames.global_sales': 0.43},
#  {'otherGames.name': 'Famicom Mini: Super Mario Bros. 2',
#   'otherGames.global_sales': 0.42},
#  {'otherGames.name': 'Dr. Mario 64', 'otherGames.global_sales': 0.42},
#  {'otherGames.name': "Zack & Wiki: Quest for Barbaros' Treasure",
#   'otherGames.global_sales': 0.42},
#  {'otherGames.name': 'Animal Crossing: Amiibo Festival',
#   'otherGames.global_sales': 0.42},
#  {'otherGames.name': 'Hyrule Warriors', 'otherGames.global_sales': 0.42},
#  {'otherGames.name': 'Ogre Battle 64: Person of Lordly Caliber',
#   'otherGames.global_sales': 0.41},
#  {'otherGames.name': 'The Wonderful 101', 'otherGames.global_sales': 0.41},
#  {'otherGames.name': 'Mario no Super Picross',
#   'otherGames.global_sales': 0.41},
#  {'otherGames.name': 'Story of Seasons', 'otherGames.global_sales': 0.4},
#  {'otherGames.name': 'Advance Wars: Dual Strike',
#   'otherGames.global_sales': 0.4},
#  {'otherGames.name': 'Battalion Wars', 'otherGames.global_sales': 0.4},
#  {'otherGames.name': 'RR64: Ridge Racer 64', 'otherGames.global_sales': 0.4},
#  {'otherGames.name': 'Mother 3', 'otherGames.global_sales': 0.4},
#  {'otherGames.name': 'Wii Sports Club', 'otherGames.global_sales': 0.4},
#  {'otherGames.name': 'Fire Emblem: Fuuin no Tsurugi',
#   'otherGames.global_sales': 0.39},
#  {'otherGames.name': 'Donkey Konga 2', 'otherGames.global_sales': 0.39},
#  {'otherGames.name': 'Mystery Case Files: The Malgrave Incident',
#   'otherGames.global_sales': 0.39},
#  {'otherGames.name': 'Yoshi Touch & Go', 'otherGames.global_sales': 0.39},
#  {'otherGames.name': 'Custom Robo V2', 'otherGames.global_sales': 0.39},
#  {'otherGames.name': 'Chibi-Robo! Plug into Adventure!',
#   'otherGames.global_sales': 0.39},
#  {'otherGames.name': 'Super Soccer', 'otherGames.global_sales': 0.38},
#  {'otherGames.name': 'Wario Land II (GBC)', 'otherGames.global_sales': 0.38},
#  {'otherGames.name': 'Elite Beat Agents', 'otherGames.global_sales': 0.38},
#  {'otherGames.name': 'Pokemon Channel', 'otherGames.global_sales': 0.38},
#  {'otherGames.name': 'Custom Robo', 'otherGames.global_sales': 0.37},
#  {'otherGames.name': 'Pac-Man World 2', 'otherGames.global_sales': 0.37},
#  {'otherGames.name': 'Trauma Center: Under the Knife',
#   'otherGames.global_sales': 0.37},
#  {'otherGames.name': 'Hamtaro: Ham-Ham Heartbreak',
#   'otherGames.global_sales': 0.36},
#  {'otherGames.name': "Kirby's Dream Land 3", 'otherGames.global_sales': 0.36},
#  {'otherGames.name': 'Tetrisphere', 'otherGames.global_sales': 0.36},
#  {'otherGames.name': 'Trauma Center: Second Opinion',
#   'otherGames.global_sales': 0.35},
#  {'otherGames.name': 'Picross 2', 'otherGames.global_sales': 0.35},
#  {'otherGames.name': 'Battalion Wars 2', 'otherGames.global_sales': 0.35},
#  {'otherGames.name': 'Fossil Fighters: Frontier',
#   'otherGames.global_sales': 0.35},
#  {'otherGames.name': 'Star Fox: Zero', 'otherGames.global_sales': 0.35},
#  {'otherGames.name': 'Stunt Race FX', 'otherGames.global_sales': 0.35},
#  {'otherGames.name': 'Etrian Odyssey', 'otherGames.global_sales': 0.34},
#  {'otherGames.name': 'Classic NES Series: Ice Climber',
#   'otherGames.global_sales': 0.34},
#  {'otherGames.name': "Pandora's Tower", 'otherGames.global_sales': 0.33},
#  {'otherGames.name': 'Planet Puzzle League', 'otherGames.global_sales': 0.33},
#  {'otherGames.name': 'Classic NES Series: Castlevania',
#   'otherGames.global_sales': 0.33},
#  {'otherGames.name': 'Custom Robo', 'otherGames.global_sales': 0.33},
#  {'otherGames.name': 'Dr. Mario / Puzzle League',
#   'otherGames.global_sales': 0.33},
#  {'otherGames.name': "Kirby's Block Ball", 'otherGames.global_sales': 0.32},
#  {'otherGames.name': 'Mario Golf', 'otherGames.global_sales': 0.31},
#  {'otherGames.name': 'Doubutsu no Mori', 'otherGames.global_sales': 0.31},
#  {'otherGames.name': 'KuruKuru Kururin', 'otherGames.global_sales': 0.31},
#  {'otherGames.name': 'Gameboy Gallery', 'otherGames.global_sales': 0.3},
#  {'otherGames.name': 'Trauma Center: New Blood',
#   'otherGames.global_sales': 0.3},
#  {'otherGames.name': 'NES Remix', 'otherGames.global_sales': 0.3},
#  {'otherGames.name': 'Rhythm Tengoku', 'otherGames.global_sales': 0.3},
#  {'otherGames.name': 'Fossil Fighters (JP sales)',
#   'otherGames.global_sales': 0.3},
#  {'otherGames.name': 'Glory of Heracles', 'otherGames.global_sales': 0.3},
#  {'otherGames.name': 'Trace Memory', 'otherGames.global_sales': 0.3},
#  {'otherGames.name': 'Punch-Out!!', 'otherGames.global_sales': 0.29},
#  {'otherGames.name': 'The New Tetris', 'otherGames.global_sales': 0.29},
#  {'otherGames.name': "Ken Griffey Jr.'s Slugfest",
#   'otherGames.global_sales': 0.29},
#  {'otherGames.name': 'Just Dance Wii 2', 'otherGames.global_sales': 0.29},
#  {'otherGames.name': 'Battle & Get! Pokemon Typing DS',
#   'otherGames.global_sales': 0.29},
#  {'otherGames.name': 'Tales of Phantasia', 'otherGames.global_sales': 0.29},
#  {'otherGames.name': 'Final Fantasy VI Advance',
#   'otherGames.global_sales': 0.28},
#  {'otherGames.name': "Mega Man: Dr. Wily's Revenge",
#   'otherGames.global_sales': 0.28},
#  {'otherGames.name': 'Mega Man II', 'otherGames.global_sales': 0.28},
#  {'otherGames.name': 'Sing Party', 'otherGames.global_sales': 0.28},
#  {'otherGames.name': 'Pokemon Box: Ruby & Sapphire',
#   'otherGames.global_sales': 0.28},
#  {'otherGames.name': 'Donkey Kong GB: Dinky Kong & Dixie Kong',
#   'otherGames.global_sales': 0.28},
#  {'otherGames.name': 'ExciteBots: Trick Racing',
#   'otherGames.global_sales': 0.28},
#  {'otherGames.name': 'Moero! Nekketsu Rhythm Damashii: Osu! Tatakae! Ouendan! 2',
#   'otherGames.global_sales': 0.27},
#  {'otherGames.name': 'Baten Kaitos: Eternal Wings and the Lost Ocean',
#   'otherGames.global_sales': 0.27},
#  {'otherGames.name': 'Command & Conquer', 'otherGames.global_sales': 0.27},
#  {'otherGames.name': 'Tohoku Daigaku Karei Igaku Kenkyuusho - Kawashima Ryuuta Kyouju Kanshuu - Mono Sugoku Nou o Kitaeru 5-Funkan no Oni Training',
#   'otherGames.global_sales': 0.27},
#  {'otherGames.name': 'Magical Vacation', 'otherGames.global_sales': 0.27},
#  {'otherGames.name': "America's Test Kitchen: Let's Get Cooking",
#   'otherGames.global_sales': 0.27},
#  {'otherGames.name': 'Fire Emblem: Shin Monshou no Nazo Hikari to Kage no Eiyuu',
#   'otherGames.global_sales': 0.27},
#  {'otherGames.name': 'DS Bungaku Zenshuu', 'otherGames.global_sales': 0.26},
#  {'otherGames.name': 'Inazuma Eleven Strikers',
#   'otherGames.global_sales': 0.26},
#  {'otherGames.name': 'Final Fantasy V Advance',
#   'otherGames.global_sales': 0.26},
#  {'otherGames.name': 'Polarium', 'otherGames.global_sales': 0.26},
#  {'otherGames.name': 'Classic NES Series: Bomberman',
#   'otherGames.global_sales': 0.26},
#  {'otherGames.name': 'Fire Emblem: Thracia 776',
#   'otherGames.global_sales': 0.26},
#  {'otherGames.name': 'Mario & Sonic at the Rio 2016 Olympic Games',
#   'otherGames.global_sales': 0.26},
#  {'otherGames.name': 'Metroid Prime Pinball', 'otherGames.global_sales': 0.26},
#  {'otherGames.name': 'NBA Courtside 2 featuring Kobe Bryant',
#   'otherGames.global_sales': 0.25},
#  {'otherGames.name': "Freshly-Picked: Tingle's Rosy Rupeeland",
#   'otherGames.global_sales': 0.25},
#  {'otherGames.name': 'NBA Courtside 2002', 'otherGames.global_sales': 0.25},
#  {'otherGames.name': 'Classic NES Series: Excitebike',
#   'otherGames.global_sales': 0.25},
#  {'otherGames.name': 'Classic NES Series: Xevious',
#   'otherGames.global_sales': 0.25},
#  {'otherGames.name': 'DK: King of Swing', 'otherGames.global_sales': 0.24},
#  {'otherGames.name': 'Densetsu no Stafi 3', 'otherGames.global_sales': 0.24},
#  {'otherGames.name': 'Chibi-Robo! Zip Lash', 'otherGames.global_sales': 0.24},
#  {'otherGames.name': 'Game & Wario', 'otherGames.global_sales': 0.24},
#  {'otherGames.name': 'Nintendo Presents: Crossword Collection',
#   'otherGames.global_sales': 0.24},
#  {'otherGames.name': 'Girls Mode 3: Kirakira Code',
#   'otherGames.global_sales': 0.23},
#  {'otherGames.name': 'Meteos', 'otherGames.global_sales': 0.23},
#  {'otherGames.name': 'Last Window: The Secret of Cape West',
#   'otherGames.global_sales': 0.23},
#  {'otherGames.name': 'Tetris 2 (weekly jp sales)',
#   'otherGames.global_sales': 0.23},
#  {'otherGames.name': 'Naruto Shippuden: Ninja Council 4',
#   'otherGames.global_sales': 0.23},
#  {'otherGames.name': 'Super Swing Golf', 'otherGames.global_sales': 0.23},
#  {'otherGames.name': 'Super R-Type', 'otherGames.global_sales': 0.23},
#  {'otherGames.name': 'Tetris Attack', 'otherGames.global_sales': 0.23},
#  {'otherGames.name': 'Hamtaro: Ham-Ham Games',
#   'otherGames.global_sales': 0.22},
#  {'otherGames.name': "Kirby's Star Stacker", 'otherGames.global_sales': 0.22},
#  {'otherGames.name': 'Shin Megami Tensei x Fire Emblem',
#   'otherGames.global_sales': 0.22},
#  {'otherGames.name': "Disney's Magical Quest Starring Mickey and Minnie",
#   'otherGames.global_sales': 0.22},
#  {'otherGames.name': 'Spirit Camera: The Cursed Memoir',
#   'otherGames.global_sales': 0.22},
#  {'otherGames.name': 'Yoshi Touch & Go (JP sales)',
#   'otherGames.global_sales': 0.22},
#  {'otherGames.name': 'Code Name: S.T.E.A.M.', 'otherGames.global_sales': 0.22},
#  {'otherGames.name': 'Are You Smarter Than a 5th Grader? Back to School',
#   'otherGames.global_sales': 0.21},
#  {'otherGames.name': 'Heroes of Ruin', 'otherGames.global_sales': 0.21},
#  {'otherGames.name': 'Solatorobo: Red the Hunter',
#   'otherGames.global_sales': 0.21},
#  {'otherGames.name': 'Little Battlers eXperience: Baku Boost',
#   'otherGames.global_sales': 0.21},
#  {'otherGames.name': 'Trade & Battle: Card Hero',
#   'otherGames.global_sales': 0.2},
#  {'otherGames.name': 'Tekken 3D: Prime Edition',
#   'otherGames.global_sales': 0.2},
#  {'otherGames.name': 'Ninja Gaiden 3', 'otherGames.global_sales': 0.19},
#  {'otherGames.name': "Disney's Magical Mirror Starring Mickey Mouse",
#   'otherGames.global_sales': 0.19},
#  {'otherGames.name': 'Disney Magic World 2', 'otherGames.global_sales': 0.19},
#  {'otherGames.name': 'Active Health with Carol Vorderman',
#   'otherGames.global_sales': 0.19},
#  {'otherGames.name': 'Sudoku Gridmaster (JP sales)',
#   'otherGames.global_sales': 0.19},
#  {'otherGames.name': 'Daigasso! Band Brothers',
#   'otherGames.global_sales': 0.19},
#  {'otherGames.name': 'Face Training', 'otherGames.global_sales': 0.19},
#  {'otherGames.name': 'Magical Starsign (US sales)',
#   'otherGames.global_sales': 0.19},
#  {'otherGames.name': 'GameBoy Wars', 'otherGames.global_sales': 0.18},
#  {'otherGames.name': 'Pokémon I Choose You / Squirtle Squad Game Boy Advance Video',
#   'otherGames.global_sales': 0.18},
#  {'otherGames.name': 'Daigasso! Band Brothers P',
#   'otherGames.global_sales': 0.18},
#  {'otherGames.name': 'Sudoku Gridmaster', 'otherGames.global_sales': 0.17},
#  {'otherGames.name': 'Pokémon Beach Blank-out Blastoise / Go West Young Meowth Game Boy Advance Video',
#   'otherGames.global_sales': 0.17},
#  {'otherGames.name': 'Custom Robo Arena', 'otherGames.global_sales': 0.17},
#  {'otherGames.name': 'Densetsu no Stafi 4', 'otherGames.global_sales': 0.17},
#  {'otherGames.name': 'Street Fighter Alpha 2',
#   'otherGames.global_sales': 0.17},
#  {'otherGames.name': 'Itoi Shigesato no Bass Tsuri No. 1',
#   'otherGames.global_sales': 0.17},
#  {'otherGames.name': 'Cubivore: Survival of the Fittest',
#   'otherGames.global_sales': 0.17},
#  {'otherGames.name': 'True Swing Golf', 'otherGames.global_sales': 0.16},
#  {'otherGames.name': 'DS Rakubiki Jiten', 'otherGames.global_sales': 0.16},
#  {'otherGames.name': 'Starcraft 64', 'otherGames.global_sales': 0.16},
#  {'otherGames.name': 'F-Zero: GP Legend', 'otherGames.global_sales': 0.16},
#  {'otherGames.name': 'Culdcept', 'otherGames.global_sales': 0.16},
#  {'otherGames.name': 'Tetris Attack', 'otherGames.global_sales': 0.15},
#  {'otherGames.name': 'Geist', 'otherGames.global_sales': 0.15},
#  {'otherGames.name': 'Okaeri! Chibi-Robo! Happy Richie Oosouji',
#   'otherGames.global_sales': 0.14},
#  {'otherGames.name': 'Doshin the Giant', 'otherGames.global_sales': 0.14},
#  {'otherGames.name': 'Mr. Driller: Drill Spirits',
#   'otherGames.global_sales': 0.14},
#  {'otherGames.name': 'Magnetica', 'otherGames.global_sales': 0.14},
#  {'otherGames.name': 'Kororinpa: Marble Mania',
#   'otherGames.global_sales': 0.14},
#  {'otherGames.name': 'Illusion of Gaia', 'otherGames.global_sales': 0.13},
#  {'otherGames.name': 'Sin and Punishment', 'otherGames.global_sales': 0.13},
#  {'otherGames.name': 'Pokémon: For Ho-Oh the Bells Toll!: Game Boy Advance Video',
#   'otherGames.global_sales': 0.13},
#  {'otherGames.name': 'Eyeshield 21: Max Devil Power',
#   'otherGames.global_sales': 0.12},
#  {'otherGames.name': 'ASH: Archaic Sealed Heat',
#   'otherGames.global_sales': 0.12},
#  {'otherGames.name': 'Pocket Soccer League: Calciobit',
#   'otherGames.global_sales': 0.11},
#  {'otherGames.name': 'Fatal Frame: Maiden of Black Water',
#   'otherGames.global_sales': 0.11},
#  {'otherGames.name': 'Zangeki no Reginleiv', 'otherGames.global_sales': 0.11},
#  {'otherGames.name': 'Kousoku Card Battle: Card Hero',
#   'otherGames.global_sales': 0.11},
#  {'otherGames.name': 'Odama', 'otherGames.global_sales': 0.11},
#  {'otherGames.name': 'Soma Bringer', 'otherGames.global_sales': 0.11},
#  {'otherGames.name': 'Famicom Mini: Famicom Tantei Club - Kieta Koukeisha Zenkouhen',
#   'otherGames.global_sales': 0.11},
#  {'otherGames.name': 'Irozuki Tingle no Koi no Balloon Trip',
#   'otherGames.global_sales': 0.11},
#  {'otherGames.name': 'Picross 3D 2', 'otherGames.global_sales': 0.11},
#  {'otherGames.name': 'Dynasty Warriors Advance',
#   'otherGames.global_sales': 0.11},
#  {'otherGames.name': 'Mega Man Battle Network 5: Double Team DS (JP sales)',
#   'otherGames.global_sales': 0.11},
#  {'otherGames.name': 'Fatal Frame 2: Wii Edition',
#   'otherGames.global_sales': 0.1},
#  {'otherGames.name': "Mickey's Speedway USA (weekly JP sales)",
#   'otherGames.global_sales': 0.1},
#  {'otherGames.name': 'Project Hacker: Kakusei',
#   'otherGames.global_sales': 0.1},
#  {'otherGames.name': "L'Aigle de Guerre", 'otherGames.global_sales': 0.1},
#  {'otherGames.name': 'Nihon Keizai Shinbunsha Kanshuu: Shiranai Mamade wa Son o Suru Mono ya Okane no Shikumi DS',
#   'otherGames.global_sales': 0.1},
#  {'otherGames.name': 'Famicom Mini: Famicom Tantei Club Part II - Ushiro ni Tatsu Shoujo Zenkouhen',
#   'otherGames.global_sales': 0.1},
#  {'otherGames.name': 'Famicom Mini: Mappy', 'otherGames.global_sales': 0.1},
#  {'otherGames.name': 'Touch Mechanic', 'otherGames.global_sales': 0.1},
#  {'otherGames.name': 'Terranigma', 'otherGames.global_sales': 0.09},
#  {'otherGames.name': 'Brain Age: Concentration Training',
#   'otherGames.global_sales': 0.09},
#  {'otherGames.name': 'Pokemon Rumble World', 'otherGames.global_sales': 0.09},
#  {'otherGames.name': 'Disney Art Academy', 'otherGames.global_sales': 0.09},
#  {'otherGames.name': 'Inazuma Eleven 3', 'otherGames.global_sales': 0.09},
#  {'otherGames.name': 'Kurikin: Nano Island Story',
#   'otherGames.global_sales': 0.09},
#  {'otherGames.name': 'Tabi no Yubisashi Kaiwachou DS: DS Series 4 America',
#   'otherGames.global_sales': 0.09},
#  {'otherGames.name': 'Just Dance Wii U', 'otherGames.global_sales': 0.09},
#  {'otherGames.name': 'Famicom Mini: Famicom Mukashi Banashi - Shin Oniga Shima Zenkouhen',
#   'otherGames.global_sales': 0.08},
#  {'otherGames.name': 'Famicom Mini: Mario Bros.',
#   'otherGames.global_sales': 0.08},
#  {'otherGames.name': 'Zero: Tsukihami no Kamen',
#   'otherGames.global_sales': 0.08},
#  {'otherGames.name': 'Famicom Mini: SD Gundam World Gachapon Senshi - Scramble Wars',
#   'otherGames.global_sales': 0.08},
#  {'otherGames.name': 'Famicom Mini: Star Soldier',
#   'otherGames.global_sales': 0.08},
#  {'otherGames.name': 'Minna no Joushiki Ryoku TV',
#   'otherGames.global_sales': 0.08},
#  {'otherGames.name': 'Disaster: Day of Crisis',
#   'otherGames.global_sales': 0.08},
#  {'otherGames.name': 'Famicom Mini: Hikari Shinwa: Palutena no Kagami',
#   'otherGames.global_sales': 0.07},
#  {'otherGames.name': 'Mega Man Battle Network 5: Double Team DS (US sales)',
#   'otherGames.global_sales': 0.07},
#  {'otherGames.name': 'DS Uranai Seikatsu', 'otherGames.global_sales': 0.07},
#  {'otherGames.name': 'Make 10: A Journey of Numbers',
#   'otherGames.global_sales': 0.07},
#  {'otherGames.name': 'Itoi Shigesato no Bass Tsuri No. 1 Ketteihan!',
#   'otherGames.global_sales': 0.07},
#  {'otherGames.name': 'Famicom Mini: Nazo no Murasame-Jou',
#   'otherGames.global_sales': 0.07},
#  {'otherGames.name': 'Famicom Mini: Wrecking Crew',
#   'otherGames.global_sales': 0.07},
#  {'otherGames.name': 'Mario Tennis', 'otherGames.global_sales': 0.07},
#  {'otherGames.name': 'Kanji Sonomama DS Rakubiki Jiten',
#   'otherGames.global_sales': 0.07},
#  {'otherGames.name': 'Another Code R: A Journey into Lost Memories',
#   'otherGames.global_sales': 0.06},
#  {'otherGames.name': 'Famicom Mini: Balloon Fight',
#   'otherGames.global_sales': 0.06},
#  {'otherGames.name': 'Osu! Tatakae! Ouendan', 'otherGames.global_sales': 0.06},
#  {'otherGames.name': 'Mario vs. Donkey Kong: Tipping Stars',
#   'otherGames.global_sales': 0.06},
#  {'otherGames.name': "Devil's Third", 'otherGames.global_sales': 0.06},
#  {'otherGames.name': 'Eigo de Tabisuru: Little Charo',
#   'otherGames.global_sales': 0.06},
#  {'otherGames.name': 'Tabi no Yubisashi Kaiwachou DS: DS Series 3 Kankoku',
#   'otherGames.global_sales': 0.06},
#  {'otherGames.name': 'Dance Dance Revolution: Mario Mix (JP sales)',
#   'otherGames.global_sales': 0.06},
#  {'otherGames.name': 'Culdcept Revolt', 'otherGames.global_sales': 0.05},
#  {'otherGames.name': 'Mawashite Tsunageru Touch Panic',
#   'otherGames.global_sales': 0.05},
#  {'otherGames.name': 'Tabi no Yubisashi Kaiwachou DS: DS Series 2 Chuugoku',
#   'otherGames.global_sales': 0.05},
#  {'otherGames.name': 'QUIZ PARTY', 'otherGames.global_sales': 0.05},
#  {'otherGames.name': 'Wii de Asobu Chibi-Robo!',
#   'otherGames.global_sales': 0.05},
#  {'otherGames.name': 'Tabi no Yubisashi Kaiwachou DS: DS Series 1 Thai',
#   'otherGames.global_sales': 0.05},
#  {'otherGames.name': 'Sekai no Gohan Shaberu! DS Oryouri Navi',
#   'otherGames.global_sales': 0.04},
#  {'otherGames.name': 'Minna ga Shuyaku no NHK Kouhaku Quiz Kassen',
#   'otherGames.global_sales': 0.04},
#  {'otherGames.name': 'Hana to Ikimo no Rittai Zukan',
#   'otherGames.global_sales': 0.04},
#  {'otherGames.name': 'Tabi no Yubisashi Kaiwachou DS: DS Series 5 Deutsch',
#   'otherGames.global_sales': 0.04},
#  {'otherGames.name': 'Famicom Mini: Clu Clu Land',
#   'otherGames.global_sales': 0.04},
#  {'otherGames.name': 'Famicom Remix Best Choice',
#   'otherGames.global_sales': 0.04},
#  {'otherGames.name': 'Magical Starsign (JP sales)',
#   'otherGames.global_sales': 0.04},
#  {'otherGames.name': 'Electroplankton', 'otherGames.global_sales': 0.03},
#  {'otherGames.name': 'Suujin Taisen', 'otherGames.global_sales': 0.03},
#  {'otherGames.name': 'Metroid Prime: Federation Force',
#   'otherGames.global_sales': 0.03},
#  {'otherGames.name': 'Eyeshield 21: Field Saikyou no Senshi Tachi',
#   'otherGames.global_sales': 0.03},
#  {'otherGames.name': 'Eyeshield 21: DevilBats DevilDays',
#   'otherGames.global_sales': 0.03},
#  {'otherGames.name': 'Calcio Bit', 'otherGames.global_sales': 0.03},
#  {'otherGames.name': '1000 Cooking Recipes from ELLE à table',
#   'otherGames.global_sales': 0.03},
#  {'otherGames.name': 'Teddy Together', 'otherGames.global_sales': 0.02},
#  {'otherGames.name': 'Wii de Asobu: Metroid Prime',
#   'otherGames.global_sales': 0.02},
#  {'otherGames.name': 'Wii de Asobu: Metroid Prime',
#   'otherGames.global_sales': 0.02},
#  {'otherGames.name': 'Otona no Renai Shousetsu: Harlequin Selection',
#   'otherGames.global_sales': 0.02},
#  {'otherGames.name': 'Jet Impulse', 'otherGames.global_sales': 0.02},
#  {'otherGames.name': 'Donkey Kong Jungle Beat',
#   'otherGames.global_sales': 0.01},
#  {'otherGames.name': 'Nintendogs and Cats Golden Retriever and New Friends',
#   'otherGames.global_sales': 0.01},
#  {'otherGames.name': 'Slide Adventure: Mag Kid',
#   'otherGames.global_sales': 0.01},
#  {'otherGames.name': 'Mario vs. Donkey Kong: Tipping Stars',
#   'otherGames.global_sales': 0.01},
#  {'otherGames.name': 'Art Academy: Home Studio',
#   'otherGames.global_sales': 0.01},
#  {'otherGames.name': 'Captain Rainbow', 'otherGames.global_sales': 0.01},
#  {'otherGames.name': 'Mario & Luigi: Paper Jam & Mario Kart 7 Double Pack',
#   'otherGames.global_sales': 0.01}]

# %%
cypher = """
  MATCH (game:Game {name:"New Super Mario Bros."})-[:PUBLISHED_BY]->(m)<-[:PUBLISHED_BY]-(othergame)
  RETURN othergame.name, othergame.global_sales
  """
kg.query(cypher)
# Out:
# []

# %%
cypher = """
  MATCH (game:Game {name:"New Super Mario Bros."})-[:PUBLISHED_BY]->(m)<-[:PUBLISHED_BY]-(otherGames)
  return count(*) as rowcount
  """
kg.query(cypher)
# Out:
# [{'rowcount': 702}]

# %%
# df[df['Name']=='New Super Mario Bros.']['Publisher'].values[0]
# df[df['Publisher']==df[df['Name']=='New Super Mario Bros.']['Publisher']]
a=df[df['Publisher']==df[df['Name']=='New Super Mario Bros.']['Publisher'].values[0]]

# %%
a[a['Name']=='New Super Mario Bros.']
# Out:
#    Rank                   Name Platform    Year     Genre Publisher  NA_Sales  \
# 6     7  New Super Mario Bros.       DS  2006.0  Platform  Nintendo     11.38
#
#    EU_Sales  JP_Sales  Other_Sales  Global_Sales
# 6      9.23       6.5          2.9         30.01

# %%
a.shape[0]
# Out:
# 703
